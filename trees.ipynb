# %% [markdown]
# # Exploring Trees and Shadows
#
# We will analyze data from the NYC Tree Census and try to understand the interplay between tree health and shadows. A detailed description of the tree data can be found in StreetTreeCensus2015TreesDataDictionary20161102.pdf. It consists of a table that includes each tree in NYC, together with its location and other attributes (e.g., height, species, etc).
# The shadow data was generated with the ShadowProfiler which calculates shadows cast by buildings in Manhattan. The program takes the dimension of buildings, and the light coming off of the sun, and calculates the shadow intensity and duration. See https://www.nytimes.com/interactive/2016/12/21/upshot/Mapping­the­Shadows­of­New­York­City.html
#
# This notebook will help you get started with the analysis. Here, we use shapefiles (.shp)-- you can find more about shapefiles in https://en.wikipedia.org/wiki/Shapefile
#
# We have constrained the data to Manhattan. So, just unzip this at
#
#     tar -xzf path/to/project/data.tar.gz
#
# If you want to work with the full datasets:
#
# Tree data--* https://data.cityofnewyork.us/Environment/2015-Street-Tree-Census-Tree-Data/pi5s-9p35/data
#
# Shapefiles--* https://www1.nyc.gov/assets/planning/download/zip/data-maps/open-data/nynta_17a.zip
#
# Streets--* https://data.cityofnewyork.us/City-Government/NYC-Street-Centerline-CSCL-/exjm-f27b/data

# %% [markdown]
# ### Some tricks to make it easier to reload the modules while coding

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Loading base modules

# %%
# %reload_ext autoreload
import geopandas as gpd
import pandas as pd
import fiona
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [10,10]

# %% [markdown]
# ### Loading datasets

# %%
from functools import partial
import pyproj
from shapely.ops import transform

#these are the datasets we are working with
villages = gpd.GeoDataFrame.from_file('data/villages-mn.shp', driver='ESRI Shapefile')
streets = gpd.read_file('data/streets-mn.shp', driver='ESRI Shapefile')
trees = gpd.read_file('data/trees-mn.shp', driver='ESRI Shapefile')

# %% [markdown]
# ### Converting coordinate reference system to UTM (flatten the maps to simplify spatial queries)
#
# The Universal Transverse Mercator (UTM) coordinate reference system has its origin on the equator at a specific Longitude. Now the Y-values increase southwards and the X-values increase to the West. The UTM CRS is a global map projection. This means, it is generally used all over the world.(http://docs.qgis.org/2.0/en/docs/gentle_gis_introduction/coordinate_reference_systems.html)

# %%
villages = villages.to_crs(epsg=26918)
streets = streets.to_crs(epsg=26918)
trees = trees.to_crs(epsg=26918)

# %%
len(villages)
# Out:
# 29

# %%
villages
# Out:
#     BoroCode   BoroName CountyFIPS NTACode  \
# 0          1  Manhattan        061    MN06
# 1          1  Manhattan        061    MN17
# 2          1  Manhattan        061    MN19
# 3          1  Manhattan        061    MN20
# 4          1  Manhattan        061    MN21
# 5          1  Manhattan        061    MN27
# 6          1  Manhattan        061    MN50
# 7          1  Manhattan        061    MN34
# 8          1  Manhattan        061    MN31
# 9          1  Manhattan        061    MN04
# 10         1  Manhattan        061    MN03
# 11         1  Manhattan        061    MN01
# 12         1  Manhattan        061    MN11
# 13         1  Manhattan        061    MN40
# 14         1  Manhattan        061    MN14
# 15         1  Manhattan        061    MN09
# 16         1  Manhattan        061    MN12
# 17         1  Manhattan        061    MN22
# 18         1  Manhattan        061    MN28
# 19         1  Manhattan        061    MN35
# 20         1  Manhattan        061    MN36
# 21         1  Manhattan        061    MN25
# 22         1  Manhattan        061    MN24
# 23         1  Manhattan        061    MN23
# 24         1  Manhattan        061    MN13
# 25         1  Manhattan        061    MN15
# 26         1  Manhattan        061    MN32
# 27         1  Manhattan        061    MN33
# 28         1  Manhattan        061    MN99
#
#                                        NTAName    Shape_Area     Shape_Leng  \
# 0                               Manhattanville  1.064708e+07   17040.685475
# 1                        Midtown-Midtown South  3.019206e+07   27035.738062
# 2                      Turtle Bay-East Midtown  1.739787e+07   21638.781375
# 3                         Murray Hill-Kips Bay  1.446596e+07   23135.103743
# 4                                     Gramercy  7.531311e+06   12092.422832
# 5                                    Chinatown  1.450187e+07   20786.255196
# 6               Stuyvesant Town-Cooper Village  5.573902e+06   11000.177313
# 7                            East Harlem North  2.449487e+07   30603.208700
# 8                  Lenox Hill-Roosevelt Island  2.150148e+07   37708.443102
# 9                             Hamilton Heights  1.609379e+07   17410.823138
# 10           Central Harlem North-Polo Grounds  2.540531e+07   28102.837627
# 11                          Marble Hill-Inwood  1.773245e+07   31845.336486
# 12                        Central Harlem South  1.443619e+07   16619.295801
# 13               Upper East Side-Carnegie Hill  2.006536e+07   23778.410765
# 14                              Lincoln Square  1.580564e+07   19866.053544
# 15                         Morningside Heights  2.015898e+07   20744.331519
# 16                             Upper West Side  3.438039e+07   29158.153314
# 17                                East Village  1.089691e+07   13539.253479
# 18                             Lower East Side  2.329777e+07   25466.611465
# 19                    Washington Heights North  2.266061e+07   26672.985434
# 20                    Washington Heights South  2.310048e+07   22095.210893
# 21           Battery Park City-Lower Manhattan  1.905416e+07   45693.079407
# 22      SoHo-TriBeCa-Civic Center-Little Italy  2.486157e+07   24277.730228
# 23                                West Village  2.500053e+07   29385.030535
# 24  Hudson Yards-Chelsea-Flatiron-Union Square  3.702972e+07   45454.722274
# 25                                     Clinton  1.838139e+07   35037.171741
# 26                                   Yorkville  1.359480e+07   17409.209799
# 27                           East Harlem South  1.665069e+07   18625.067610
# 28                 park-cemetery-etc-Manhattan  9.154071e+07  155078.174573
#
#                                              geometry
# 0   POLYGON ((588876.1785597933 4519450.267877867,...
# 1   POLYGON ((586678.6911153347 4513097.574779067,...
# 2   (POLYGON ((587703.2741437969 4510461.153370242...
# 3   (POLYGON ((587623.6256422841 4509648.642779417...
# 4   POLYGON ((586251.3783624729 4510040.811386588,...
# 5   POLYGON ((585821.3946368636 4508335.179919497,...
# 6   (POLYGON ((587630.0675326242 4508660.108073168...
# 7   (POLYGON ((590501.9336688609 4516815.013944671...
# 8   (POLYGON ((589306.8937351991 4513658.171538641...
# 9   POLYGON ((589347.2057885575 4520476.782137589,...
# 10  POLYGON ((589911.4746366711 4519266.040511988,...
# 11  (POLYGON ((590898.9874979255 4523398.305138851...
# 12  POLYGON ((589258.3768370337 4517881.183358252,...
# 13  POLYGON ((588649.8026216743 4515442.888737123,...
# 14  POLYGON ((586494.1675317499 4514566.877235616,...
# 15  POLYGON ((588381.2931646316 4518354.031700201,...
# 16  POLYGON ((587730.1966700222 4516858.027595109,...
# 17  POLYGON ((585915.7454167157 4509432.863223869,...
# 18  (POLYGON ((585964.3839419651 4506568.316394739...
# 19  POLYGON ((590277.7277520876 4524516.515419188,...
# 20  POLYGON ((590079.1228794146 4522369.819538517,...
# 21  (POLYGON ((584423.418549469 4505300.884525624,...
# 22  POLYGON ((585076.5290951424 4508622.311958601,...
# 23  POLYGON ((585291.4233615998 4509768.118086833,...
# 24  POLYGON ((584273.7491857304 4512888.374912286,...
# 25  POLYGON ((584910.7365491197 4514037.756837863,...
# 26  (POLYGON ((589607.8773951404 4514969.964364661...
# 27  POLYGON ((589845.8300834247 4516178.316162244,...
# 28  (POLYGON ((583578.4583573071 4504203.877192213...

# %%
from datetime import datetime

m = trees.created_at

def get_date(x):
    dt = datetime.strptime(x, '%m/%d/%Y')
    return dt

trees['created_custom'] = trees.created_at.apply(lambda x: get_date(x))

# %%
t = trees.created_custom
print (t.min(), t.max())
# Out:
# 2015-05-19 00:00:00 2016-10-03 00:00:00

# %% [markdown]
# ### Let's plot some trees and streets in Manhattan
#
# To save time, you can work with smaller samples

# %%
fig, ax = plt.subplots()
ax.set_aspect('equal')
villages.sample(29).plot(ax=ax, color="white", linewidth=.1)
trees.sample(100).plot(ax=ax) # there are 6500 trees
streets.sample(100).plot(ax=ax)
#villages

# %% [markdown]
# ### What are the contents and columns of these dataset?

# %%
trees.head()
# Out:
#               address  block_id  boro_ct borocode   boroname brnch_ligh  \
# 0   8 COLUMBUS AVENUE  106099.0  1014500        1  Manhattan         No
# 1  120 WEST 60 STREET  106099.0  1014500        1  Manhattan         No
# 2  311 WEST 50 STREET  103940.0  1012700        1  Manhattan         No
# 3  170 EAST 75 STREET  107600.0  1012800        1  Manhattan         No
# 4       2163 BROADWAY  107038.0  1016300        1  Manhattan         No
#
#   brnch_othe brnch_shoe cb_num  cncldist      ...       trnk_light trnk_other  \
# 0         No         No    107       3.0      ...               No         No
# 1         No         No    107       3.0      ...               No         No
# 2         No         No    104       3.0      ...               No         No
# 3        Yes         No    108       4.0      ...               No        Yes
# 4         No         No    107       6.0      ...               No         No
#
#   trnk_wire         user_type                        village           x_sp  \
# 0        No         Volunteer                 Lincoln Square  988418.699656
# 1        No         Volunteer                 Lincoln Square  988311.190028
# 2        No         Volunteer                        Clinton  987769.116309
# 3        No         Volunteer  Upper East Side-Carnegie Hill  995203.003673
# 4        No  TreesCount Staff                Upper West Side  989521.741413
#
#             y_sp  zip_city zipcode created_custom
# 0  219825.522669  New York   10023     2015-08-30
# 1  219885.278455  New York   10023     2015-08-30
# 2  217157.856088  New York   10019     2015-09-07
# 3  220602.155302  New York   10021     2015-08-31
# 4  224212.887582  New York   10024     2015-09-03
#
# [5 rows x 44 columns]

# %%
trees.columns
# Out:
# Index(['address', 'block_id', 'boro_ct', 'borocode', 'boroname', 'brnch_ligh',
#        'brnch_othe', 'brnch_shoe', 'cb_num', 'cncldist', 'created_at',
#        'curb_loc', 'geometry', 'guards', 'health', 'latitude', 'longitude',
#        'nta', 'nta_name', 'problems', 'root_grate', 'root_other', 'root_stone',
#        'sidewalk', 'spc_common', 'spc_latin', 'st_assem', 'st_senate', 'state',
#        'status', 'steward', 'stump_diam', 'tree_dbh', 'tree_id', 'trnk_light',
#        'trnk_other', 'trnk_wire', 'user_type', 'village', 'x_sp', 'y_sp',
#        'zip_city', 'zipcode', 'created_custom'],
#       dtype='object')

# %%
villages.columns
# Out:
# Index(['BoroCode', 'BoroName', 'CountyFIPS', 'NTACode', 'NTAName',
#        'Shape_Area', 'Shape_Leng', 'geometry'],
#       dtype='object')

# %%
villages.head()
# Out:
#    BoroCode   BoroName CountyFIPS NTACode                  NTAName  \
# 0         1  Manhattan        061    MN06           Manhattanville
# 1         1  Manhattan        061    MN17    Midtown-Midtown South
# 2         1  Manhattan        061    MN19  Turtle Bay-East Midtown
# 3         1  Manhattan        061    MN20     Murray Hill-Kips Bay
# 4         1  Manhattan        061    MN21                 Gramercy
#
#      Shape_Area    Shape_Leng  \
# 0  1.064708e+07  17040.685475
# 1  3.019206e+07  27035.738062
# 2  1.739787e+07  21638.781375
# 3  1.446596e+07  23135.103743
# 4  7.531311e+06  12092.422832
#
#                                             geometry
# 0  POLYGON ((588876.1785597933 4519450.267877867,...
# 1  POLYGON ((586678.6911153347 4513097.574779067,...
# 2  (POLYGON ((587703.2741437969 4510461.153370242...
# 3  (POLYGON ((587623.6256422841 4509648.642779417...
# 4  POLYGON ((586251.3783624729 4510040.811386588,...

# %% [markdown]
# NTA Name=Neighbourhood Tabulation Area Code

# %% [markdown]
# ### Now, let's find out where trees are located and save inside their metadata
#
# Since this step takes a little while, we will also save this as a file

# %%
if 'village' not in trees.columns:
    def find(x):
        v = villages[villages.intersects(x)]['NTAName'].iloc[0]
        return v 
    trees['village'] = trees['geometry'].apply(lambda x: find(x))
    # let's save this to not run again in future
    trees.to_file('data/trees-mn.shp')

# %% [markdown]
# ### Group trees by village and checking some basic statistics

# %%
trees_dead = trees.loc[trees['status']=="Dead"]
trees_dead.head()
len(trees_dead)
# Out:
# 1802

# %%
groups = trees.groupby('village')
#groups.get_group('Upper West Side').describe()
groups.get_group('Marble Hill-Inwood').describe()
# Out:
#             block_id  cncldist     latitude    longitude  st_assem  st_senate  \
# count    1419.000000    1419.0  1419.000000  1419.000000    1419.0     1419.0
# mean   117378.390416      10.0    40.866748   -73.920800      72.0       31.0
# std     53448.266974       0.0     0.003147     0.003615       0.0        0.0
# min    111003.000000      10.0    40.859429   -73.928560      72.0       31.0
# 25%    111403.000000      10.0    40.864434   -73.923640      72.0       31.0
# 50%    111481.000000      10.0    40.866954   -73.920880      72.0       31.0
# 75%    111556.000000      10.0    40.868877   -73.918310      72.0       31.0
# max    602589.000000      10.0    40.872890   -73.911202      72.0       31.0
#
#         stump_diam     tree_dbh        tree_id          x_sp           y_sp
# count  1419.000000  1419.000000    1419.000000  1.419000e+03    1419.000000
# mean      0.162791     6.674419   73402.516561  1.006156e+06  255067.204889
# std       1.580781     5.188110   56942.721095  9.994776e+02    1147.004765
# min       0.000000     0.000000   33733.000000  1.004009e+06  252400.008045
# 25%       0.000000     3.000000   48477.500000  1.005371e+06  254224.017520
# 50%       0.000000     5.000000   59348.000000  1.006133e+06  255141.093114
# 75%       0.000000     9.000000   75222.500000  1.006845e+06  255842.286921
# max      36.000000    46.000000  451193.000000  1.008809e+06  257305.647840

# %% [markdown]
# ### You can now explore the data and compile 'interesting' statistics about tree height, species, health, etc.

# %%
trees.head()
# Out:
#               address  block_id  boro_ct borocode   boroname brnch_ligh  \
# 0   8 COLUMBUS AVENUE  106099.0  1014500        1  Manhattan         No
# 1  120 WEST 60 STREET  106099.0  1014500        1  Manhattan         No
# 2  311 WEST 50 STREET  103940.0  1012700        1  Manhattan         No
# 3  170 EAST 75 STREET  107600.0  1012800        1  Manhattan         No
# 4       2163 BROADWAY  107038.0  1016300        1  Manhattan         No
#
#   brnch_othe brnch_shoe cb_num  cncldist      ...       trnk_light trnk_other  \
# 0         No         No    107       3.0      ...               No         No
# 1         No         No    107       3.0      ...               No         No
# 2         No         No    104       3.0      ...               No         No
# 3        Yes         No    108       4.0      ...               No        Yes
# 4         No         No    107       6.0      ...               No         No
#
#   trnk_wire         user_type                        village           x_sp  \
# 0        No         Volunteer                 Lincoln Square  988418.699656
# 1        No         Volunteer                 Lincoln Square  988311.190028
# 2        No         Volunteer                        Clinton  987769.116309
# 3        No         Volunteer  Upper East Side-Carnegie Hill  995203.003673
# 4        No  TreesCount Staff                Upper West Side  989521.741413
#
#             y_sp  zip_city zipcode created_custom
# 0  219825.522669  New York   10023     2015-08-30
# 1  219885.278455  New York   10023     2015-08-30
# 2  217157.856088  New York   10019     2015-09-07
# 3  220602.155302  New York   10021     2015-08-31
# 4  224212.887582  New York   10024     2015-09-03
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Now let's look at the shadows in different seasons
#
# The csv files contain, for each season and each tree, the number of minutes the tree is under sunlight

# %%
shd = []
# summer
shd.append(pd.read_csv('data/tree-shade-june-21.csv'))
# fall and spring
shd.append(pd.read_csv('data/tree-shade-sep-22.csv'))
# winter
shd.append(pd.read_csv('data/tree-shade-dec-21.csv'))

# %%
shd
# Out:
# [        tree_id  time
#  0        180683    78
#  1        200540     0
#  2        204026   318
#  3        204337   169
#  4        189565   145
#  5        190422   539
#  6        190426   429
#  7        208649   484
#  8        209610    26
#  9        192755     3
#  10       203719   236
#  11       203726   155
#  12       195202     0
#  13       189465   365
#  14       192998   310
#  15       189834    48
#  16       204208   338
#  17       161339   352
#  18       187311   192
#  19       208201   402
#  20       193093    39
#  21       193310   533
#  22       199760   525
#  23       204325   109
#  24       189700   162
#  25       205044   145
#  26       192942   171
#  27       195265   308
#  28       201555   392
#  29       208407    47
#  ...         ...   ...
#  683758   183515   164
#  683759   179860    88
#  683760   178849   250
#  683761   191692   192
#  683762   180028   440
#  683763   195286   268
#  683764   170513   369
#  683765   192369   297
#  683766   198289    71
#  683767   203987   217
#  683768   190040   328
#  683769   179301    66
#  683770   183963    98
#  683771   181448    42
#  683772   189461   103
#  683773   191269   430
#  683774   200250   363
#  683775   192812   340
#  683776   179969   212
#  683777   181723     0
#  683778   200671   277
#  683779   193070     0
#  683780   195173    92
#  683781   155348   336
#  683782   184210   360
#  683783   155433   245
#  683784   183795   220
#  683785   166161    66
#  683786   184028    74
#  683787   200607    50
#
#  [683788 rows x 2 columns],         tree_id  time
#  0        180683   159
#  1        200540     0
#  2        204026   174
#  3        204337     0
#  4        189565   179
#  5        190422   484
#  6        190426   500
#  7        208649   272
#  8        209610     0
#  9        192755     0
#  10       203719    61
#  11       203726    73
#  12       195202     0
#  13       189465   341
#  14       192998   230
#  15       189834    35
#  16       204208   272
#  17       161339   344
#  18       187311   162
#  19       208201   279
#  20       193093   219
#  21       193310   486
#  22       199760   351
#  23       204325    28
#  24       189700   213
#  25       205044   104
#  26       192942   107
#  27       195265   190
#  28       201555   447
#  29       208407    97
#  ...         ...   ...
#  683758   183515    47
#  683759   179860    63
#  683760   178849   235
#  683761   191692   100
#  683762   180028   325
#  683763   195286   206
#  683764   170513   271
#  683765   192369   190
#  683766   198289   153
#  683767   203987   115
#  683768   190040   273
#  683769   179301     0
#  683770   183963   102
#  683771   181448    76
#  683772   189461   230
#  683773   191269   286
#  683774   200250   188
#  683775   192812   331
#  683776   179969   142
#  683777   181723     0
#  683778   200671   221
#  683779   193070   105
#  683780   195173     0
#  683781   155348   343
#  683782   184210   282
#  683783   155433   133
#  683784   183795   307
#  683785   166161   382
#  683786   184028   317
#  683787   200607    92
#
#  [683788 rows x 2 columns],         tree_id  time
#  0        180683   353
#  1        200540   149
#  2        204026     5
#  3        204337   131
#  4        189565   331
#  5        190422   360
#  6        190426   360
#  7        208649   306
#  8        209610    53
#  9        192755   137
#  10       203719   206
#  11       203726   244
#  12       195202   196
#  13       189465   218
#  14       192998   161
#  15       189834   360
#  16       204208    58
#  17       161339   358
#  18       187311   210
#  19       208201   202
#  20       193093   213
#  21       193310   360
#  22       199760   265
#  23       204325    68
#  24       189700   183
#  25       205044    93
#  26       192942   130
#  27       195265     0
#  28       201555   360
#  29       208407     0
#  ...         ...   ...
#  683758   183515   162
#  683759   179860   261
#  683760   178849   282
#  683761   191692   232
#  683762   180028   252
#  683763   195286   142
#  683764   170513   262
#  683765   192369    70
#  683766   198289   124
#  683767   203987    33
#  683768   190040   360
#  683769   179301     0
#  683770   183963   192
#  683771   181448   100
#  683772   189461   222
#  683773   191269   331
#  683774   200250   181
#  683775   192812   257
#  683776   179969   108
#  683777   181723   199
#  683778   200671   151
#  683779   193070   360
#  683780   195173    84
#  683781   155348   207
#  683782   184210   237
#  683783   155433    60
#  683784   183795   324
#  683785   166161   336
#  683786   184028   276
#  683787   200607    43
#
#  [683788 rows x 2 columns]]

# %% [markdown]
# For each tree, compute the length of time in sun and shade for the different seasons

# %%
# season_shadow captures the time the tree is in shadow
# season_sun captures the time when the tree is not in shadow
tree_shd = {}

def extract_sun(season_shadow,season_sun,shade_max,shd):

    for i,r in shd.iterrows():

        id = r['tree_id']

        if id not in tree_shd:
            tree_shd[id] = {}

        tree_shd[id][season_shadow] = r['time']
        tree_shd[id][season_sun] = shade_max-r['time']

extract_sun('summer', 'summer_sun', 720, shd[0])
extract_sun('fall', 'fall_sun', 540, shd[1])
extract_sun('winter','winter_sun', 360, shd[2])

# %%
tree_shd[180683]
# Out:
# {180683: {'fall': 159,
#   'fall_sun': 381,
#   'summer': 78,
#   'summer_sun': 642,
#   'winter': 353,
#   'winter_sun': 7},
#  200540: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 149,
#   'winter_sun': 211},
#  204026: {'fall': 174,
#   'fall_sun': 366,
#   'summer': 318,
#   'summer_sun': 402,
#   'winter': 5,
#   'winter_sun': 355},
#  204337: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 169,
#   'summer_sun': 551,
#   'winter': 131,
#   'winter_sun': 229},
#  189565: {'fall': 179,
#   'fall_sun': 361,
#   'summer': 145,
#   'summer_sun': 575,
#   'winter': 331,
#   'winter_sun': 29},
#  190422: {'fall': 484,
#   'fall_sun': 56,
#   'summer': 539,
#   'summer_sun': 181,
#   'winter': 360,
#   'winter_sun': 0},
#  190426: {'fall': 500,
#   'fall_sun': 40,
#   'summer': 429,
#   'summer_sun': 291,
#   'winter': 360,
#   'winter_sun': 0},
#  208649: {'fall': 272,
#   'fall_sun': 268,
#   'summer': 484,
#   'summer_sun': 236,
#   'winter': 306,
#   'winter_sun': 54},
#  209610: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 26,
#   'summer_sun': 694,
#   'winter': 53,
#   'winter_sun': 307},
#  192755: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 3,
#   'summer_sun': 717,
#   'winter': 137,
#   'winter_sun': 223},
#  203719: {'fall': 61,
#   'fall_sun': 479,
#   'summer': 236,
#   'summer_sun': 484,
#   'winter': 206,
#   'winter_sun': 154},
#  203726: {'fall': 73,
#   'fall_sun': 467,
#   'summer': 155,
#   'summer_sun': 565,
#   'winter': 244,
#   'winter_sun': 116},
#  195202: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 196,
#   'winter_sun': 164},
#  189465: {'fall': 341,
#   'fall_sun': 199,
#   'summer': 365,
#   'summer_sun': 355,
#   'winter': 218,
#   'winter_sun': 142},
#  192998: {'fall': 230,
#   'fall_sun': 310,
#   'summer': 310,
#   'summer_sun': 410,
#   'winter': 161,
#   'winter_sun': 199},
#  189834: {'fall': 35,
#   'fall_sun': 505,
#   'summer': 48,
#   'summer_sun': 672,
#   'winter': 360,
#   'winter_sun': 0},
#  204208: {'fall': 272,
#   'fall_sun': 268,
#   'summer': 338,
#   'summer_sun': 382,
#   'winter': 58,
#   'winter_sun': 302},
#  161339: {'fall': 344,
#   'fall_sun': 196,
#   'summer': 352,
#   'summer_sun': 368,
#   'winter': 358,
#   'winter_sun': 2},
#  187311: {'fall': 162,
#   'fall_sun': 378,
#   'summer': 192,
#   'summer_sun': 528,
#   'winter': 210,
#   'winter_sun': 150},
#  208201: {'fall': 279,
#   'fall_sun': 261,
#   'summer': 402,
#   'summer_sun': 318,
#   'winter': 202,
#   'winter_sun': 158},
#  193093: {'fall': 219,
#   'fall_sun': 321,
#   'summer': 39,
#   'summer_sun': 681,
#   'winter': 213,
#   'winter_sun': 147},
#  193310: {'fall': 486,
#   'fall_sun': 54,
#   'summer': 533,
#   'summer_sun': 187,
#   'winter': 360,
#   'winter_sun': 0},
#  199760: {'fall': 351,
#   'fall_sun': 189,
#   'summer': 525,
#   'summer_sun': 195,
#   'winter': 265,
#   'winter_sun': 95},
#  204325: {'fall': 28,
#   'fall_sun': 512,
#   'summer': 109,
#   'summer_sun': 611,
#   'winter': 68,
#   'winter_sun': 292},
#  189700: {'fall': 213,
#   'fall_sun': 327,
#   'summer': 162,
#   'summer_sun': 558,
#   'winter': 183,
#   'winter_sun': 177},
#  205044: {'fall': 104,
#   'fall_sun': 436,
#   'summer': 145,
#   'summer_sun': 575,
#   'winter': 93,
#   'winter_sun': 267},
#  192942: {'fall': 107,
#   'fall_sun': 433,
#   'summer': 171,
#   'summer_sun': 549,
#   'winter': 130,
#   'winter_sun': 230},
#  195265: {'fall': 190,
#   'fall_sun': 350,
#   'summer': 308,
#   'summer_sun': 412,
#   'winter': 0,
#   'winter_sun': 360},
#  201555: {'fall': 447,
#   'fall_sun': 93,
#   'summer': 392,
#   'summer_sun': 328,
#   'winter': 360,
#   'winter_sun': 0},
#  208407: {'fall': 97,
#   'fall_sun': 443,
#   'summer': 47,
#   'summer_sun': 673,
#   'winter': 0,
#   'winter_sun': 360},
#  189164: {'fall': 231,
#   'fall_sun': 309,
#   'summer': 312,
#   'summer_sun': 408,
#   'winter': 57,
#   'winter_sun': 303},
#  184375: {'fall': 292,
#   'fall_sun': 248,
#   'summer': 420,
#   'summer_sun': 300,
#   'winter': 206,
#   'winter_sun': 154},
#  187056: {'fall': 442,
#   'fall_sun': 98,
#   'summer': 451,
#   'summer_sun': 269,
#   'winter': 360,
#   'winter_sun': 0},
#  187058: {'fall': 435,
#   'fall_sun': 105,
#   'summer': 552,
#   'summer_sun': 168,
#   'winter': 357,
#   'winter_sun': 3},
#  178659: {'fall': 249,
#   'fall_sun': 291,
#   'summer': 93,
#   'summer_sun': 627,
#   'winter': 345,
#   'winter_sun': 15},
#  190423: {'fall': 496,
#   'fall_sun': 44,
#   'summer': 520,
#   'summer_sun': 200,
#   'winter': 360,
#   'winter_sun': 0},
#  190425: {'fall': 500,
#   'fall_sun': 40,
#   'summer': 409,
#   'summer_sun': 311,
#   'winter': 360,
#   'winter_sun': 0},
#  204202: {'fall': 92,
#   'fall_sun': 448,
#   'summer': 187,
#   'summer_sun': 533,
#   'winter': 32,
#   'winter_sun': 328},
#  201494: {'fall': 8,
#   'fall_sun': 532,
#   'summer': 180,
#   'summer_sun': 540,
#   'winter': 25,
#   'winter_sun': 335},
#  208346: {'fall': 102,
#   'fall_sun': 438,
#   'summer': 296,
#   'summer_sun': 424,
#   'winter': 121,
#   'winter_sun': 239},
#  181710: {'fall': 138,
#   'fall_sun': 402,
#   'summer': 111,
#   'summer_sun': 609,
#   'winter': 64,
#   'winter_sun': 296},
#  178382: {'fall': 324,
#   'fall_sun': 216,
#   'summer': 259,
#   'summer_sun': 461,
#   'winter': 302,
#   'winter_sun': 58},
#  193690: {'fall': 70,
#   'fall_sun': 470,
#   'summer': 139,
#   'summer_sun': 581,
#   'winter': 0,
#   'winter_sun': 360},
#  196089: {'fall': 21,
#   'fall_sun': 519,
#   'summer': 235,
#   'summer_sun': 485,
#   'winter': 28,
#   'winter_sun': 332},
#  191988: {'fall': 247,
#   'fall_sun': 293,
#   'summer': 157,
#   'summer_sun': 563,
#   'winter': 347,
#   'winter_sun': 13},
#  203720: {'fall': 191,
#   'fall_sun': 349,
#   'summer': 136,
#   'summer_sun': 584,
#   'winter': 232,
#   'winter_sun': 128},
#  189339: {'fall': 114,
#   'fall_sun': 426,
#   'summer': 21,
#   'summer_sun': 699,
#   'winter': 3,
#   'winter_sun': 357},
#  208230: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 95,
#   'summer_sun': 625,
#   'winter': 130,
#   'winter_sun': 230},
#  204413: {'fall': 48,
#   'fall_sun': 492,
#   'summer': 175,
#   'summer_sun': 545,
#   'winter': 24,
#   'winter_sun': 336},
#  161193: {'fall': 79,
#   'fall_sun': 461,
#   'summer': 146,
#   'summer_sun': 574,
#   'winter': 51,
#   'winter_sun': 309},
#  196132: {'fall': 88,
#   'fall_sun': 452,
#   'summer': 113,
#   'summer_sun': 607,
#   'winter': 186,
#   'winter_sun': 174},
#  196223: {'fall': 33,
#   'fall_sun': 507,
#   'summer': 22,
#   'summer_sun': 698,
#   'winter': 0,
#   'winter_sun': 360},
#  192888: {'fall': 195,
#   'fall_sun': 345,
#   'summer': 194,
#   'summer_sun': 526,
#   'winter': 125,
#   'winter_sun': 235},
#  192890: {'fall': 203,
#   'fall_sun': 337,
#   'summer': 165,
#   'summer_sun': 555,
#   'winter': 124,
#   'winter_sun': 236},
#  197978: {'fall': 129,
#   'fall_sun': 411,
#   'summer': 387,
#   'summer_sun': 333,
#   'winter': 22,
#   'winter_sun': 338},
#  178601: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 69,
#   'summer_sun': 651,
#   'winter': 0,
#   'winter_sun': 360},
#  184317: {'fall': 242,
#   'fall_sun': 298,
#   'summer': 273,
#   'summer_sun': 447,
#   'winter': 106,
#   'winter_sun': 254},
#  184031: {'fall': 210,
#   'fall_sun': 330,
#   'summer': 67,
#   'summer_sun': 653,
#   'winter': 348,
#   'winter_sun': 12},
#  200225: {'fall': 398,
#   'fall_sun': 142,
#   'summer': 547,
#   'summer_sun': 173,
#   'winter': 199,
#   'winter_sun': 161},
#  208974: {'fall': 50,
#   'fall_sun': 490,
#   'summer': 140,
#   'summer_sun': 580,
#   'winter': 32,
#   'winter_sun': 328},
#  198146: {'fall': 2,
#   'fall_sun': 538,
#   'summer': 138,
#   'summer_sun': 582,
#   'winter': 0,
#   'winter_sun': 360},
#  198121: {'fall': 468,
#   'fall_sun': 72,
#   'summer': 525,
#   'summer_sun': 195,
#   'winter': 360,
#   'winter_sun': 0},
#  195252: {'fall': 432,
#   'fall_sun': 108,
#   'summer': 384,
#   'summer_sun': 336,
#   'winter': 360,
#   'winter_sun': 0},
#  204355: {'fall': 16,
#   'fall_sun': 524,
#   'summer': 90,
#   'summer_sun': 630,
#   'winter': 64,
#   'winter_sun': 296},
#  205759: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 20,
#   'summer_sun': 700,
#   'winter': 0,
#   'winter_sun': 360},
#  201654: {'fall': 250,
#   'fall_sun': 290,
#   'summer': 353,
#   'summer_sun': 367,
#   'winter': 197,
#   'winter_sun': 163},
#  198514: {'fall': 316,
#   'fall_sun': 224,
#   'summer': 308,
#   'summer_sun': 412,
#   'winter': 357,
#   'winter_sun': 3},
#  203334: {'fall': 365,
#   'fall_sun': 175,
#   'summer': 478,
#   'summer_sun': 242,
#   'winter': 242,
#   'winter_sun': 118},
#  200628: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 2,
#   'summer_sun': 718,
#   'winter': 53,
#   'winter_sun': 307},
#  186888: {'fall': 89,
#   'fall_sun': 451,
#   'summer': 144,
#   'summer_sun': 576,
#   'winter': 47,
#   'winter_sun': 313},
#  196373: {'fall': 228,
#   'fall_sun': 312,
#   'summer': 189,
#   'summer_sun': 531,
#   'winter': 133,
#   'winter_sun': 227},
#  209441: {'fall': 42,
#   'fall_sun': 498,
#   'summer': 114,
#   'summer_sun': 606,
#   'winter': 357,
#   'winter_sun': 3},
#  206435: {'fall': 66,
#   'fall_sun': 474,
#   'summer': 127,
#   'summer_sun': 593,
#   'winter': 55,
#   'winter_sun': 305},
#  196080: {'fall': 185,
#   'fall_sun': 355,
#   'summer': 216,
#   'summer_sun': 504,
#   'winter': 160,
#   'winter_sun': 200},
#  203759: {'fall': 112,
#   'fall_sun': 428,
#   'summer': 34,
#   'summer_sun': 686,
#   'winter': 42,
#   'winter_sun': 318},
#  190359: {'fall': 321,
#   'fall_sun': 219,
#   'summer': 327,
#   'summer_sun': 393,
#   'winter': 210,
#   'winter_sun': 150},
#  209909: {'fall': 316,
#   'fall_sun': 224,
#   'summer': 299,
#   'summer_sun': 421,
#   'winter': 291,
#   'winter_sun': 69},
#  180295: {'fall': 479,
#   'fall_sun': 61,
#   'summer': 532,
#   'summer_sun': 188,
#   'winter': 360,
#   'winter_sun': 0},
#  208373: {'fall': 256,
#   'fall_sun': 284,
#   'summer': 208,
#   'summer_sun': 512,
#   'winter': 223,
#   'winter_sun': 137},
#  196205: {'fall': 324,
#   'fall_sun': 216,
#   'summer': 307,
#   'summer_sun': 413,
#   'winter': 360,
#   'winter_sun': 0},
#  192086: {'fall': 14,
#   'fall_sun': 526,
#   'summer': 28,
#   'summer_sun': 692,
#   'winter': 9,
#   'winter_sun': 351},
#  203550: {'fall': 160,
#   'fall_sun': 380,
#   'summer': 175,
#   'summer_sun': 545,
#   'winter': 131,
#   'winter_sun': 229},
#  203718: {'fall': 249,
#   'fall_sun': 291,
#   'summer': 122,
#   'summer_sun': 598,
#   'winter': 215,
#   'winter_sun': 145},
#  208832: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 8,
#   'summer_sun': 712,
#   'winter': 110,
#   'winter_sun': 250},
#  193183: {'fall': 148,
#   'fall_sun': 392,
#   'summer': 212,
#   'summer_sun': 508,
#   'winter': 36,
#   'winter_sun': 324},
#  203577: {'fall': 60,
#   'fall_sun': 480,
#   'summer': 154,
#   'summer_sun': 566,
#   'winter': 26,
#   'winter_sun': 334},
#  179477: {'fall': 229,
#   'fall_sun': 311,
#   'summer': 99,
#   'summer_sun': 621,
#   'winter': 255,
#   'winter_sun': 105},
#  203386: {'fall': 122,
#   'fall_sun': 418,
#   'summer': 68,
#   'summer_sun': 652,
#   'winter': 123,
#   'winter_sun': 237},
#  189537: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 53,
#   'summer_sun': 667,
#   'winter': 38,
#   'winter_sun': 322},
#  196130: {'fall': 97,
#   'fall_sun': 443,
#   'summer': 164,
#   'summer_sun': 556,
#   'winter': 181,
#   'winter_sun': 179},
#  200676: {'fall': 219,
#   'fall_sun': 321,
#   'summer': 317,
#   'summer_sun': 403,
#   'winter': 154,
#   'winter_sun': 206},
#  206326: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 1,
#   'summer_sun': 719,
#   'winter': 0,
#   'winter_sun': 360},
#  204118: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 74,
#   'summer_sun': 646,
#   'winter': 0,
#   'winter_sun': 360},
#  192653: {'fall': 122,
#   'fall_sun': 418,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 132,
#   'winter_sun': 228},
#  203592: {'fall': 109,
#   'fall_sun': 431,
#   'summer': 160,
#   'summer_sun': 560,
#   'winter': 55,
#   'winter_sun': 305},
#  189338: {'fall': 54,
#   'fall_sun': 486,
#   'summer': 110,
#   'summer_sun': 610,
#   'winter': 213,
#   'winter_sun': 147},
#  208240: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 143,
#   'summer_sun': 577,
#   'winter': 151,
#   'winter_sun': 209},
#  208247: {'fall': 25,
#   'fall_sun': 515,
#   'summer': 149,
#   'summer_sun': 571,
#   'winter': 0,
#   'winter_sun': 360},
#  204203: {'fall': 32,
#   'fall_sun': 508,
#   'summer': 6,
#   'summer_sun': 714,
#   'winter': 22,
#   'winter_sun': 338},
#  203385: {'fall': 77,
#   'fall_sun': 463,
#   'summer': 65,
#   'summer_sun': 655,
#   'winter': 162,
#   'winter_sun': 198},
#  196372: {'fall': 251,
#   'fall_sun': 289,
#   'summer': 208,
#   'summer_sun': 512,
#   'winter': 141,
#   'winter_sun': 219},
#  192889: {'fall': 103,
#   'fall_sun': 437,
#   'summer': 259,
#   'summer_sun': 461,
#   'winter': 98,
#   'winter_sun': 262},
#  203760: {'fall': 30,
#   'fall_sun': 510,
#   'summer': 180,
#   'summer_sun': 540,
#   'winter': 134,
#   'winter_sun': 226},
#  203767: {'fall': 93,
#   'fall_sun': 447,
#   'summer': 27,
#   'summer_sun': 693,
#   'winter': 102,
#   'winter_sun': 258},
#  208458: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 0,
#   'winter_sun': 360},
#  209919: {'fall': 164,
#   'fall_sun': 376,
#   'summer': 273,
#   'summer_sun': 447,
#   'winter': 230,
#   'winter_sun': 130},
#  198296: {'fall': 357,
#   'fall_sun': 183,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 290,
#   'winter_sun': 70},
#  204169: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 312,
#   'winter_sun': 48},
#  208338: {'fall': 146,
#   'fall_sun': 394,
#   'summer': 237,
#   'summer_sun': 483,
#   'winter': 55,
#   'winter_sun': 305},
#  196131: {'fall': 101,
#   'fall_sun': 439,
#   'summer': 114,
#   'summer_sun': 606,
#   'winter': 172,
#   'winter_sun': 188},
#  196374: {'fall': 253,
#   'fall_sun': 287,
#   'summer': 298,
#   'summer_sun': 422,
#   'winter': 153,
#   'winter_sun': 207},
#  208463: {'fall': 282,
#   'fall_sun': 258,
#   'summer': 443,
#   'summer_sun': 277,
#   'winter': 134,
#   'winter_sun': 226},
#  201661: {'fall': 172,
#   'fall_sun': 368,
#   'summer': 179,
#   'summer_sun': 541,
#   'winter': 120,
#   'winter_sun': 240},
#  203769: {'fall': 121,
#   'fall_sun': 419,
#   'summer': 167,
#   'summer_sun': 553,
#   'winter': 35,
#   'winter_sun': 325},
#  208456: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 35,
#   'summer_sun': 685,
#   'winter': 67,
#   'winter_sun': 293},
#  209921: {'fall': 219,
#   'fall_sun': 321,
#   'summer': 288,
#   'summer_sun': 432,
#   'winter': 225,
#   'winter_sun': 135},
#  189840: {'fall': 164,
#   'fall_sun': 376,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 313,
#   'winter_sun': 47},
#  203887: {'fall': 180,
#   'fall_sun': 360,
#   'summer': 394,
#   'summer_sun': 326,
#   'winter': 274,
#   'winter_sun': 86},
#  200654: {'fall': 40,
#   'fall_sun': 500,
#   'summer': 80,
#   'summer_sun': 640,
#   'winter': 168,
#   'winter_sun': 192},
#  196440: {'fall': 286,
#   'fall_sun': 254,
#   'summer': 281,
#   'summer_sun': 439,
#   'winter': 242,
#   'winter_sun': 118},
#  204246: {'fall': 93,
#   'fall_sun': 447,
#   'summer': 197,
#   'summer_sun': 523,
#   'winter': 113,
#   'winter_sun': 247},
#  193014: {'fall': 176,
#   'fall_sun': 364,
#   'summer': 199,
#   'summer_sun': 521,
#   'winter': 130,
#   'winter_sun': 230},
#  180707: {'fall': 282,
#   'fall_sun': 258,
#   'summer': 338,
#   'summer_sun': 382,
#   'winter': 128,
#   'winter_sun': 232},
#  198230: {'fall': 5,
#   'fall_sun': 535,
#   'summer': 121,
#   'summer_sun': 599,
#   'winter': 67,
#   'winter_sun': 293},
#  192814: {'fall': 237,
#   'fall_sun': 303,
#   'summer': 351,
#   'summer_sun': 369,
#   'winter': 306,
#   'winter_sun': 54},
#  179828: {'fall': 125,
#   'fall_sun': 415,
#   'summer': 128,
#   'summer_sun': 592,
#   'winter': 117,
#   'winter_sun': 243},
#  196765: {'fall': 3,
#   'fall_sun': 537,
#   'summer': 33,
#   'summer_sun': 687,
#   'winter': 119,
#   'winter_sun': 241},
#  178599: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 37,
#   'summer_sun': 683,
#   'winter': 0,
#   'winter_sun': 360},
#  208229: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 110,
#   'summer_sun': 610,
#   'winter': 125,
#   'winter_sun': 235},
#  189313: {'fall': 160,
#   'fall_sun': 380,
#   'summer': 160,
#   'summer_sun': 560,
#   'winter': 302,
#   'winter_sun': 58},
#  208876: {'fall': 225,
#   'fall_sun': 315,
#   'summer': 282,
#   'summer_sun': 438,
#   'winter': 289,
#   'winter_sun': 71},
#  189570: {'fall': 201,
#   'fall_sun': 339,
#   'summer': 241,
#   'summer_sun': 479,
#   'winter': 340,
#   'winter_sun': 20},
#  170988: {'fall': 1,
#   'fall_sun': 539,
#   'summer': 7,
#   'summer_sun': 713,
#   'winter': 98,
#   'winter_sun': 262},
#  178783: {'fall': 78,
#   'fall_sun': 462,
#   'summer': 192,
#   'summer_sun': 528,
#   'winter': 78,
#   'winter_sun': 282},
#  175693: {'fall': 346,
#   'fall_sun': 194,
#   'summer': 410,
#   'summer_sun': 310,
#   'winter': 293,
#   'winter_sun': 67},
#  190540: {'fall': 309,
#   'fall_sun': 231,
#   'summer': 400,
#   'summer_sun': 320,
#   'winter': 360,
#   'winter_sun': 0},
#  140722: {'fall': 150,
#   'fall_sun': 390,
#   'summer': 347,
#   'summer_sun': 373,
#   'winter': 189,
#   'winter_sun': 171},
#  161235: {'fall': 72,
#   'fall_sun': 468,
#   'summer': 223,
#   'summer_sun': 497,
#   'winter': 46,
#   'winter_sun': 314},
#  161242: {'fall': 275,
#   'fall_sun': 265,
#   'summer': 169,
#   'summer_sun': 551,
#   'winter': 161,
#   'winter_sun': 199},
#  186060: {'fall': 158,
#   'fall_sun': 382,
#   'summer': 275,
#   'summer_sun': 445,
#   'winter': 47,
#   'winter_sun': 313},
#  180891: {'fall': 290,
#   'fall_sun': 250,
#   'summer': 363,
#   'summer_sun': 357,
#   'winter': 218,
#   'winter_sun': 142},
#  183381: {'fall': 52,
#   'fall_sun': 488,
#   'summer': 117,
#   'summer_sun': 603,
#   'winter': 0,
#   'winter_sun': 360},
#  166440: {'fall': 225,
#   'fall_sun': 315,
#   'summer': 116,
#   'summer_sun': 604,
#   'winter': 133,
#   'winter_sun': 227},
#  134320: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 220,
#   'winter_sun': 140},
#  168348: {'fall': 259,
#   'fall_sun': 281,
#   'summer': 325,
#   'summer_sun': 395,
#   'winter': 189,
#   'winter_sun': 171},
#  201658: {'fall': 81,
#   'fall_sun': 459,
#   'summer': 59,
#   'summer_sun': 661,
#   'winter': 77,
#   'winter_sun': 283},
#  204165: {'fall': 68,
#   'fall_sun': 472,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 359,
#   'winter_sun': 1},
#  186817: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 14,
#   'summer_sun': 706,
#   'winter': 0,
#   'winter_sun': 360},
#  198164: {'fall': 132,
#   'fall_sun': 408,
#   'summer': 321,
#   'summer_sun': 399,
#   'winter': 156,
#   'winter_sun': 204},
#  196627: {'fall': 109,
#   'fall_sun': 431,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 198,
#   'winter_sun': 162},
#  208395: {'fall': 7,
#   'fall_sun': 533,
#   'summer': 174,
#   'summer_sun': 546,
#   'winter': 277,
#   'winter_sun': 83},
#  191733: {'fall': 414,
#   'fall_sun': 126,
#   'summer': 354,
#   'summer_sun': 366,
#   'winter': 360,
#   'winter_sun': 0},
#  209913: {'fall': 256,
#   'fall_sun': 284,
#   'summer': 290,
#   'summer_sun': 430,
#   'winter': 173,
#   'winter_sun': 187},
#  194656: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 83,
#   'summer_sun': 637,
#   'winter': 0,
#   'winter_sun': 360},
#  192702: {'fall': 88,
#   'fall_sun': 452,
#   'summer': 108,
#   'summer_sun': 612,
#   'winter': 71,
#   'winter_sun': 289},
#  191162: {'fall': 451,
#   'fall_sun': 89,
#   'summer': 365,
#   'summer_sun': 355,
#   'winter': 360,
#   'winter_sun': 0},
#  191248: {'fall': 143,
#   'fall_sun': 397,
#   'summer': 183,
#   'summer_sun': 537,
#   'winter': 157,
#   'winter_sun': 203},
#  189708: {'fall': 251,
#   'fall_sun': 289,
#   'summer': 190,
#   'summer_sun': 530,
#   'winter': 360,
#   'winter_sun': 0},
#  201682: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 30,
#   'summer_sun': 690,
#   'winter': 145,
#   'winter_sun': 215},
#  195151: {'fall': 145,
#   'fall_sun': 395,
#   'summer': 191,
#   'summer_sun': 529,
#   'winter': 72,
#   'winter_sun': 288},
#  173925: {'fall': 213,
#   'fall_sun': 327,
#   'summer': 160,
#   'summer_sun': 560,
#   'winter': 230,
#   'winter_sun': 130},
#  178756: {'fall': 460,
#   'fall_sun': 80,
#   'summer': 468,
#   'summer_sun': 252,
#   'winter': 360,
#   'winter_sun': 0},
#  163280: {'fall': 334,
#   'fall_sun': 206,
#   'summer': 462,
#   'summer_sun': 258,
#   'winter': 285,
#   'winter_sun': 75},
#  190420: {'fall': 476,
#   'fall_sun': 64,
#   'summer': 645,
#   'summer_sun': 75,
#   'winter': 360,
#   'winter_sun': 0},
#  190154: {'fall': 387,
#   'fall_sun': 153,
#   'summer': 381,
#   'summer_sun': 339,
#   'winter': 359,
#   'winter_sun': 1},
#  191273: {'fall': 390,
#   'fall_sun': 150,
#   'summer': 305,
#   'summer_sun': 415,
#   'winter': 360,
#   'winter_sun': 0},
#  178435: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 59,
#   'summer_sun': 661,
#   'winter': 360,
#   'winter_sun': 0},
#  180307: {'fall': 172,
#   'fall_sun': 368,
#   'summer': 275,
#   'summer_sun': 445,
#   'winter': 132,
#   'winter_sun': 228},
#  179475: {'fall': 107,
#   'fall_sun': 433,
#   'summer': 168,
#   'summer_sun': 552,
#   'winter': 283,
#   'winter_sun': 77},
#  189401: {'fall': 298,
#   'fall_sun': 242,
#   'summer': 346,
#   'summer_sun': 374,
#   'winter': 121,
#   'winter_sun': 239},
#  176850: {'fall': 219,
#   'fall_sun': 321,
#   'summer': 295,
#   'summer_sun': 425,
#   'winter': 118,
#   'winter_sun': 242},
#  191197: {'fall': 57,
#   'fall_sun': 483,
#   'summer': 95,
#   'summer_sun': 625,
#   'winter': 76,
#   'winter_sun': 284},
#  183942: {'fall': 301,
#   'fall_sun': 239,
#   'summer': 418,
#   'summer_sun': 302,
#   'winter': 221,
#   'winter_sun': 139},
#  178779: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 27,
#   'summer_sun': 693,
#   'winter': 255,
#   'winter_sun': 105},
#  189593: {'fall': 369,
#   'fall_sun': 171,
#   'summer': 416,
#   'summer_sun': 304,
#   'winter': 294,
#   'winter_sun': 66},
#  200590: {'fall': 59,
#   'fall_sun': 481,
#   'summer': 167,
#   'summer_sun': 553,
#   'winter': 115,
#   'winter_sun': 245},
#  200604: {'fall': 414,
#   'fall_sun': 126,
#   'summer': 412,
#   'summer_sun': 308,
#   'winter': 360,
#   'winter_sun': 0},
#  180266: {'fall': 382,
#   'fall_sun': 158,
#   'summer': 354,
#   'summer_sun': 366,
#   'winter': 310,
#   'winter_sun': 50},
#  206337: {'fall': 115,
#   'fall_sun': 425,
#   'summer': 134,
#   'summer_sun': 586,
#   'winter': 229,
#   'winter_sun': 131},
#  206338: {'fall': 163,
#   'fall_sun': 377,
#   'summer': 131,
#   'summer_sun': 589,
#   'winter': 218,
#   'winter_sun': 142},
#  190393: {'fall': 340,
#   'fall_sun': 200,
#   'summer': 475,
#   'summer_sun': 245,
#   'winter': 357,
#   'winter_sun': 3},
#  201558: {'fall': 422,
#   'fall_sun': 118,
#   'summer': 408,
#   'summer_sun': 312,
#   'winter': 360,
#   'winter_sun': 0},
#  205787: {'fall': 492,
#   'fall_sun': 48,
#   'summer': 542,
#   'summer_sun': 178,
#   'winter': 360,
#   'winter_sun': 0},
#  205970: {'fall': 29,
#   'fall_sun': 511,
#   'summer': 90,
#   'summer_sun': 630,
#   'winter': 171,
#   'winter_sun': 189},
#  179537: {'fall': 131,
#   'fall_sun': 409,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 357,
#   'winter_sun': 3},
#  196492: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 73,
#   'winter_sun': 287},
#  179476: {'fall': 190,
#   'fall_sun': 350,
#   'summer': 166,
#   'summer_sun': 554,
#   'winter': 298,
#   'winter_sun': 62},
#  189590: {'fall': 381,
#   'fall_sun': 159,
#   'summer': 487,
#   'summer_sun': 233,
#   'winter': 275,
#   'winter_sun': 85},
#  191351: {'fall': 181,
#   'fall_sun': 359,
#   'summer': 215,
#   'summer_sun': 505,
#   'winter': 122,
#   'winter_sun': 238},
#  208767: {'fall': 260,
#   'fall_sun': 280,
#   'summer': 436,
#   'summer_sun': 284,
#   'winter': 164,
#   'winter_sun': 196},
#  205734: {'fall': 297,
#   'fall_sun': 243,
#   'summer': 154,
#   'summer_sun': 566,
#   'winter': 340,
#   'winter_sun': 20},
#  201486: {'fall': 250,
#   'fall_sun': 290,
#   'summer': 179,
#   'summer_sun': 541,
#   'winter': 189,
#   'winter_sun': 171},
#  203326: {'fall': 335,
#   'fall_sun': 205,
#   'summer': 482,
#   'summer_sun': 238,
#   'winter': 194,
#   'winter_sun': 166},
#  179994: {'fall': 242,
#   'fall_sun': 298,
#   'summer': 333,
#   'summer_sun': 387,
#   'winter': 195,
#   'winter_sun': 165},
#  178583: {'fall': 288,
#   'fall_sun': 252,
#   'summer': 419,
#   'summer_sun': 301,
#   'winter': 135,
#   'winter_sun': 225},
#  187232: {'fall': 319,
#   'fall_sun': 221,
#   'summer': 379,
#   'summer_sun': 341,
#   'winter': 287,
#   'winter_sun': 73},
#  179887: {'fall': 452,
#   'fall_sun': 88,
#   'summer': 379,
#   'summer_sun': 341,
#   'winter': 360,
#   'winter_sun': 0},
#  200381: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 30,
#   'summer_sun': 690,
#   'winter': 0,
#   'winter_sun': 360},
#  198290: {'fall': 219,
#   'fall_sun': 321,
#   'summer': 204,
#   'summer_sun': 516,
#   'winter': 136,
#   'winter_sun': 224},
#  190087: {'fall': 370,
#   'fall_sun': 170,
#   'summer': 212,
#   'summer_sun': 508,
#   'winter': 360,
#   'winter_sun': 0},
#  190421: {'fall': 474,
#   'fall_sun': 66,
#   'summer': 596,
#   'summer_sun': 124,
#   'winter': 360,
#   'winter_sun': 0},
#  181446: {'fall': 78,
#   'fall_sun': 462,
#   'summer': 189,
#   'summer_sun': 531,
#   'winter': 97,
#   'winter_sun': 263},
#  199062: {'fall': 423,
#   'fall_sun': 117,
#   'summer': 398,
#   'summer_sun': 322,
#   'winter': 277,
#   'winter_sun': 83},
#  200398: {'fall': 61,
#   'fall_sun': 479,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 0,
#   'winter_sun': 360},
#  179942: {'fall': 39,
#   'fall_sun': 501,
#   'summer': 130,
#   'summer_sun': 590,
#   'winter': 359,
#   'winter_sun': 1},
#  189351: {'fall': 358,
#   'fall_sun': 182,
#   'summer': 323,
#   'summer_sun': 397,
#   'winter': 360,
#   'winter_sun': 0},
#  196020: {'fall': 394,
#   'fall_sun': 146,
#   'summer': 526,
#   'summer_sun': 194,
#   'winter': 294,
#   'winter_sun': 66},
#  205829: {'fall': 205,
#   'fall_sun': 335,
#   'summer': 268,
#   'summer_sun': 452,
#   'winter': 87,
#   'winter_sun': 273},
#  208820: {'fall': 314,
#   'fall_sun': 226,
#   'summer': 309,
#   'summer_sun': 411,
#   'winter': 360,
#   'winter_sun': 0},
#  178606: {'fall': 321,
#   'fall_sun': 219,
#   'summer': 433,
#   'summer_sun': 287,
#   'winter': 312,
#   'winter_sun': 48},
#  200673: {'fall': 211,
#   'fall_sun': 329,
#   'summer': 249,
#   'summer_sun': 471,
#   'winter': 146,
#   'winter_sun': 214},
#  186501: {'fall': 206,
#   'fall_sun': 334,
#   'summer': 400,
#   'summer_sun': 320,
#   'winter': 51,
#   'winter_sun': 309},
#  197897: {'fall': 408,
#   'fall_sun': 132,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 359,
#   'winter_sun': 1},
#  199051: {'fall': 434,
#   'fall_sun': 106,
#   'summer': 428,
#   'summer_sun': 292,
#   'winter': 265,
#   'winter_sun': 95},
#  200406: {'fall': 2,
#   'fall_sun': 538,
#   'summer': 57,
#   'summer_sun': 663,
#   'winter': 0,
#   'winter_sun': 360},
#  189459: {'fall': 293,
#   'fall_sun': 247,
#   'summer': 367,
#   'summer_sun': 353,
#   'winter': 226,
#   'winter_sun': 134},
#  189460: {'fall': 78,
#   'fall_sun': 462,
#   'summer': 214,
#   'summer_sun': 506,
#   'winter': 228,
#   'winter_sun': 132},
#  189709: {'fall': 226,
#   'fall_sun': 314,
#   'summer': 151,
#   'summer_sun': 569,
#   'winter': 360,
#   'winter_sun': 0},
#  208761: {'fall': 191,
#   'fall_sun': 349,
#   'summer': 199,
#   'summer_sun': 521,
#   'winter': 319,
#   'winter_sun': 41},
#  190395: {'fall': 412,
#   'fall_sun': 128,
#   'summer': 545,
#   'summer_sun': 175,
#   'winter': 316,
#   'winter_sun': 44},
#  187234: {'fall': 318,
#   'fall_sun': 222,
#   'summer': 372,
#   'summer_sun': 348,
#   'winter': 282,
#   'winter_sun': 78},
#  205785: {'fall': 498,
#   'fall_sun': 42,
#   'summer': 562,
#   'summer_sun': 158,
#   'winter': 360,
#   'winter_sun': 0},
#  201410: {'fall': 290,
#   'fall_sun': 250,
#   'summer': 408,
#   'summer_sun': 312,
#   'winter': 240,
#   'winter_sun': 120},
#  208760: {'fall': 378,
#   'fall_sun': 162,
#   'summer': 365,
#   'summer_sun': 355,
#   'winter': 354,
#   'winter_sun': 6},
#  208763: {'fall': 222,
#   'fall_sun': 318,
#   'summer': 188,
#   'summer_sun': 532,
#   'winter': 352,
#   'winter_sun': 8},
#  189626: {'fall': 288,
#   'fall_sun': 252,
#   'summer': 476,
#   'summer_sun': 244,
#   'winter': 255,
#   'winter_sun': 105},
#  190394: {'fall': 380,
#   'fall_sun': 160,
#   'summer': 538,
#   'summer_sun': 182,
#   'winter': 334,
#   'winter_sun': 26},
#  200471: {'fall': 492,
#   'fall_sun': 48,
#   'summer': 616,
#   'summer_sun': 104,
#   'winter': 360,
#   'winter_sun': 0},
#  179834: {'fall': 82,
#   'fall_sun': 458,
#   'summer': 104,
#   'summer_sun': 616,
#   'winter': 95,
#   'winter_sun': 265},
#  180251: {'fall': 393,
#   'fall_sun': 147,
#   'summer': 398,
#   'summer_sun': 322,
#   'winter': 360,
#   'winter_sun': 0},
#  209063: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 33,
#   'summer_sun': 687,
#   'winter': 99,
#   'winter_sun': 261},
#  201590: {'fall': 1,
#   'fall_sun': 539,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 60,
#   'winter_sun': 300},
#  187054: {'fall': 369,
#   'fall_sun': 171,
#   'summer': 460,
#   'summer_sun': 260,
#   'winter': 360,
#   'winter_sun': 0},
#  201811: {'fall': 83,
#   'fall_sun': 457,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 33,
#   'winter_sun': 327},
#  208863: {'fall': 110,
#   'fall_sun': 430,
#   'summer': 186,
#   'summer_sun': 534,
#   'winter': 47,
#   'winter_sun': 313},
#  195995: {'fall': 499,
#   'fall_sun': 41,
#   'summer': 613,
#   'summer_sun': 107,
#   'winter': 360,
#   'winter_sun': 0},
#  190386: {'fall': 299,
#   'fall_sun': 241,
#   'summer': 458,
#   'summer_sun': 262,
#   'winter': 290,
#   'winter_sun': 70},
#  208819: {'fall': 367,
#   'fall_sun': 173,
#   'summer': 306,
#   'summer_sun': 414,
#   'winter': 360,
#   'winter_sun': 0},
#  200697: {'fall': 247,
#   'fall_sun': 293,
#   'summer': 311,
#   'summer_sun': 409,
#   'winter': 203,
#   'winter_sun': 157},
#  189599: {'fall': 107,
#   'fall_sun': 433,
#   'summer': 253,
#   'summer_sun': 467,
#   'winter': 27,
#   'winter_sun': 333},
#  187229: {'fall': 492,
#   'fall_sun': 48,
#   'summer': 521,
#   'summer_sun': 199,
#   'winter': 325,
#   'winter_sun': 35},
#  192892: {'fall': 153,
#   'fall_sun': 387,
#   'summer': 263,
#   'summer_sun': 457,
#   'winter': 89,
#   'winter_sun': 271},
#  206381: {'fall': 272,
#   'fall_sun': 268,
#   'summer': 518,
#   'summer_sun': 202,
#   'winter': 292,
#   'winter_sun': 68},
#  187061: {'fall': 286,
#   'fall_sun': 254,
#   'summer': 530,
#   'summer_sun': 190,
#   'winter': 251,
#   'winter_sun': 109},
#  189365: {'fall': 240,
#   'fall_sun': 300,
#   'summer': 147,
#   'summer_sun': 573,
#   'winter': 360,
#   'winter_sun': 0},
#  161340: {'fall': 220,
#   'fall_sun': 320,
#   'summer': 89,
#   'summer_sun': 631,
#   'winter': 219,
#   'winter_sun': 141},
#  204224: {'fall': 483,
#   'fall_sun': 57,
#   'summer': 336,
#   'summer_sun': 384,
#   'winter': 360,
#   'winter_sun': 0},
#  190435: {'fall': 489,
#   'fall_sun': 51,
#   'summer': 561,
#   'summer_sun': 159,
#   'winter': 360,
#   'winter_sun': 0},
#  193092: {'fall': 105,
#   'fall_sun': 435,
#   'summer': 128,
#   'summer_sun': 592,
#   'winter': 243,
#   'winter_sun': 117},
#  209331: {'fall': 191,
#   'fall_sun': 349,
#   'summer': 320,
#   'summer_sun': 400,
#   'winter': 298,
#   'winter_sun': 62},
#  200439: {'fall': 539,
#   'fall_sun': 1,
#   'summer': 469,
#   'summer_sun': 251,
#   'winter': 360,
#   'winter_sun': 0},
#  180252: {'fall': 402,
#   'fall_sun': 138,
#   'summer': 392,
#   'summer_sun': 328,
#   'winter': 360,
#   'winter_sun': 0},
#  180434: {'fall': 103,
#   'fall_sun': 437,
#   'summer': 48,
#   'summer_sun': 672,
#   'winter': 77,
#   'winter_sun': 283},
#  209045: {'fall': 268,
#   'fall_sun': 272,
#   'summer': 306,
#   'summer_sun': 414,
#   'winter': 291,
#   'winter_sun': 69},
#  201593: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 0,
#   'winter_sun': 360},
#  193069: {'fall': 90,
#   'fall_sun': 450,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 232,
#   'winter_sun': 128},
#  189243: {'fall': 390,
#   'fall_sun': 150,
#   'summer': 358,
#   'summer_sun': 362,
#   'winter': 360,
#   'winter_sun': 0},
#  180516: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 77,
#   'summer_sun': 643,
#   'winter': 257,
#   'winter_sun': 103},
#  208860: {'fall': 112,
#   'fall_sun': 428,
#   'summer': 133,
#   'summer_sun': 587,
#   'winter': 45,
#   'winter_sun': 315},
#  204033: {'fall': 192,
#   'fall_sun': 348,
#   'summer': 343,
#   'summer_sun': 377,
#   'winter': 168,
#   'winter_sun': 192},
#  208410: {'fall': 173,
#   'fall_sun': 367,
#   'summer': 242,
#   'summer_sun': 478,
#   'winter': 111,
#   'winter_sun': 249},
#  170023: {'fall': 409,
#   'fall_sun': 131,
#   'summer': 303,
#   'summer_sun': 417,
#   'winter': 359,
#   'winter_sun': 1},
#  189583: {'fall': 66,
#   'fall_sun': 474,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 100,
#   'winter_sun': 260},
#  189500: {'fall': 242,
#   'fall_sun': 298,
#   'summer': 134,
#   'summer_sun': 586,
#   'winter': 360,
#   'winter_sun': 0},
#  189902: {'fall': 315,
#   'fall_sun': 225,
#   'summer': 420,
#   'summer_sun': 300,
#   'winter': 252,
#   'winter_sun': 108},
#  187294: {'fall': 225,
#   'fall_sun': 315,
#   'summer': 350,
#   'summer_sun': 370,
#   'winter': 161,
#   'winter_sun': 199},
#  192893: {'fall': 2,
#   'fall_sun': 538,
#   'summer': 157,
#   'summer_sun': 563,
#   'winter': 0,
#   'winter_sun': 360},
#  206382: {'fall': 313,
#   'fall_sun': 227,
#   'summer': 520,
#   'summer_sun': 200,
#   'winter': 287,
#   'winter_sun': 73},
#  189249: {'fall': 428,
#   'fall_sun': 112,
#   'summer': 344,
#   'summer_sun': 376,
#   'winter': 360,
#   'winter_sun': 0},
#  189251: {'fall': 452,
#   'fall_sun': 88,
#   'summer': 493,
#   'summer_sun': 227,
#   'winter': 354,
#   'winter_sun': 6},
#  201817: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 299,
#   'winter_sun': 61},
#  201819: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 292,
#   'winter_sun': 68},
#  204025: {'fall': 223,
#   'fall_sun': 317,
#   'summer': 335,
#   'summer_sun': 385,
#   'winter': 57,
#   'winter_sun': 303},
#  193395: {'fall': 356,
#   'fall_sun': 184,
#   'summer': 448,
#   'summer_sun': 272,
#   'winter': 225,
#   'winter_sun': 135},
#  210541: {'fall': 59,
#   'fall_sun': 481,
#   'summer': 158,
#   'summer_sun': 562,
#   'winter': 270,
#   'winter_sun': 90},
#  184749: {'fall': 381,
#   'fall_sun': 159,
#   'summer': 380,
#   'summer_sun': 340,
#   'winter': 360,
#   'winter_sun': 0},
#  185678: {'fall': 432,
#   'fall_sun': 108,
#   'summer': 435,
#   'summer_sun': 285,
#   'winter': 360,
#   'winter_sun': 0},
#  182059: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 59,
#   'summer_sun': 661,
#   'winter': 297,
#   'winter_sun': 63},
#  182170: {'fall': 65,
#   'fall_sun': 475,
#   'summer': 172,
#   'summer_sun': 548,
#   'winter': 64,
#   'winter_sun': 296},
#  161371: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 83,
#   'summer_sun': 637,
#   'winter': 0,
#   'winter_sun': 360},
#  195488: {'fall': 91,
#   'fall_sun': 449,
#   'summer': 82,
#   'summer_sun': 638,
#   'winter': 21,
#   'winter_sun': 339},
#  184924: {'fall': 325,
#   'fall_sun': 215,
#   'summer': 515,
#   'summer_sun': 205,
#   'winter': 227,
#   'winter_sun': 133},
#  192294: {'fall': 108,
#   'fall_sun': 432,
#   'summer': 182,
#   'summer_sun': 538,
#   'winter': 158,
#   'winter_sun': 202},
#  188761: {'fall': 97,
#   'fall_sun': 443,
#   'summer': 196,
#   'summer_sun': 524,
#   'winter': 89,
#   'winter_sun': 271},
#  189940: {'fall': 77,
#   'fall_sun': 463,
#   'summer': 154,
#   'summer_sun': 566,
#   'winter': 65,
#   'winter_sun': 295},
#  163875: {'fall': 2,
#   'fall_sun': 538,
#   'summer': 305,
#   'summer_sun': 415,
#   'winter': 0,
#   'winter_sun': 360},
#  171588: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 9,
#   'summer_sun': 711,
#   'winter': 1,
#   'winter_sun': 359},
#  181473: {'fall': 279,
#   'fall_sun': 261,
#   'summer': 242,
#   'summer_sun': 478,
#   'winter': 360,
#   'winter_sun': 0},
#  179494: {'fall': 21,
#   'fall_sun': 519,
#   'summer': 15,
#   'summer_sun': 705,
#   'winter': 87,
#   'winter_sun': 273},
#  179651: {'fall': 119,
#   'fall_sun': 421,
#   'summer': 49,
#   'summer_sun': 671,
#   'winter': 91,
#   'winter_sun': 269},
#  188661: {'fall': 173,
#   'fall_sun': 367,
#   'summer': 135,
#   'summer_sun': 585,
#   'winter': 2,
#   'winter_sun': 358},
#  188386: {'fall': 140,
#   'fall_sun': 400,
#   'summer': 49,
#   'summer_sun': 671,
#   'winter': 0,
#   'winter_sun': 360},
#  192037: {'fall': 105,
#   'fall_sun': 435,
#   'summer': 9,
#   'summer_sun': 711,
#   'winter': 360,
#   'winter_sun': 0},
#  190115: {'fall': 473,
#   'fall_sun': 67,
#   'summer': 531,
#   'summer_sun': 189,
#   'winter': 360,
#   'winter_sun': 0},
#  119244: {'fall': 33,
#   'fall_sun': 507,
#   'summer': 102,
#   'summer_sun': 618,
#   'winter': 0,
#   'winter_sun': 360},
#  121659: {'fall': 21,
#   'fall_sun': 519,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 358,
#   'winter_sun': 2},
#  143237: {'fall': 213,
#   'fall_sun': 327,
#   'summer': 42,
#   'summer_sun': 678,
#   'winter': 331,
#   'winter_sun': 29},
#  132105: {'fall': 205,
#   'fall_sun': 335,
#   'summer': 267,
#   'summer_sun': 453,
#   'winter': 138,
#   'winter_sun': 222},
#  118769: {'fall': 64,
#   'fall_sun': 476,
#   'summer': 213,
#   'summer_sun': 507,
#   'winter': 305,
#   'winter_sun': 55},
#  151575: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 39,
#   'winter_sun': 321},
#  143026: {'fall': 312,
#   'fall_sun': 228,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 360,
#   'winter_sun': 0},
#  165029: {'fall': 98,
#   'fall_sun': 442,
#   'summer': 124,
#   'summer_sun': 596,
#   'winter': 3,
#   'winter_sun': 357},
#  157920: {'fall': 225,
#   'fall_sun': 315,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 360,
#   'winter_sun': 0},
#  131562: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 71,
#   'summer_sun': 649,
#   'winter': 65,
#   'winter_sun': 295},
#  153022: {'fall': 58,
#   'fall_sun': 482,
#   'summer': 147,
#   'summer_sun': 573,
#   'winter': 235,
#   'winter_sun': 125},
#  162964: {'fall': 57,
#   'fall_sun': 483,
#   'summer': 148,
#   'summer_sun': 572,
#   'winter': 31,
#   'winter_sun': 329},
#  159649: {'fall': 8,
#   'fall_sun': 532,
#   'summer': 28,
#   'summer_sun': 692,
#   'winter': 291,
#   'winter_sun': 69},
#  164329: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 22,
#   'summer_sun': 698,
#   'winter': 0,
#   'winter_sun': 360},
#  176111: {'fall': 301,
#   'fall_sun': 239,
#   'summer': 437,
#   'summer_sun': 283,
#   'winter': 228,
#   'winter_sun': 132},
#  178894: {'fall': 360,
#   'fall_sun': 180,
#   'summer': 323,
#   'summer_sun': 397,
#   'winter': 360,
#   'winter_sun': 0},
#  162178: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 5,
#   'summer_sun': 715,
#   'winter': 55,
#   'winter_sun': 305},
#  73302: {'fall': 178,
#   'fall_sun': 362,
#   'summer': 251,
#   'summer_sun': 469,
#   'winter': 119,
#   'winter_sun': 241},
#  191083: {'fall': 186,
#   'fall_sun': 354,
#   'summer': 129,
#   'summer_sun': 591,
#   'winter': 259,
#   'winter_sun': 101},
#  163225: {'fall': 350,
#   'fall_sun': 190,
#   'summer': 369,
#   'summer_sun': 351,
#   'winter': 307,
#   'winter_sun': 53},
#  184448: {'fall': 101,
#   'fall_sun': 439,
#   'summer': 313,
#   'summer_sun': 407,
#   'winter': 127,
#   'winter_sun': 233},
#  203468: {'fall': 49,
#   'fall_sun': 491,
#   'summer': 117,
#   'summer_sun': 603,
#   'winter': 91,
#   'winter_sun': 269},
#  183939: {'fall': 234,
#   'fall_sun': 306,
#   'summer': 317,
#   'summer_sun': 403,
#   'winter': 236,
#   'winter_sun': 124},
#  183941: {'fall': 323,
#   'fall_sun': 217,
#   'summer': 409,
#   'summer_sun': 311,
#   'winter': 183,
#   'winter_sun': 177},
#  191268: {'fall': 275,
#   'fall_sun': 265,
#   'summer': 435,
#   'summer_sun': 285,
#   'winter': 337,
#   'winter_sun': 23},
#  201655: {'fall': 383,
#   'fall_sun': 157,
#   'summer': 331,
#   'summer_sun': 389,
#   'winter': 209,
#   'winter_sun': 151},
#  189587: {'fall': 362,
#   'fall_sun': 178,
#   'summer': 337,
#   'summer_sun': 383,
#   'winter': 277,
#   'winter_sun': 83},
#  180306: {'fall': 198,
#   'fall_sun': 342,
#   'summer': 259,
#   'summer_sun': 461,
#   'winter': 150,
#   'winter_sun': 210},
#  198018: {'fall': 489,
#   'fall_sun': 51,
#   'summer': 609,
#   'summer_sun': 111,
#   'winter': 309,
#   'winter_sun': 51},
#  198020: {'fall': 485,
#   'fall_sun': 55,
#   'summer': 596,
#   'summer_sun': 124,
#   'winter': 310,
#   'winter_sun': 50},
#  164685: {'fall': 244,
#   'fall_sun': 296,
#   'summer': 332,
#   'summer_sun': 388,
#   'winter': 157,
#   'winter_sun': 203},
#  170671: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 147,
#   'summer_sun': 573,
#   'winter': 0,
#   'winter_sun': 360},
#  162756: {'fall': 89,
#   'fall_sun': 451,
#   'summer': 198,
#   'summer_sun': 522,
#   'winter': 206,
#   'winter_sun': 154},
#  179127: {'fall': 52,
#   'fall_sun': 488,
#   'summer': 49,
#   'summer_sun': 671,
#   'winter': 93,
#   'winter_sun': 267},
#  172273: {'fall': 253,
#   'fall_sun': 287,
#   'summer': 354,
#   'summer_sun': 366,
#   'winter': 48,
#   'winter_sun': 312},
#  186754: {'fall': 169,
#   'fall_sun': 371,
#   'summer': 209,
#   'summer_sun': 511,
#   'winter': 70,
#   'winter_sun': 290},
#  178264: {'fall': 307,
#   'fall_sun': 233,
#   'summer': 364,
#   'summer_sun': 356,
#   'winter': 359,
#   'winter_sun': 1},
#  178434: {'fall': 137,
#   'fall_sun': 403,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 187,
#   'winter_sun': 173},
#  164151: {'fall': 479,
#   'fall_sun': 61,
#   'summer': 333,
#   'summer_sun': 387,
#   'winter': 350,
#   'winter_sun': 10},
#  179202: {'fall': 464,
#   'fall_sun': 76,
#   'summer': 459,
#   'summer_sun': 261,
#   'winter': 360,
#   'winter_sun': 0},
#  175792: {'fall': 159,
#   'fall_sun': 381,
#   'summer': 252,
#   'summer_sun': 468,
#   'winter': 48,
#   'winter_sun': 312},
#  175281: {'fall': 486,
#   'fall_sun': 54,
#   'summer': 360,
#   'summer_sun': 360,
#   'winter': 360,
#   'winter_sun': 0},
#  155427: {'fall': 328,
#   'fall_sun': 212,
#   'summer': 393,
#   'summer_sun': 327,
#   'winter': 143,
#   'winter_sun': 217},
#  176428: {'fall': 196,
#   'fall_sun': 344,
#   'summer': 87,
#   'summer_sun': 633,
#   'winter': 359,
#   'winter_sun': 1},
#  172782: {'fall': 265,
#   'fall_sun': 275,
#   'summer': 258,
#   'summer_sun': 462,
#   'winter': 133,
#   'winter_sun': 227},
#  157533: {'fall': 164,
#   'fall_sun': 376,
#   'summer': 134,
#   'summer_sun': 586,
#   'winter': 156,
#   'winter_sun': 204},
#  198291: {'fall': 450,
#   'fall_sun': 90,
#   'summer': 334,
#   'summer_sun': 386,
#   'winter': 360,
#   'winter_sun': 0},
#  200363: {'fall': 488,
#   'fall_sun': 52,
#   'summer': 613,
#   'summer_sun': 107,
#   'winter': 360,
#   'winter_sun': 0},
#  183936: {'fall': 294,
#   'fall_sun': 246,
#   'summer': 311,
#   'summer_sun': 409,
#   'winter': 233,
#   'winter_sun': 127},
#  203805: {'fall': 461,
#   'fall_sun': 79,
#   'summer': 571,
#   'summer_sun': 149,
#   'winter': 360,
#   'winter_sun': 0},
#  204158: {'fall': 439,
#   'fall_sun': 101,
#   'summer': 488,
#   'summer_sun': 232,
#   'winter': 360,
#   'winter_sun': 0},
#  208787: {'fall': 458,
#   'fall_sun': 82,
#   'summer': 509,
#   'summer_sun': 211,
#   'winter': 360,
#   'winter_sun': 0},
#  189469: {'fall': 222,
#   'fall_sun': 318,
#   'summer': 286,
#   'summer_sun': 434,
#   'winter': 269,
#   'winter_sun': 91},
#  189618: {'fall': 171,
#   'fall_sun': 369,
#   'summer': 412,
#   'summer_sun': 308,
#   'winter': 66,
#   'winter_sun': 294},
#  205830: {'fall': 118,
#   'fall_sun': 422,
#   'summer': 213,
#   'summer_sun': 507,
#   'winter': 54,
#   'winter_sun': 306},
#  184319: {'fall': 75,
#   'fall_sun': 465,
#   'summer': 129,
#   'summer_sun': 591,
#   'winter': 8,
#   'winter_sun': 352},
#  184168: {'fall': 257,
#   'fall_sun': 283,
#   'summer': 458,
#   'summer_sun': 262,
#   'winter': 359,
#   'winter_sun': 1},
#  155673: {'fall': 475,
#   'fall_sun': 65,
#   'summer': 543,
#   'summer_sun': 177,
#   'winter': 360,
#   'winter_sun': 0},
#  201933: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 31,
#   'summer_sun': 689,
#   'winter': 0,
#   'winter_sun': 360},
#  208457: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 35,
#   'summer_sun': 685,
#   'winter': 6,
#   'winter_sun': 354},
#  208555: {'fall': 41,
#   'fall_sun': 499,
#   'summer': 82,
#   'summer_sun': 638,
#   'winter': 143,
#   'winter_sun': 217},
#  208866: {'fall': 140,
#   'fall_sun': 400,
#   'summer': 180,
#   'summer_sun': 540,
#   'winter': 67,
#   'winter_sun': 293},
#  163101: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 245,
#   'winter_sun': 115},
#  175099: {'fall': 6,
#   'fall_sun': 534,
#   'summer': 109,
#   'summer_sun': 611,
#   'winter': 222,
#   'winter_sun': 138},
#  135634: {'fall': 10,
#   'fall_sun': 530,
#   'summer': 55,
#   'summer_sun': 665,
#   'winter': 111,
#   'winter_sun': 249},
#  147189: {'fall': 123,
#   'fall_sun': 417,
#   'summer': 176,
#   'summer_sun': 544,
#   'winter': 20,
#   'winter_sun': 340},
#  166718: {'fall': 77,
#   'fall_sun': 463,
#   'summer': 83,
#   'summer_sun': 637,
#   'winter': 36,
#   'winter_sun': 324},
#  138199: {'fall': 14,
#   'fall_sun': 526,
#   'summer': 70,
#   'summer_sun': 650,
#   'winter': 360,
#   'winter_sun': 0},
#  166477: {'fall': 169,
#   'fall_sun': 371,
#   'summer': 132,
#   'summer_sun': 588,
#   'winter': 164,
#   'winter_sun': 196},
#  178550: {'fall': 75,
#   'fall_sun': 465,
#   'summer': 185,
#   'summer_sun': 535,
#   'winter': 127,
#   'winter_sun': 233},
#  185627: {'fall': 155,
#   'fall_sun': 385,
#   'summer': 173,
#   'summer_sun': 547,
#   'winter': 81,
#   'winter_sun': 279},
#  185670: {'fall': 257,
#   'fall_sun': 283,
#   'summer': 184,
#   'summer_sun': 536,
#   'winter': 191,
#   'winter_sun': 169},
#  183686: {'fall': 46,
#   'fall_sun': 494,
#   'summer': 98,
#   'summer_sun': 622,
#   'winter': 163,
#   'winter_sun': 197},
#  192223: {'fall': 116,
#   'fall_sun': 424,
#   'summer': 190,
#   'summer_sun': 530,
#   'winter': 129,
#   'winter_sun': 231},
#  178385: {'fall': 173,
#   'fall_sun': 367,
#   'summer': 293,
#   'summer_sun': 427,
#   'winter': 252,
#   'winter_sun': 108},
#  178387: {'fall': 74,
#   'fall_sun': 466,
#   'summer': 218,
#   'summer_sun': 502,
#   'winter': 360,
#   'winter_sun': 0},
#  186324: {'fall': 329,
#   'fall_sun': 211,
#   'summer': 319,
#   'summer_sun': 401,
#   'winter': 269,
#   'winter_sun': 91},
#  191989: {'fall': 213,
#   'fall_sun': 327,
#   'summer': 164,
#   'summer_sun': 556,
#   'winter': 355,
#   'winter_sun': 5},
#  203721: {'fall': 244,
#   'fall_sun': 296,
#   'summer': 166,
#   'summer_sun': 554,
#   'winter': 207,
#   'winter_sun': 153},
#  189332: {'fall': 254,
#   'fall_sun': 286,
#   'summer': 371,
#   'summer_sun': 349,
#   'winter': 176,
#   'winter_sun': 184},
#  198109: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 27,
#   'summer_sun': 693,
#   'winter': 0,
#   'winter_sun': 360},
#  209105: {'fall': 192,
#   'fall_sun': 348,
#   'summer': 318,
#   'summer_sun': 402,
#   'winter': 145,
#   'winter_sun': 215},
#  189551: {'fall': 242,
#   'fall_sun': 298,
#   'summer': 296,
#   'summer_sun': 424,
#   'winter': 195,
#   'winter_sun': 165},
#  208371: {'fall': 187,
#   'fall_sun': 353,
#   'summer': 217,
#   'summer_sun': 503,
#   'winter': 239,
#   'winter_sun': 121},
#  177285: {'fall': 192,
#   'fall_sun': 348,
#   'summer': 270,
#   'summer_sun': 450,
#   'winter': 108,
#   'winter_sun': 252},
#  191378: {'fall': 211,
#   'fall_sun': 329,
#   'summer': 435,
#   'summer_sun': 285,
#   'winter': 360,
#   'winter_sun': 0},
#  146736: {'fall': 156,
#   'fall_sun': 384,
#   'summer': 135,
#   'summer_sun': 585,
#   'winter': 187,
#   'winter_sun': 173},
#  147983: {'fall': 200,
#   'fall_sun': 340,
#   'summer': 389,
#   'summer_sun': 331,
#   'winter': 101,
#   'winter_sun': 259},
#  133750: {'fall': 73,
#   'fall_sun': 467,
#   'summer': 22,
#   'summer_sun': 698,
#   'winter': 26,
#   'winter_sun': 334},
#  172058: {'fall': 98,
#   'fall_sun': 442,
#   'summer': 238,
#   'summer_sun': 482,
#   'winter': 54,
#   'winter_sun': 306},
#  175959: {'fall': 382,
#   'fall_sun': 158,
#   'summer': 510,
#   'summer_sun': 210,
#   'winter': 250,
#   'winter_sun': 110},
#  184715: {'fall': 270,
#   'fall_sun': 270,
#   'summer': 268,
#   'summer_sun': 452,
#   'winter': 206,
#   'winter_sun': 154},
#  158050: {'fall': 2,
#   'fall_sun': 538,
#   'summer': 44,
#   'summer_sun': 676,
#   'winter': 0,
#   'winter_sun': 360},
#  147397: {'fall': 373,
#   'fall_sun': 167,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 359,
#   'winter_sun': 1},
#  159658: {'fall': 199,
#   'fall_sun': 341,
#   'summer': 423,
#   'summer_sun': 297,
#   'winter': 122,
#   'winter_sun': 238},
#  173394: {'fall': 269,
#   'fall_sun': 271,
#   'summer': 350,
#   'summer_sun': 370,
#   'winter': 192,
#   'winter_sun': 168},
#  185008: {'fall': 97,
#   'fall_sun': 443,
#   'summer': 221,
#   'summer_sun': 499,
#   'winter': 5,
#   'winter_sun': 355},
#  176563: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 72,
#   'summer_sun': 648,
#   'winter': 246,
#   'winter_sun': 114},
#  170024: {'fall': 379,
#   'fall_sun': 161,
#   'summer': 308,
#   'summer_sun': 412,
#   'winter': 342,
#   'winter_sun': 18},
#  186382: {'fall': 293,
#   'fall_sun': 247,
#   'summer': 410,
#   'summer_sun': 310,
#   'winter': 114,
#   'winter_sun': 246},
#  175704: {'fall': 452,
#   'fall_sun': 88,
#   'summer': 429,
#   'summer_sun': 291,
#   'winter': 306,
#   'winter_sun': 54},
#  185163: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 30,
#   'summer_sun': 690,
#   'winter': 0,
#   'winter_sun': 360},
#  185164: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 21,
#   'summer_sun': 699,
#   'winter': 0,
#   'winter_sun': 360},
#  165625: {'fall': 357,
#   'fall_sun': 183,
#   'summer': 386,
#   'summer_sun': 334,
#   'winter': 239,
#   'winter_sun': 121},
#  181202: {'fall': 211,
#   'fall_sun': 329,
#   'summer': 189,
#   'summer_sun': 531,
#   'winter': 160,
#   'winter_sun': 200},
#  183359: {'fall': 300,
#   'fall_sun': 240,
#   'summer': 366,
#   'summer_sun': 354,
#   'winter': 201,
#   'winter_sun': 159},
#  145055: {'fall': 397,
#   'fall_sun': 143,
#   'summer': 343,
#   'summer_sun': 377,
#   'winter': 360,
#   'winter_sun': 0},
#  167230: {'fall': 148,
#   'fall_sun': 392,
#   'summer': 160,
#   'summer_sun': 560,
#   'winter': 95,
#   'winter_sun': 265},
#  178930: {'fall': 349,
#   'fall_sun': 191,
#   'summer': 471,
#   'summer_sun': 249,
#   'winter': 289,
#   'winter_sun': 71},
#  180333: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 68,
#   'summer_sun': 652,
#   'winter': 0,
#   'winter_sun': 360},
#  172663: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 0,
#   'winter_sun': 360},
#  208791: {'fall': 457,
#   'fall_sun': 83,
#   'summer': 504,
#   'summer_sun': 216,
#   'winter': 360,
#   'winter_sun': 0},
#  208793: {'fall': 464,
#   'fall_sun': 76,
#   'summer': 543,
#   'summer_sun': 177,
#   'winter': 360,
#   'winter_sun': 0},
#  194260: {'fall': 415,
#   'fall_sun': 125,
#   'summer': 535,
#   'summer_sun': 185,
#   'winter': 291,
#   'winter_sun': 69},
#  184166: {'fall': 405,
#   'fall_sun': 135,
#   'summer': 381,
#   'summer_sun': 339,
#   'winter': 360,
#   'winter_sun': 0},
#  188408: {'fall': 423,
#   'fall_sun': 117,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 360,
# ...
#   'summer_sun': 310,
#   'winter': 360,
#   'winter_sun': 0},
#  189582: {'fall': 42,
#   'fall_sun': 498,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 181,
#   'winter_sun': 179},
#  209057: {'fall': 12,
#   'fall_sun': 528,
#   'summer': 121,
#   'summer_sun': 599,
#   'winter': 0,
#   'winter_sun': 360},
#  159759: {'fall': 19,
#   'fall_sun': 521,
#   'summer': 69,
#   'summer_sun': 651,
#   'winter': 0,
#   'winter_sun': 360},
#  179866: {'fall': 274,
#   'fall_sun': 266,
#   'summer': 365,
#   'summer_sun': 355,
#   'winter': 200,
#   'winter_sun': 160},
#  192133: {'fall': 484,
#   'fall_sun': 56,
#   'summer': 178,
#   'summer_sun': 542,
#   'winter': 360,
#   'winter_sun': 0},
#  196677: {'fall': 16,
#   'fall_sun': 524,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 183,
#   'winter_sun': 177},
#  192584: {'fall': 34,
#   'fall_sun': 506,
#   'summer': 164,
#   'summer_sun': 556,
#   'winter': 20,
#   'winter_sun': 340},
#  189308: {'fall': 151,
#   'fall_sun': 389,
#   'summer': 31,
#   'summer_sun': 689,
#   'winter': 360,
#   'winter_sun': 0},
#  200371: {'fall': 494,
#   'fall_sun': 46,
#   'summer': 628,
#   'summer_sun': 92,
#   'winter': 334,
#   'winter_sun': 26},
#  208977: {'fall': 77,
#   'fall_sun': 463,
#   'summer': 152,
#   'summer_sun': 568,
#   'winter': 54,
#   'winter_sun': 306},
#  184278: {'fall': 199,
#   'fall_sun': 341,
#   'summer': 176,
#   'summer_sun': 544,
#   'winter': 278,
#   'winter_sun': 82},
#  194841: {'fall': 34,
#   'fall_sun': 506,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 330,
#   'winter_sun': 30},
#  194842: {'fall': 50,
#   'fall_sun': 490,
#   'summer': 4,
#   'summer_sun': 716,
#   'winter': 335,
#   'winter_sun': 25},
#  200539: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 5,
#   'summer_sun': 715,
#   'winter': 84,
#   'winter_sun': 276},
#  209413: {'fall': 75,
#   'fall_sun': 465,
#   'summer': 56,
#   'summer_sun': 664,
#   'winter': 71,
#   'winter_sun': 289},
#  173167: {'fall': 50,
#   'fall_sun': 490,
#   'summer': 25,
#   'summer_sun': 695,
#   'winter': 122,
#   'winter_sun': 238},
#  165265: {'fall': 48,
#   'fall_sun': 492,
#   'summer': 175,
#   'summer_sun': 545,
#   'winter': 224,
#   'winter_sun': 136},
#  180966: {'fall': 112,
#   'fall_sun': 428,
#   'summer': 123,
#   'summer_sun': 597,
#   'winter': 62,
#   'winter_sun': 298},
#  178515: {'fall': 272,
#   'fall_sun': 268,
#   'summer': 347,
#   'summer_sun': 373,
#   'winter': 183,
#   'winter_sun': 177},
#  178265: {'fall': 387,
#   'fall_sun': 153,
#   'summer': 396,
#   'summer_sun': 324,
#   'winter': 360,
#   'winter_sun': 0},
#  185671: {'fall': 100,
#   'fall_sun': 440,
#   'summer': 300,
#   'summer_sun': 420,
#   'winter': 96,
#   'winter_sun': 264},
#  187986: {'fall': 110,
#   'fall_sun': 430,
#   'summer': 231,
#   'summer_sun': 489,
#   'winter': 12,
#   'winter_sun': 348},
#  176429: {'fall': 226,
#   'fall_sun': 314,
#   'summer': 35,
#   'summer_sun': 685,
#   'winter': 281,
#   'winter_sun': 79},
#  145909: {'fall': 249,
#   'fall_sun': 291,
#   'summer': 288,
#   'summer_sun': 432,
#   'winter': 140,
#   'winter_sun': 220},
#  190015: {'fall': 171,
#   'fall_sun': 369,
#   'summer': 167,
#   'summer_sun': 553,
#   'winter': 151,
#   'winter_sun': 209},
#  156323: {'fall': 19,
#   'fall_sun': 521,
#   'summer': 63,
#   'summer_sun': 657,
#   'winter': 0,
#   'winter_sun': 360},
#  173453: {'fall': 87,
#   'fall_sun': 453,
#   'summer': 8,
#   'summer_sun': 712,
#   'winter': 88,
#   'winter_sun': 272},
#  164154: {'fall': 61,
#   'fall_sun': 479,
#   'summer': 173,
#   'summer_sun': 547,
#   'winter': 100,
#   'winter_sun': 260},
#  193119: {'fall': 299,
#   'fall_sun': 241,
#   'summer': 408,
#   'summer_sun': 312,
#   'winter': 117,
#   'winter_sun': 243},
#  208260: {'fall': 80,
#   'fall_sun': 460,
#   'summer': 134,
#   'summer_sun': 586,
#   'winter': 39,
#   'winter_sun': 321},
#  208813: {'fall': 539,
#   'fall_sun': 1,
#   'summer': 258,
#   'summer_sun': 462,
#   'winter': 359,
#   'winter_sun': 1},
#  208477: {'fall': 214,
#   'fall_sun': 326,
#   'summer': 304,
#   'summer_sun': 416,
#   'winter': 113,
#   'winter_sun': 247},
#  208478: {'fall': 209,
#   'fall_sun': 331,
#   'summer': 296,
#   'summer_sun': 424,
#   'winter': 152,
#   'winter_sun': 208},
#  209163: {'fall': 240,
#   'fall_sun': 300,
#   'summer': 327,
#   'summer_sun': 393,
#   'winter': 189,
#   'winter_sun': 171},
#  188608: {'fall': 319,
#   'fall_sun': 221,
#   'summer': 397,
#   'summer_sun': 323,
#   'winter': 360,
#   'winter_sun': 0},
#  188739: {'fall': 43,
#   'fall_sun': 497,
#   'summer': 120,
#   'summer_sun': 600,
#   'winter': 23,
#   'winter_sun': 337},
#  209264: {'fall': 132,
#   'fall_sun': 408,
#   'summer': 215,
#   'summer_sun': 505,
#   'winter': 122,
#   'winter_sun': 238},
#  190361: {'fall': 311,
#   'fall_sun': 229,
#   'summer': 412,
#   'summer_sun': 308,
#   'winter': 193,
#   'winter_sun': 167},
#  196078: {'fall': 353,
#   'fall_sun': 187,
#   'summer': 466,
#   'summer_sun': 254,
#   'winter': 264,
#   'winter_sun': 96},
#  206538: {'fall': 185,
#   'fall_sun': 355,
#   'summer': 212,
#   'summer_sun': 508,
#   'winter': 52,
#   'winter_sun': 308},
#  212004: {'fall': 219,
#   'fall_sun': 321,
#   'summer': 349,
#   'summer_sun': 371,
#   'winter': 178,
#   'winter_sun': 182},
#  165601: {'fall': 307,
#   'fall_sun': 233,
#   'summer': 366,
#   'summer_sun': 354,
#   'winter': 260,
#   'winter_sun': 100},
#  159702: {'fall': 100,
#   'fall_sun': 440,
#   'summer': 45,
#   'summer_sun': 675,
#   'winter': 97,
#   'winter_sun': 263},
#  159704: {'fall': 115,
#   'fall_sun': 425,
#   'summer': 194,
#   'summer_sun': 526,
#   'winter': 66,
#   'winter_sun': 294},
#  167573: {'fall': 148,
#   'fall_sun': 392,
#   'summer': 194,
#   'summer_sun': 526,
#   'winter': 88,
#   'winter_sun': 272},
#  170666: {'fall': 198,
#   'fall_sun': 342,
#   'summer': 391,
#   'summer_sun': 329,
#   'winter': 153,
#   'winter_sun': 207},
#  185774: {'fall': 41,
#   'fall_sun': 499,
#   'summer': 118,
#   'summer_sun': 602,
#   'winter': 94,
#   'winter_sun': 266},
#  180845: {'fall': 178,
#   'fall_sun': 362,
#   'summer': 234,
#   'summer_sun': 486,
#   'winter': 74,
#   'winter_sun': 286},
#  181160: {'fall': 326,
#   'fall_sun': 214,
#   'summer': 467,
#   'summer_sun': 253,
#   'winter': 305,
#   'winter_sun': 55},
#  166171: {'fall': 69,
#   'fall_sun': 471,
#   'summer': 36,
#   'summer_sun': 684,
#   'winter': 110,
#   'winter_sun': 250},
#  178303: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 27,
#   'summer_sun': 693,
#   'winter': 263,
#   'winter_sun': 97},
#  178071: {'fall': 59,
#   'fall_sun': 481,
#   'summer': 1,
#   'summer_sun': 719,
#   'winter': 329,
#   'winter_sun': 31},
#  160504: {'fall': 113,
#   'fall_sun': 427,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 48,
#   'winter_sun': 312},
#  160506: {'fall': 169,
#   'fall_sun': 371,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 190,
#   'winter_sun': 170},
#  190277: {'fall': 406,
#   'fall_sun': 134,
#   'summer': 513,
#   'summer_sun': 207,
#   'winter': 295,
#   'winter_sun': 65},
#  179717: {'fall': 246,
#   'fall_sun': 294,
#   'summer': 320,
#   'summer_sun': 400,
#   'winter': 162,
#   'winter_sun': 198},
#  176842: {'fall': 205,
#   'fall_sun': 335,
#   'summer': 288,
#   'summer_sun': 432,
#   'winter': 262,
#   'winter_sun': 98},
#  186883: {'fall': 153,
#   'fall_sun': 387,
#   'summer': 264,
#   'summer_sun': 456,
#   'winter': 24,
#   'winter_sun': 336},
#  186884: {'fall': 147,
#   'fall_sun': 393,
#   'summer': 252,
#   'summer_sun': 468,
#   'winter': 12,
#   'winter_sun': 348},
#  201942: {'fall': 330,
#   'fall_sun': 210,
#   'summer': 341,
#   'summer_sun': 379,
#   'winter': 360,
#   'winter_sun': 0},
#  157640: {'fall': 120,
#   'fall_sun': 420,
#   'summer': 88,
#   'summer_sun': 632,
#   'winter': 47,
#   'winter_sun': 313},
#  185298: {'fall': 273,
#   'fall_sun': 267,
#   'summer': 275,
#   'summer_sun': 445,
#   'winter': 217,
#   'winter_sun': 143},
#  185047: {'fall': 348,
#   'fall_sun': 192,
#   'summer': 62,
#   'summer_sun': 658,
#   'winter': 353,
#   'winter_sun': 7},
#  165478: {'fall': 178,
#   'fall_sun': 362,
#   'summer': 100,
#   'summer_sun': 620,
#   'winter': 257,
#   'winter_sun': 103},
#  160012: {'fall': 381,
#   'fall_sun': 159,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 360,
#   'winter_sun': 0},
#  173647: {'fall': 27,
#   'fall_sun': 513,
#   'summer': 78,
#   'summer_sun': 642,
#   'winter': 307,
#   'winter_sun': 53},
#  165159: {'fall': 280,
#   'fall_sun': 260,
#   'summer': 307,
#   'summer_sun': 413,
#   'winter': 264,
#   'winter_sun': 96},
#  161360: {'fall': 140,
#   'fall_sun': 400,
#   'summer': 76,
#   'summer_sun': 644,
#   'winter': 331,
#   'winter_sun': 29},
#  184267: {'fall': 231,
#   'fall_sun': 309,
#   'summer': 262,
#   'summer_sun': 458,
#   'winter': 160,
#   'winter_sun': 200},
#  158552: {'fall': 17,
#   'fall_sun': 523,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 23,
#   'winter_sun': 337},
#  140990: {'fall': 165,
#   'fall_sun': 375,
#   'summer': 242,
#   'summer_sun': 478,
#   'winter': 218,
#   'winter_sun': 142},
#  158370: {'fall': 203,
#   'fall_sun': 337,
#   'summer': 210,
#   'summer_sun': 510,
#   'winter': 134,
#   'winter_sun': 226},
#  167930: {'fall': 210,
#   'fall_sun': 330,
#   'summer': 322,
#   'summer_sun': 398,
#   'winter': 126,
#   'winter_sun': 234},
#  167937: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 181,
#   'summer_sun': 539,
#   'winter': 93,
#   'winter_sun': 267},
#  169659: {'fall': 461,
#   'fall_sun': 79,
#   'summer': 238,
#   'summer_sun': 482,
#   'winter': 360,
#   'winter_sun': 0},
#  185628: {'fall': 148,
#   'fall_sun': 392,
#   'summer': 217,
#   'summer_sun': 503,
#   'winter': 93,
#   'winter_sun': 267},
#  164568: {'fall': 296,
#   'fall_sun': 244,
#   'summer': 498,
#   'summer_sun': 222,
#   'winter': 139,
#   'winter_sun': 221},
#  175793: {'fall': 202,
#   'fall_sun': 338,
#   'summer': 173,
#   'summer_sun': 547,
#   'winter': 71,
#   'winter_sun': 289},
#  155426: {'fall': 347,
#   'fall_sun': 193,
#   'summer': 472,
#   'summer_sun': 248,
#   'winter': 165,
#   'winter_sun': 195},
#  177890: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 61,
#   'summer_sun': 659,
#   'winter': 7,
#   'winter_sun': 353},
#  172840: {'fall': 111,
#   'fall_sun': 429,
#   'summer': 238,
#   'summer_sun': 482,
#   'winter': 185,
#   'winter_sun': 175},
#  170500: {'fall': 540,
#   'fall_sun': 0,
#   'summer': 51,
#   'summer_sun': 669,
#   'winter': 360,
#   'winter_sun': 0},
#  159904: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 352,
#   'winter_sun': 8},
#  181996: {'fall': 55,
#   'fall_sun': 485,
#   'summer': 56,
#   'summer_sun': 664,
#   'winter': 27,
#   'winter_sun': 333},
#  151180: {'fall': 215,
#   'fall_sun': 325,
#   'summer': 210,
#   'summer_sun': 510,
#   'winter': 309,
#   'winter_sun': 51},
#  173208: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 62,
#   'summer_sun': 658,
#   'winter': 254,
#   'winter_sun': 106},
#  194464: {'fall': 227,
#   'fall_sun': 313,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 359,
#   'winter_sun': 1},
#  183400: {'fall': 113,
#   'fall_sun': 427,
#   'summer': 163,
#   'summer_sun': 557,
#   'winter': 161,
#   'winter_sun': 199},
#  180460: {'fall': 538,
#   'fall_sun': 2,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 360,
#   'winter_sun': 0},
#  161391: {'fall': 34,
#   'fall_sun': 506,
#   'summer': 101,
#   'summer_sun': 619,
#   'winter': 359,
#   'winter_sun': 1},
#  172904: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 22,
#   'summer_sun': 698,
#   'winter': 175,
#   'winter_sun': 185},
#  186610: {'fall': 335,
#   'fall_sun': 205,
#   'summer': 445,
#   'summer_sun': 275,
#   'winter': 225,
#   'winter_sun': 135},
#  171102: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 37,
#   'summer_sun': 683,
#   'winter': 72,
#   'winter_sun': 288},
#  180556: {'fall': 146,
#   'fall_sun': 394,
#   'summer': 19,
#   'summer_sun': 701,
#   'winter': 236,
#   'winter_sun': 124},
#  201578: {'fall': 395,
#   'fall_sun': 145,
#   'summer': 208,
#   'summer_sun': 512,
#   'winter': 360,
#   'winter_sun': 0},
#  171789: {'fall': 50,
#   'fall_sun': 490,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 196,
#   'winter_sun': 164},
#  196030: {'fall': 476,
#   'fall_sun': 64,
#   'summer': 553,
#   'summer_sun': 167,
#   'winter': 360,
#   'winter_sun': 0},
#  186838: {'fall': 138,
#   'fall_sun': 402,
#   'summer': 121,
#   'summer_sun': 599,
#   'winter': 122,
#   'winter_sun': 238},
#  186840: {'fall': 163,
#   'fall_sun': 377,
#   'summer': 171,
#   'summer_sun': 549,
#   'winter': 109,
#   'winter_sun': 251},
#  166241: {'fall': 196,
#   'fall_sun': 344,
#   'summer': 210,
#   'summer_sun': 510,
#   'winter': 46,
#   'winter_sun': 314},
#  180311: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 46,
#   'summer_sun': 674,
#   'winter': 53,
#   'winter_sun': 307},
#  200610: {'fall': 58,
#   'fall_sun': 482,
#   'summer': 93,
#   'summer_sun': 627,
#   'winter': 39,
#   'winter_sun': 321},
#  165614: {'fall': 338,
#   'fall_sun': 202,
#   'summer': 460,
#   'summer_sun': 260,
#   'winter': 259,
#   'winter_sun': 101},
#  182283: {'fall': 42,
#   'fall_sun': 498,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 328,
#   'winter_sun': 32},
#  180286: {'fall': 527,
#   'fall_sun': 13,
#   'summer': 353,
#   'summer_sun': 367,
#   'winter': 360,
#   'winter_sun': 0},
#  182099: {'fall': 14,
#   'fall_sun': 526,
#   'summer': 33,
#   'summer_sun': 687,
#   'winter': 66,
#   'winter_sun': 294},
#  180778: {'fall': 239,
#   'fall_sun': 301,
#   'summer': 403,
#   'summer_sun': 317,
#   'winter': 168,
#   'winter_sun': 192},
#  193327: {'fall': 481,
#   'fall_sun': 59,
#   'summer': 549,
#   'summer_sun': 171,
#   'winter': 360,
#   'winter_sun': 0},
#  194114: {'fall': 164,
#   'fall_sun': 376,
#   'summer': 309,
#   'summer_sun': 411,
#   'winter': 33,
#   'winter_sun': 327},
#  189417: {'fall': 326,
#   'fall_sun': 214,
#   'summer': 357,
#   'summer_sun': 363,
#   'winter': 262,
#   'winter_sun': 98},
#  200330: {'fall': 145,
#   'fall_sun': 395,
#   'summer': 169,
#   'summer_sun': 551,
#   'winter': 108,
#   'winter_sun': 252},
#  188115: {'fall': 22,
#   'fall_sun': 518,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 64,
#   'winter_sun': 296},
#  194180: {'fall': 462,
#   'fall_sun': 78,
#   'summer': 272,
#   'summer_sun': 448,
#   'winter': 360,
#   'winter_sun': 0},
#  192057: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 336,
#   'winter_sun': 24},
#  179759: {'fall': 132,
#   'fall_sun': 408,
#   'summer': 234,
#   'summer_sun': 486,
#   'winter': 140,
#   'winter_sun': 220},
#  205161: {'fall': 25,
#   'fall_sun': 515,
#   'summer': 181,
#   'summer_sun': 539,
#   'winter': 118,
#   'winter_sun': 242},
#  197822: {'fall': 66,
#   'fall_sun': 474,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 308,
#   'winter_sun': 52},
#  197824: {'fall': 70,
#   'fall_sun': 470,
#   'summer': 7,
#   'summer_sun': 713,
#   'winter': 314,
#   'winter_sun': 46},
#  191374: {'fall': 156,
#   'fall_sun': 384,
#   'summer': 139,
#   'summer_sun': 581,
#   'winter': 209,
#   'winter_sun': 151},
#  177355: {'fall': 300,
#   'fall_sun': 240,
#   'summer': 226,
#   'summer_sun': 494,
#   'winter': 360,
#   'winter_sun': 0},
#  195035: {'fall': 82,
#   'fall_sun': 458,
#   'summer': 209,
#   'summer_sun': 511,
#   'winter': 116,
#   'winter_sun': 244},
#  177062: {'fall': 61,
#   'fall_sun': 479,
#   'summer': 73,
#   'summer_sun': 647,
#   'winter': 105,
#   'winter_sun': 255},
#  188662: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 81,
#   'summer_sun': 639,
#   'winter': 0,
#   'winter_sun': 360},
#  169510: {'fall': 246,
#   'fall_sun': 294,
#   'summer': 279,
#   'summer_sun': 441,
#   'winter': 130,
#   'winter_sun': 230},
#  181074: {'fall': 114,
#   'fall_sun': 426,
#   'summer': 204,
#   'summer_sun': 516,
#   'winter': 81,
#   'winter_sun': 279},
#  173209: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 59,
#   'summer_sun': 661,
#   'winter': 254,
#   'winter_sun': 106},
#  182103: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 28,
#   'summer_sun': 692,
#   'winter': 38,
#   'winter_sun': 322},
#  194512: {'fall': 126,
#   'fall_sun': 414,
#   'summer': 184,
#   'summer_sun': 536,
#   'winter': 234,
#   'winter_sun': 126},
#  190164: {'fall': 125,
#   'fall_sun': 415,
#   'summer': 158,
#   'summer_sun': 562,
#   'winter': 123,
#   'winter_sun': 237},
#  191234: {'fall': 221,
#   'fall_sun': 319,
#   'summer': 245,
#   'summer_sun': 475,
#   'winter': 240,
#   'winter_sun': 120},
#  171078: {'fall': 66,
#   'fall_sun': 474,
#   'summer': 175,
#   'summer_sun': 545,
#   'winter': 219,
#   'winter_sun': 141},
#  183705: {'fall': 0,
#   'fall_sun': 540,
#   'summer': 0,
#   'summer_sun': 720,
#   'winter': 0,
#   'winter_sun': 360},
#  157532: {'fall': 107,
#   'fall_sun': 433,
#   'summer': 128,
#   'summer_sun': 592,
#   'winter': 142,
#   'winter_sun': 218},
#  145911: {'fall': 239,
#   'fall_sun': 301,
#   'summer': 290,
#   'summer_sun': 430,
#   'winter': 167,
#   'winter_sun': 193},
#  165181: {'fall': 18,
#   'fall_sun': 522,
#   'summer': 88,
#   'summer_sun': 632,
#   'winter': 0,
#   'winter_sun': 360},
#  180846: {'fall': 170,
#   'fall_sun': 370,
#   'summer': 237,
#   'summer_sun': 483,
#   'winter': 126,
#   'winter_sun': 234},
#  ...}

# %% [markdown]
# ### Can you find a correlation between the amount of sun and tree health?

# %% [markdown]
# ### Is tree height associated with  health?  Do taller trees get more sun?

# %% [markdown]
# ### Exploring tree species.
#
# Here is the NYC list of trees you can use when you plant  a tree:
# https://www.nycgovparks.org/trees/street-tree-planting/species-list
#
# From that list, NYC says that only the following tolerate shade well (only 3!):
#
# Tilia americana
# Tilia tomentosa
# Ulmus americana
#
# How prevalent are these species? Are trees of these species healthier? Have they been planted in suitable places, where they get plenty of shade?

# %% [markdown]
# ### Scratch code

# %%
# create an array with all trees, their health, and the time in shade and sun
tree_all_info = {}

for i,r in trees.iterrows():
    id = r['tree_id']
    if id not in tree_all_info:
            tree_all_info[id] = {}
            
    # copy tree fields
    tree_all_info[id]['tree_id'] = id    
    tree_all_info[id]['health'] = r['health']
    tree_all_info[id]['status'] = r['status']
    tree_all_info[id]['spc_common'] = r['spc_common']
    tree_all_info[id]['village'] = r['village']
    
    # make health numeric 
    if r['health']=="Good":
         tree_all_info[id]['health_num'] = 20
    if r['health']=="Poor":
         tree_all_info[id]['health_num'] = 5
    if r['health']=="Fair":
         tree_all_info[id]['health_num'] = 10
    if r['health']=="None":
         tree_all_info[id]['health_num'] = 0
            
    # copy shade/sun fields
    tree_all_info[id]['fall'] = tree_shd[id]['fall']
    tree_all_info[id]['fall_sun'] = tree_shd[id]['fall_sun']
    tree_all_info[id]['summer'] = tree_shd[id]['summer']
    tree_all_info[id]['summer_sun'] = tree_shd[id]['summer_sun']
    tree_all_info[id]['winter'] = tree_shd[id]['winter']
    tree_all_info[id]['winter_sun'] = tree_shd[id]['fall_sun']
    tree_all_info[id]['all_shade'] = 2*tree_shd[id]['fall'] + tree_shd[id]['summer'] + tree_shd[id]['winter']
    tree_all_info[id]['all_sun'] = 2*tree_shd[id]['fall_sun'] + tree_shd[id]['summer_sun'] + tree_shd[id]['winter_sun']

# %%
tree_all_info
# Out:
# {190422.0: {'all_shade': 1867,
#   'all_sun': 293,
#   'fall': 484,
#   'fall_sun': 56,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 539,
#   'summer_sun': 181,
#   'tree_id': 190422.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 56},
#  190426.0: {'all_shade': 1789,
#   'all_sun': 371,
#   'fall': 500,
#   'fall_sun': 40,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 429,
#   'summer_sun': 291,
#   'tree_id': 190426.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 40},
#  208649.0: {'all_shade': 1334,
#   'all_sun': 826,
#   'fall': 272,
#   'fall_sun': 268,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 484,
#   'summer_sun': 236,
#   'tree_id': 208649.0,
#   'village': 'Clinton',
#   'winter': 306,
#   'winter_sun': 268},
#  193310.0: {'all_shade': 1865,
#   'all_sun': 295,
#   'fall': 486,
#   'fall_sun': 54,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 533,
#   'summer_sun': 187,
#   'tree_id': 193310.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 360,
#   'winter_sun': 54},
#  199760.0: {'all_shade': 1492,
#   'all_sun': 668,
#   'fall': 351,
#   'fall_sun': 189,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'willow oak',
#   'status': 'Alive',
#   'summer': 525,
#   'summer_sun': 195,
#   'tree_id': 199760.0,
#   'village': 'Upper West Side',
#   'winter': 265,
#   'winter_sun': 189},
#  201555.0: {'all_shade': 1646,
#   'all_sun': 514,
#   'fall': 447,
#   'fall_sun': 93,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 392,
#   'summer_sun': 328,
#   'tree_id': 201555.0,
#   'village': 'Chinatown',
#   'winter': 360,
#   'winter_sun': 93},
#  187056.0: {'all_shade': 1695,
#   'all_sun': 465,
#   'fall': 442,
#   'fall_sun': 98,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 451,
#   'summer_sun': 269,
#   'tree_id': 187056.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 98},
#  187058.0: {'all_shade': 1779,
#   'all_sun': 381,
#   'fall': 435,
#   'fall_sun': 105,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 552,
#   'summer_sun': 168,
#   'tree_id': 187058.0,
#   'village': 'Lincoln Square',
#   'winter': 357,
#   'winter_sun': 105},
#  190423.0: {'all_shade': 1872,
#   'all_sun': 288,
#   'fall': 496,
#   'fall_sun': 44,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 520,
#   'summer_sun': 200,
#   'tree_id': 190423.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 44},
#  190425.0: {'all_shade': 1769,
#   'all_sun': 391,
#   'fall': 500,
#   'fall_sun': 40,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 409,
#   'summer_sun': 311,
#   'tree_id': 190425.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 40},
#  208346.0: {'all_shade': 621,
#   'all_sun': 1539,
#   'fall': 102,
#   'fall_sun': 438,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 296,
#   'summer_sun': 424,
#   'tree_id': 208346.0,
#   'village': 'Upper West Side',
#   'winter': 121,
#   'winter_sun': 438},
#  178382.0: {'all_shade': 1209,
#   'all_sun': 951,
#   'fall': 324,
#   'fall_sun': 216,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 259,
#   'summer_sun': 461,
#   'tree_id': 178382.0,
#   'village': 'Stuyvesant Town-Cooper Village',
#   'winter': 302,
#   'winter_sun': 216},
#  191988.0: {'all_shade': 998,
#   'all_sun': 1162,
#   'fall': 247,
#   'fall_sun': 293,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'willow oak',
#   'status': 'Alive',
#   'summer': 157,
#   'summer_sun': 563,
#   'tree_id': 191988.0,
#   'village': 'SoHo-TriBeCa-Civic Center-Little Italy',
#   'winter': 347,
#   'winter_sun': 293},
#  208230.0: {'all_shade': 225,
#   'all_sun': 1935,
#   'fall': 0,
#   'fall_sun': 540,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 95,
#   'summer_sun': 625,
#   'tree_id': 208230.0,
#   'village': 'Upper West Side',
#   'winter': 130,
#   'winter_sun': 540},
#  200225.0: {'all_shade': 1542,
#   'all_sun': 618,
#   'fall': 398,
#   'fall_sun': 142,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 547,
#   'summer_sun': 173,
#   'tree_id': 200225.0,
#   'village': 'Upper West Side',
#   'winter': 199,
#   'winter_sun': 142},
#  198121.0: {'all_shade': 1821,
#   'all_sun': 339,
#   'fall': 468,
#   'fall_sun': 72,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 525,
#   'summer_sun': 195,
#   'tree_id': 198121.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 360,
#   'winter_sun': 72},
#  195252.0: {'all_shade': 1608,
#   'all_sun': 552,
#   'fall': 432,
#   'fall_sun': 108,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 384,
#   'summer_sun': 336,
#   'tree_id': 195252.0,
#   'village': 'West Village',
#   'winter': 360,
#   'winter_sun': 108},
#  198514.0: {'all_shade': 1297,
#   'all_sun': 863,
#   'fall': 316,
#   'fall_sun': 224,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 308,
#   'summer_sun': 412,
#   'tree_id': 198514.0,
#   'village': 'Morningside Heights',
#   'winter': 357,
#   'winter_sun': 224},
#  196373.0: {'all_shade': 778,
#   'all_sun': 1382,
#   'fall': 228,
#   'fall_sun': 312,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 189,
#   'summer_sun': 531,
#   'tree_id': 196373.0,
#   'village': 'Chinatown',
#   'winter': 133,
#   'winter_sun': 312},
#  190359.0: {'all_shade': 1179,
#   'all_sun': 981,
#   'fall': 321,
#   'fall_sun': 219,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 327,
#   'summer_sun': 393,
#   'tree_id': 190359.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 210,
#   'winter_sun': 219},
#  180295.0: {'all_shade': 1850,
#   'all_sun': 310,
#   'fall': 479,
#   'fall_sun': 61,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American elm',
#   'status': 'Alive',
#   'summer': 532,
#   'summer_sun': 188,
#   'tree_id': 180295.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 61},
#  208373.0: {'all_shade': 943,
#   'all_sun': 1217,
#   'fall': 256,
#   'fall_sun': 284,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 208,
#   'summer_sun': 512,
#   'tree_id': 208373.0,
#   'village': 'Upper West Side',
#   'winter': 223,
#   'winter_sun': 284},
#  208240.0: {'all_shade': 294,
#   'all_sun': 1866,
#   'fall': 0,
#   'fall_sun': 540,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 143,
#   'summer_sun': 577,
#   'tree_id': 208240.0,
#   'village': 'Upper West Side',
#   'winter': 151,
#   'winter_sun': 540},
#  208247.0: {'all_shade': 199,
#   'all_sun': 1961,
#   'fall': 25,
#   'fall_sun': 515,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'American elm',
#   'status': 'Alive',
#   'summer': 149,
#   'summer_sun': 571,
#   'tree_id': 208247.0,
#   'village': 'Upper West Side',
#   'winter': 0,
#   'winter_sun': 515},
#  196372.0: {'all_shade': 851,
#   'all_sun': 1309,
#   'fall': 251,
#   'fall_sun': 289,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 208,
#   'summer_sun': 512,
#   'tree_id': 196372.0,
#   'village': 'Chinatown',
#   'winter': 141,
#   'winter_sun': 289},
#  209919.0: {'all_shade': 831,
#   'all_sun': 1329,
#   'fall': 164,
#   'fall_sun': 376,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 273,
#   'summer_sun': 447,
#   'tree_id': 209919.0,
#   'village': 'Morningside Heights',
#   'winter': 230,
#   'winter_sun': 376},
#  208338.0: {'all_shade': 584,
#   'all_sun': 1576,
#   'fall': 146,
#   'fall_sun': 394,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 237,
#   'summer_sun': 483,
#   'tree_id': 208338.0,
#   'village': 'Upper West Side',
#   'winter': 55,
#   'winter_sun': 394},
#  196374.0: {'all_shade': 957,
#   'all_sun': 1203,
#   'fall': 253,
#   'fall_sun': 287,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 298,
#   'summer_sun': 422,
#   'tree_id': 196374.0,
#   'village': 'Chinatown',
#   'winter': 153,
#   'winter_sun': 287},
#  208463.0: {'all_shade': 1141,
#   'all_sun': 1019,
#   'fall': 282,
#   'fall_sun': 258,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ash',
#   'status': 'Alive',
#   'summer': 443,
#   'summer_sun': 277,
#   'tree_id': 208463.0,
#   'village': 'Clinton',
#   'winter': 134,
#   'winter_sun': 258},
#  209921.0: {'all_shade': 951,
#   'all_sun': 1209,
#   'fall': 219,
#   'fall_sun': 321,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 288,
#   'summer_sun': 432,
#   'tree_id': 209921.0,
#   'village': 'Morningside Heights',
#   'winter': 225,
#   'winter_sun': 321},
#  203887.0: {'all_shade': 1028,
#   'all_sun': 1132,
#   'fall': 180,
#   'fall_sun': 360,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'willow oak',
#   'status': 'Alive',
#   'summer': 394,
#   'summer_sun': 326,
#   'tree_id': 203887.0,
#   'village': 'Morningside Heights',
#   'winter': 274,
#   'winter_sun': 360},
#  196440.0: {'all_shade': 1095,
#   'all_sun': 1065,
#   'fall': 286,
#   'fall_sun': 254,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'American elm',
#   'status': 'Alive',
#   'summer': 281,
#   'summer_sun': 439,
#   'tree_id': 196440.0,
#   'village': 'Morningside Heights',
#   'winter': 242,
#   'winter_sun': 254},
#  192814.0: {'all_shade': 1131,
#   'all_sun': 1029,
#   'fall': 237,
#   'fall_sun': 303,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 351,
#   'summer_sun': 369,
#   'tree_id': 192814.0,
#   'village': 'West Village',
#   'winter': 306,
#   'winter_sun': 303},
#  179828.0: {'all_shade': 495,
#   'all_sun': 1665,
#   'fall': 125,
#   'fall_sun': 415,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'red maple',
#   'status': 'Alive',
#   'summer': 128,
#   'summer_sun': 592,
#   'tree_id': 179828.0,
#   'village': 'Chinatown',
#   'winter': 117,
#   'winter_sun': 415},
#  208229.0: {'all_shade': 235,
#   'all_sun': 1925,
#   'fall': 0,
#   'fall_sun': 540,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 110,
#   'summer_sun': 610,
#   'tree_id': 208229.0,
#   'village': 'Upper West Side',
#   'winter': 125,
#   'winter_sun': 540},
#  175693.0: {'all_shade': 1395,
#   'all_sun': 765,
#   'fall': 346,
#   'fall_sun': 194,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 410,
#   'summer_sun': 310,
#   'tree_id': 175693.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 293,
#   'winter_sun': 194},
#  190540.0: {'all_shade': 1378,
#   'all_sun': 782,
#   'fall': 309,
#   'fall_sun': 231,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 400,
#   'summer_sun': 320,
#   'tree_id': 190540.0,
#   'village': 'Upper West Side',
#   'winter': 360,
#   'winter_sun': 231},
#  208395.0: {'all_shade': 465,
#   'all_sun': 1695,
#   'fall': 7,
#   'fall_sun': 533,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 174,
#   'summer_sun': 546,
#   'tree_id': 208395.0,
#   'village': 'Upper West Side',
#   'winter': 277,
#   'winter_sun': 533},
#  209913.0: {'all_shade': 975,
#   'all_sun': 1185,
#   'fall': 256,
#   'fall_sun': 284,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 290,
#   'summer_sun': 430,
#   'tree_id': 209913.0,
#   'village': 'Morningside Heights',
#   'winter': 173,
#   'winter_sun': 284},
#  178756.0: {'all_shade': 1748,
#   'all_sun': 412,
#   'fall': 460,
#   'fall_sun': 80,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 468,
#   'summer_sun': 252,
#   'tree_id': 178756.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 80},
#  163280.0: {'all_shade': 1415,
#   'all_sun': 745,
#   'fall': 334,
#   'fall_sun': 206,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 462,
#   'summer_sun': 258,
#   'tree_id': 163280.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 285,
#   'winter_sun': 206},
#  190420.0: {'all_shade': 1957,
#   'all_sun': 203,
#   'fall': 476,
#   'fall_sun': 64,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 645,
#   'summer_sun': 75,
#   'tree_id': 190420.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 64},
#  191273.0: {'all_shade': 1445,
#   'all_sun': 715,
#   'fall': 390,
#   'fall_sun': 150,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 305,
#   'summer_sun': 415,
#   'tree_id': 191273.0,
#   'village': 'Gramercy',
#   'winter': 360,
#   'winter_sun': 150},
#  176850.0: {'all_shade': 851,
#   'all_sun': 1309,
#   'fall': 219,
#   'fall_sun': 321,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 295,
#   'summer_sun': 425,
#   'tree_id': 176850.0,
#   'village': 'Gramercy',
#   'winter': 118,
#   'winter_sun': 321},
#  180266.0: {'all_shade': 1428,
#   'all_sun': 732,
#   'fall': 382,
#   'fall_sun': 158,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 354,
#   'summer_sun': 366,
#   'tree_id': 180266.0,
#   'village': 'Lincoln Square',
#   'winter': 310,
#   'winter_sun': 158},
#  190393.0: {'all_shade': 1512,
#   'all_sun': 648,
#   'fall': 340,
#   'fall_sun': 200,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 475,
#   'summer_sun': 245,
#   'tree_id': 190393.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 357,
#   'winter_sun': 200},
#  201558.0: {'all_shade': 1612,
#   'all_sun': 548,
#   'fall': 422,
#   'fall_sun': 118,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 408,
#   'summer_sun': 312,
#   'tree_id': 201558.0,
#   'village': 'Chinatown',
#   'winter': 360,
#   'winter_sun': 118},
#  205787.0: {'all_shade': 1886,
#   'all_sun': 274,
#   'fall': 492,
#   'fall_sun': 48,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 542,
#   'summer_sun': 178,
#   'tree_id': 205787.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 48},
#  208767.0: {'all_shade': 1120,
#   'all_sun': 1040,
#   'fall': 260,
#   'fall_sun': 280,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 436,
#   'summer_sun': 284,
#   'tree_id': 208767.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 164,
#   'winter_sun': 280},
#  205734.0: {'all_shade': 1088,
#   'all_sun': 1072,
#   'fall': 297,
#   'fall_sun': 243,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 154,
#   'summer_sun': 566,
#   'tree_id': 205734.0,
#   'village': 'Upper West Side',
#   'winter': 340,
#   'winter_sun': 243},
#  190421.0: {'all_shade': 1904,
#   'all_sun': 256,
#   'fall': 474,
#   'fall_sun': 66,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 596,
#   'summer_sun': 124,
#   'tree_id': 190421.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 66},
#  199062.0: {'all_shade': 1521,
#   'all_sun': 639,
#   'fall': 423,
#   'fall_sun': 117,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 398,
#   'summer_sun': 322,
#   'tree_id': 199062.0,
#   'village': 'Lincoln Square',
#   'winter': 277,
#   'winter_sun': 117},
#  208820.0: {'all_shade': 1297,
#   'all_sun': 863,
#   'fall': 314,
#   'fall_sun': 226,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 309,
#   'summer_sun': 411,
#   'tree_id': 208820.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 226},
#  178606.0: {'all_shade': 1387,
#   'all_sun': 773,
#   'fall': 321,
#   'fall_sun': 219,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 433,
#   'summer_sun': 287,
#   'tree_id': 178606.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 312,
#   'winter_sun': 219},
#  199051.0: {'all_shade': 1561,
#   'all_sun': 599,
#   'fall': 434,
#   'fall_sun': 106,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 428,
#   'summer_sun': 292,
#   'tree_id': 199051.0,
#   'village': 'Lincoln Square',
#   'winter': 265,
#   'winter_sun': 106},
#  208761.0: {'all_shade': 900,
#   'all_sun': 1260,
#   'fall': 191,
#   'fall_sun': 349,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 199,
#   'summer_sun': 521,
#   'tree_id': 208761.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 319,
#   'winter_sun': 349},
#  190395.0: {'all_shade': 1685,
#   'all_sun': 475,
#   'fall': 412,
#   'fall_sun': 128,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 545,
#   'summer_sun': 175,
#   'tree_id': 190395.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 316,
#   'winter_sun': 128},
#  205785.0: {'all_shade': 1918,
#   'all_sun': 242,
#   'fall': 498,
#   'fall_sun': 42,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 562,
#   'summer_sun': 158,
#   'tree_id': 205785.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 42},
#  201410.0: {'all_shade': 1228,
#   'all_sun': 932,
#   'fall': 290,
#   'fall_sun': 250,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 408,
#   'summer_sun': 312,
#   'tree_id': 201410.0,
#   'village': 'Chinatown',
#   'winter': 240,
#   'winter_sun': 250},
#  208760.0: {'all_shade': 1475,
#   'all_sun': 685,
#   'fall': 378,
#   'fall_sun': 162,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 365,
#   'summer_sun': 355,
#   'tree_id': 208760.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 354,
#   'winter_sun': 162},
#  208763.0: {'all_shade': 984,
#   'all_sun': 1176,
#   'fall': 222,
#   'fall_sun': 318,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 188,
#   'summer_sun': 532,
#   'tree_id': 208763.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 352,
#   'winter_sun': 318},
#  190394.0: {'all_shade': 1632,
#   'all_sun': 528,
#   'fall': 380,
#   'fall_sun': 160,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 538,
#   'summer_sun': 182,
#   'tree_id': 190394.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 334,
#   'winter_sun': 160},
#  200471.0: {'all_shade': 1960,
#   'all_sun': 200,
#   'fall': 492,
#   'fall_sun': 48,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 616,
#   'summer_sun': 104,
#   'tree_id': 200471.0,
#   'village': 'Midtown-Midtown South',
#   'winter': 360,
#   'winter_sun': 48},
#  179834.0: {'all_shade': 363,
#   'all_sun': 1797,
#   'fall': 82,
#   'fall_sun': 458,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 104,
#   'summer_sun': 616,
#   'tree_id': 179834.0,
#   'village': 'Chinatown',
#   'winter': 95,
#   'winter_sun': 458},
#  180251.0: {'all_shade': 1544,
#   'all_sun': 616,
#   'fall': 393,
#   'fall_sun': 147,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 398,
#   'summer_sun': 322,
#   'tree_id': 180251.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 147},
#  187054.0: {'all_shade': 1558,
#   'all_sun': 602,
#   'fall': 369,
#   'fall_sun': 171,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 460,
#   'summer_sun': 260,
#   'tree_id': 187054.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 171},
#  195995.0: {'all_shade': 1971,
#   'all_sun': 189,
#   'fall': 499,
#   'fall_sun': 41,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 613,
#   'summer_sun': 107,
#   'tree_id': 195995.0,
#   'village': 'Midtown-Midtown South',
#   'winter': 360,
#   'winter_sun': 41},
#  190386.0: {'all_shade': 1346,
#   'all_sun': 814,
#   'fall': 299,
#   'fall_sun': 241,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 458,
#   'summer_sun': 262,
#   'tree_id': 190386.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 290,
#   'winter_sun': 241},
#  208819.0: {'all_shade': 1400,
#   'all_sun': 760,
#   'fall': 367,
#   'fall_sun': 173,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 306,
#   'summer_sun': 414,
#   'tree_id': 208819.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 173},
#  187229.0: {'all_shade': 1830,
#   'all_sun': 330,
#   'fall': 492,
#   'fall_sun': 48,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 521,
#   'summer_sun': 199,
#   'tree_id': 187229.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 325,
#   'winter_sun': 48},
#  206381.0: {'all_shade': 1354,
#   'all_sun': 806,
#   'fall': 272,
#   'fall_sun': 268,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 518,
#   'summer_sun': 202,
#   'tree_id': 206381.0,
#   'village': 'Gramercy',
#   'winter': 292,
#   'winter_sun': 268},
#  187061.0: {'all_shade': 1353,
#   'all_sun': 807,
#   'fall': 286,
#   'fall_sun': 254,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 530,
#   'summer_sun': 190,
#   'tree_id': 187061.0,
#   'village': 'Lincoln Square',
#   'winter': 251,
#   'winter_sun': 254},
#  190435.0: {'all_shade': 1899,
#   'all_sun': 261,
#   'fall': 489,
#   'fall_sun': 51,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 561,
#   'summer_sun': 159,
#   'tree_id': 190435.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 51},
#  200439.0: {'all_shade': 1907,
#   'all_sun': 253,
#   'fall': 539,
#   'fall_sun': 1,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 469,
#   'summer_sun': 251,
#   'tree_id': 200439.0,
#   'village': 'Chinatown',
#   'winter': 360,
#   'winter_sun': 1},
#  180252.0: {'all_shade': 1556,
#   'all_sun': 604,
#   'fall': 402,
#   'fall_sun': 138,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 392,
#   'summer_sun': 328,
#   'tree_id': 180252.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 138},
#  204033.0: {'all_shade': 895,
#   'all_sun': 1265,
#   'fall': 192,
#   'fall_sun': 348,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 343,
#   'summer_sun': 377,
#   'tree_id': 204033.0,
#   'village': 'Upper West Side',
#   'winter': 168,
#   'winter_sun': 348},
#  170023.0: {'all_shade': 1480,
#   'all_sun': 680,
#   'fall': 409,
#   'fall_sun': 131,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 303,
#   'summer_sun': 417,
#   'tree_id': 170023.0,
#   'village': 'Battery Park City-Lower Manhattan',
#   'winter': 359,
#   'winter_sun': 131},
#  187294.0: {'all_shade': 961,
#   'all_sun': 1199,
#   'fall': 225,
#   'fall_sun': 315,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 350,
#   'summer_sun': 370,
#   'tree_id': 187294.0,
#   'village': 'Central Harlem South',
#   'winter': 161,
#   'winter_sun': 315},
#  206382.0: {'all_shade': 1433,
#   'all_sun': 727,
#   'fall': 313,
#   'fall_sun': 227,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 520,
#   'summer_sun': 200,
#   'tree_id': 206382.0,
#   'village': 'Gramercy',
#   'winter': 287,
#   'winter_sun': 227},
#  181473.0: {'all_shade': 1160,
#   'all_sun': 1000,
#   'fall': 279,
#   'fall_sun': 261,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 242,
#   'summer_sun': 478,
#   'tree_id': 181473.0,
#   'village': 'Upper West Side',
#   'winter': 360,
#   'winter_sun': 261},
#  190115.0: {'all_shade': 1837,
#   'all_sun': 323,
#   'fall': 473,
#   'fall_sun': 67,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'willow oak',
#   'status': 'Alive',
#   'summer': 531,
#   'summer_sun': 189,
#   'tree_id': 190115.0,
#   'village': 'Upper West Side',
#   'winter': 360,
#   'winter_sun': 67},
#  118769.0: {'all_shade': 646,
#   'all_sun': 1514,
#   'fall': 64,
#   'fall_sun': 476,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'Turkish hazelnut',
#   'status': 'Alive',
#   'summer': 213,
#   'summer_sun': 507,
#   'tree_id': 118769.0,
#   'village': 'Chinatown',
#   'winter': 305,
#   'winter_sun': 476},
#  191268.0: {'all_shade': 1322,
#   'all_sun': 838,
#   'fall': 275,
#   'fall_sun': 265,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 435,
#   'summer_sun': 285,
#   'tree_id': 191268.0,
#   'village': 'Gramercy',
#   'winter': 337,
#   'winter_sun': 265},
#  198018.0: {'all_shade': 1896,
#   'all_sun': 264,
#   'fall': 489,
#   'fall_sun': 51,
#   'health': 'Poor',
#   'health_num': 5,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 609,
#   'summer_sun': 111,
#   'tree_id': 198018.0,
#   'village': 'Turtle Bay-East Midtown',
#   'winter': 309,
#   'winter_sun': 51},
#  198020.0: {'all_shade': 1876,
#   'all_sun': 284,
#   'fall': 485,
#   'fall_sun': 55,
#   'health': 'Poor',
#   'health_num': 5,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 596,
#   'summer_sun': 124,
#   'tree_id': 198020.0,
#   'village': 'Turtle Bay-East Midtown',
#   'winter': 310,
#   'winter_sun': 55},
#  175281.0: {'all_shade': 1692,
#   'all_sun': 468,
#   'fall': 486,
#   'fall_sun': 54,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Norway maple',
#   'status': 'Alive',
#   'summer': 360,
#   'summer_sun': 360,
#   'tree_id': 175281.0,
#   'village': 'Clinton',
#   'winter': 360,
#   'winter_sun': 54},
#  200363.0: {'all_shade': 1949,
#   'all_sun': 211,
#   'fall': 488,
#   'fall_sun': 52,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 613,
#   'summer_sun': 107,
#   'tree_id': 200363.0,
#   'village': 'Midtown-Midtown South',
#   'winter': 360,
#   'winter_sun': 52},
#  203805.0: {'all_shade': 1853,
#   'all_sun': 307,
#   'fall': 461,
#   'fall_sun': 79,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 571,
#   'summer_sun': 149,
#   'tree_id': 203805.0,
#   'village': 'Upper West Side',
#   'winter': 360,
#   'winter_sun': 79},
#  204158.0: {'all_shade': 1726,
#   'all_sun': 434,
#   'fall': 439,
#   'fall_sun': 101,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 488,
#   'summer_sun': 232,
#   'tree_id': 204158.0,
#   'village': 'Upper West Side',
#   'winter': 360,
#   'winter_sun': 101},
#  208787.0: {'all_shade': 1785,
#   'all_sun': 375,
#   'fall': 458,
#   'fall_sun': 82,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 509,
#   'summer_sun': 211,
#   'tree_id': 208787.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 82},
#  155673.0: {'all_shade': 1853,
#   'all_sun': 307,
#   'fall': 475,
#   'fall_sun': 65,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 543,
#   'summer_sun': 177,
#   'tree_id': 155673.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 65},
#  178550.0: {'all_shade': 462,
#   'all_sun': 1698,
#   'fall': 75,
#   'fall_sun': 465,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Norway maple',
#   'status': 'Alive',
#   'summer': 185,
#   'summer_sun': 535,
#   'tree_id': 178550.0,
#   'village': 'Morningside Heights',
#   'winter': 127,
#   'winter_sun': 465},
#  178385.0: {'all_shade': 891,
#   'all_sun': 1269,
#   'fall': 173,
#   'fall_sun': 367,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 293,
#   'summer_sun': 427,
#   'tree_id': 178385.0,
#   'village': 'Stuyvesant Town-Cooper Village',
#   'winter': 252,
#   'winter_sun': 367},
#  178387.0: {'all_shade': 726,
#   'all_sun': 1434,
#   'fall': 74,
#   'fall_sun': 466,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 218,
#   'summer_sun': 502,
#   'tree_id': 178387.0,
#   'village': 'Stuyvesant Town-Cooper Village',
#   'winter': 360,
#   'winter_sun': 466},
#  191989.0: {'all_shade': 945,
#   'all_sun': 1215,
#   'fall': 213,
#   'fall_sun': 327,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'willow oak',
#   'status': 'Alive',
#   'summer': 164,
#   'summer_sun': 556,
#   'tree_id': 191989.0,
#   'village': 'SoHo-TriBeCa-Civic Center-Little Italy',
#   'winter': 355,
#   'winter_sun': 327},
#  208371.0: {'all_shade': 830,
#   'all_sun': 1330,
#   'fall': 187,
#   'fall_sun': 353,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 217,
#   'summer_sun': 503,
#   'tree_id': 208371.0,
#   'village': 'Upper West Side',
#   'winter': 239,
#   'winter_sun': 353},
#  191378.0: {'all_shade': 1217,
#   'all_sun': 943,
#   'fall': 211,
#   'fall_sun': 329,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 435,
#   'summer_sun': 285,
#   'tree_id': 191378.0,
#   'village': 'Gramercy',
#   'winter': 360,
#   'winter_sun': 329},
#  170024.0: {'all_shade': 1408,
#   'all_sun': 752,
#   'fall': 379,
#   'fall_sun': 161,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 308,
#   'summer_sun': 412,
#   'tree_id': 170024.0,
#   'village': 'Battery Park City-Lower Manhattan',
#   'winter': 342,
#   'winter_sun': 161},
#  175704.0: {'all_shade': 1639,
#   'all_sun': 521,
#   'fall': 452,
#   'fall_sun': 88,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 429,
#   'summer_sun': 291,
#   'tree_id': 175704.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 306,
#   'winter_sun': 88},
#  145055.0: {'all_shade': 1497,
#   'all_sun': 663,
#   'fall': 397,
#   'fall_sun': 143,
#   'health': 'Poor',
#   'health_num': 5,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 343,
#   'summer_sun': 377,
#   'tree_id': 145055.0,
#   'village': 'SoHo-TriBeCa-Civic Center-Little Italy',
#   'winter': 360,
#   'winter_sun': 143},
#  208791.0: {'all_shade': 1778,
#   'all_sun': 382,
#   'fall': 457,
#   'fall_sun': 83,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 504,
#   'summer_sun': 216,
#   'tree_id': 208791.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 83},
#  208793.0: {'all_shade': 1831,
#   'all_sun': 329,
#   'fall': 464,
#   'fall_sun': 76,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 543,
#   'summer_sun': 177,
#   'tree_id': 208793.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 76},
#  194260.0: {'all_shade': 1656,
#   'all_sun': 504,
#   'fall': 415,
#   'fall_sun': 125,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 535,
#   'summer_sun': 185,
#   'tree_id': 194260.0,
#   'village': 'Lower East Side',
#   'winter': 291,
#   'winter_sun': 125},
#  189403.0: {'all_shade': 961,
#   'all_sun': 1199,
#   'fall': 244,
#   'fall_sun': 296,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'Callery pear',
#   'status': 'Alive',
#   'summer': 318,
#   'summer_sun': 402,
#   'tree_id': 189403.0,
#   'village': 'Morningside Heights',
#   'winter': 155,
#   'winter_sun': 296},
#  120819.0: {'all_shade': 1771,
#   'all_sun': 389,
#   'fall': 468,
#   'fall_sun': 72,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'swamp white oak',
#   'status': 'Alive',
#   'summer': 475,
#   'summer_sun': 245,
#   'tree_id': 120819.0,
#   'village': 'Hudson Yards-Chelsea-Flatiron-Union Square',
#   'winter': 360,
#   'winter_sun': 72},
#  199052.0: {'all_shade': 1590,
#   'all_sun': 570,
#   'fall': 443,
#   'fall_sun': 97,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 441,
#   'summer_sun': 279,
#   'tree_id': 199052.0,
#   'village': 'Lincoln Square',
#   'winter': 263,
#   'winter_sun': 97},
#  208762.0: {'all_shade': 952,
#   'all_sun': 1208,
#   'fall': 209,
#   'fall_sun': 331,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 194,
#   'summer_sun': 526,
#   'tree_id': 208762.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 340,
#   'winter_sun': 331},
#  170507.0: {'all_shade': 1192,
#   'all_sun': 968,
#   'fall': 297,
#   'fall_sun': 243,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Japanese zelkova',
#   'status': 'Alive',
#   'summer': 407,
#   'summer_sun': 313,
#   'tree_id': 170507.0,
#   'village': 'Battery Park City-Lower Manhattan',
#   'winter': 191,
#   'winter_sun': 243},
#  192803.0: {'all_shade': 967,
#   'all_sun': 1193,
#   'fall': 226,
#   'fall_sun': 314,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Japanese zelkova',
#   'status': 'Alive',
#   'summer': 215,
#   'summer_sun': 505,
#   'tree_id': 192803.0,
#   'village': 'West Village',
#   'winter': 300,
#   'winter_sun': 314},
#  187260.0: {'all_shade': 776,
#   'all_sun': 1384,
#   'fall': 121,
#   'fall_sun': 419,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 313,
#   'summer_sun': 407,
#   'tree_id': 187260.0,
#   'village': 'Central Harlem South',
#   'winter': 221,
#   'winter_sun': 419},
#  156710.0: {'all_shade': 1255,
#   'all_sun': 905,
#   'fall': 300,
#   'fall_sun': 240,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 314,
#   'summer_sun': 406,
#   'tree_id': 156710.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 341,
#   'winter_sun': 240},
#  163815.0: {'all_shade': 1078,
#   'all_sun': 1082,
#   'fall': 232,
#   'fall_sun': 308,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 254,
#   'summer_sun': 466,
#   'tree_id': 163815.0,
#   'village': 'Lower East Side',
#   'winter': 360,
#   'winter_sun': 308},
#  175294.0: {'all_shade': 1696,
#   'all_sun': 464,
#   'fall': 432,
#   'fall_sun': 108,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 472,
#   'summer_sun': 248,
#   'tree_id': 175294.0,
#   'village': 'Clinton',
#   'winter': 360,
#   'winter_sun': 108},
#  187057.0: {'all_shade': 1722,
#   'all_sun': 438,
#   'fall': 446,
#   'fall_sun': 94,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 470,
#   'summer_sun': 250,
#   'tree_id': 187057.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 94},
#  190383.0: {'all_shade': 1330,
#   'all_sun': 830,
#   'fall': 348,
#   'fall_sun': 192,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 342,
#   'summer_sun': 378,
#   'tree_id': 190383.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 292,
#   'winter_sun': 192},
#  190433.0: {'all_shade': 1909,
#   'all_sun': 251,
#   'fall': 488,
#   'fall_sun': 52,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 573,
#   'summer_sun': 147,
#   'tree_id': 190433.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 52},
#  176350.0: {'all_shade': 1053,
#   'all_sun': 1107,
#   'fall': 246,
#   'fall_sun': 294,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 201,
#   'summer_sun': 519,
#   'tree_id': 176350.0,
#   'village': 'Gramercy',
#   'winter': 360,
#   'winter_sun': 294},
#  196606.0: {'all_shade': 748,
#   'all_sun': 1412,
#   'fall': 207,
#   'fall_sun': 333,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 169,
#   'summer_sun': 551,
#   'tree_id': 196606.0,
#   'village': 'Morningside Heights',
#   'winter': 165,
#   'winter_sun': 333},
#  162814.0: {'all_shade': 1737,
#   'all_sun': 423,
#   'fall': 422,
#   'fall_sun': 118,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 534,
#   'summer_sun': 186,
#   'tree_id': 162814.0,
#   'village': 'Lower East Side',
#   'winter': 359,
#   'winter_sun': 118},
#  195249.0: {'all_shade': 1704,
#   'all_sun': 456,
#   'fall': 425,
#   'fall_sun': 115,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 494,
#   'summer_sun': 226,
#   'tree_id': 195249.0,
#   'village': 'West Village',
#   'winter': 360,
#   'winter_sun': 115},
#  190437.0: {'all_shade': 1880,
#   'all_sun': 280,
#   'fall': 486,
#   'fall_sun': 54,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 548,
#   'summer_sun': 172,
#   'tree_id': 190437.0,
#   'village': 'Lincoln Square',
#   'winter': 360,
#   'winter_sun': 54},
#  210642.0: {'all_shade': 1201,
#   'all_sun': 959,
#   'fall': 254,
#   'fall_sun': 286,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 333,
#   'summer_sun': 387,
#   'tree_id': 210642.0,
#   'village': 'Clinton',
#   'winter': 360,
#   'winter_sun': 286},
#  195970.0: {'all_shade': 1427,
#   'all_sun': 733,
#   'fall': 376,
#   'fall_sun': 164,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'sweetgum',
#   'status': 'Alive',
#   'summer': 373,
#   'summer_sun': 347,
#   'tree_id': 195970.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 302,
#   'winter_sun': 164},
#  200364.0: {'all_shade': 1909,
#   'all_sun': 251,
#   'fall': 471,
#   'fall_sun': 69,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 607,
#   'summer_sun': 113,
#   'tree_id': 200364.0,
#   'village': 'Midtown-Midtown South',
#   'winter': 360,
#   'winter_sun': 69},
#  204159.0: {'all_shade': 1639,
#   'all_sun': 521,
#   'fall': 411,
#   'fall_sun': 129,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 473,
#   'summer_sun': 247,
#   'tree_id': 204159.0,
#   'village': 'Upper West Side',
#   'winter': 344,
#   'winter_sun': 129},
#  176849.0: {'all_shade': 806,
#   'all_sun': 1354,
#   'fall': 186,
#   'fall_sun': 354,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 304,
#   'summer_sun': 416,
#   'tree_id': 176849.0,
#   'village': 'Gramercy',
#   'winter': 130,
#   'winter_sun': 354},
#  190387.0: {'all_shade': 1508,
#   'all_sun': 652,
#   'fall': 329,
#   'fall_sun': 211,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 526,
#   'summer_sun': 194,
#   'tree_id': 190387.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 324,
#   'winter_sun': 211},
#  208520.0: {'all_shade': 1432,
#   'all_sun': 728,
#   'fall': 340,
#   'fall_sun': 200,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 393,
#   'summer_sun': 327,
#   'tree_id': 208520.0,
#   'village': 'Clinton',
#   'winter': 359,
#   'winter_sun': 200},
#  208365.0: {'all_shade': 609,
#   'all_sun': 1551,
#   'fall': 109,
#   'fall_sun': 431,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 175,
#   'summer_sun': 545,
#   'tree_id': 208365.0,
#   'village': 'Upper West Side',
#   'winter': 216,
#   'winter_sun': 431},
#  198512.0: {'all_shade': 1253,
#   'all_sun': 907,
#   'fall': 324,
#   'fall_sun': 216,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 245,
#   'summer_sun': 475,
#   'tree_id': 198512.0,
#   'village': 'Morningside Heights',
#   'winter': 360,
#   'winter_sun': 216},
#  197862.0: {'all_shade': 1957,
#   'all_sun': 203,
#   'fall': 481,
#   'fall_sun': 59,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 635,
#   'summer_sun': 85,
#   'tree_id': 197862.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 360,
#   'winter_sun': 59},
#  208818.0: {'all_shade': 1434,
#   'all_sun': 726,
#   'fall': 388,
#   'fall_sun': 152,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 298,
#   'summer_sun': 422,
#   'tree_id': 208818.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 152},
#  196005.0: {'all_shade': 1837,
#   'all_sun': 323,
#   'fall': 449,
#   'fall_sun': 91,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 621,
#   'summer_sun': 99,
#   'tree_id': 196005.0,
#   'village': 'Midtown-Midtown South',
#   'winter': 318,
#   'winter_sun': 91},
#  201419.0: {'all_shade': 1106,
#   'all_sun': 1054,
#   'fall': 284,
#   'fall_sun': 256,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 352,
#   'summer_sun': 368,
#   'tree_id': 201419.0,
#   'village': 'Chinatown',
#   'winter': 186,
#   'winter_sun': 256},
#  196541.0: {'all_shade': 1102,
#   'all_sun': 1058,
#   'fall': 283,
#   'fall_sun': 257,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 282,
#   'summer_sun': 438,
#   'tree_id': 196541.0,
#   'village': 'Morningside Heights',
#   'winter': 254,
#   'winter_sun': 257},
#  204268.0: {'all_shade': 1519,
#   'all_sun': 641,
#   'fall': 409,
#   'fall_sun': 131,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 341,
#   'summer_sun': 379,
#   'tree_id': 204268.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 131},
#  190345.0: {'all_shade': 1542,
#   'all_sun': 618,
#   'fall': 381,
#   'fall_sun': 159,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 539,
#   'summer_sun': 181,
#   'tree_id': 190345.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 241,
#   'winter_sun': 159},
#  190127.0: {'all_shade': 1619,
#   'all_sun': 541,
#   'fall': 430,
#   'fall_sun': 110,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 489,
#   'summer_sun': 231,
#   'tree_id': 190127.0,
#   'village': 'Yorkville',
#   'winter': 270,
#   'winter_sun': 110},
#  203268.0: {'all_shade': 1080,
#   'all_sun': 1080,
#   'fall': 268,
#   'fall_sun': 272,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 396,
#   'summer_sun': 324,
#   'tree_id': 203268.0,
#   'village': 'Gramercy',
#   'winter': 148,
#   'winter_sun': 272},
#  208339.0: {'all_shade': 542,
#   'all_sun': 1618,
#   'fall': 135,
#   'fall_sun': 405,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 222,
#   'summer_sun': 498,
#   'tree_id': 208339.0,
#   'village': 'Upper West Side',
#   'winter': 50,
#   'winter_sun': 405},
#  208350.0: {'all_shade': 546,
#   'all_sun': 1614,
#   'fall': 110,
#   'fall_sun': 430,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 272,
#   'summer_sun': 448,
#   'tree_id': 208350.0,
#   'village': 'Upper West Side',
#   'winter': 54,
#   'winter_sun': 430},
#  173727.0: {'all_shade': 1107,
#   'all_sun': 1053,
#   'fall': 294,
#   'fall_sun': 246,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Ohio buckeye',
#   'status': 'Alive',
#   'summer': 182,
#   'summer_sun': 538,
#   'tree_id': 173727.0,
#   'village': 'West Village',
#   'winter': 337,
#   'winter_sun': 246},
#  195309.0: {'all_shade': 806,
#   'all_sun': 1354,
#   'fall': 180,
#   'fall_sun': 360,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 359,
#   'summer_sun': 361,
#   'tree_id': 195309.0,
#   'village': 'West Village',
#   'winter': 87,
#   'winter_sun': 360},
#  189962.0: {'all_shade': 1884,
#   'all_sun': 276,
#   'fall': 481,
#   'fall_sun': 59,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Sophora',
#   'status': 'Alive',
#   'summer': 562,
#   'summer_sun': 158,
#   'tree_id': 189962.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 59},
#  195966.0: {'all_shade': 1974,
#   'all_sun': 186,
#   'fall': 498,
#   'fall_sun': 42,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Callery pear',
#   'status': 'Alive',
#   'summer': 618,
#   'summer_sun': 102,
#   'tree_id': 195966.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 360,
#   'winter_sun': 42},
#  208530.0: {'all_shade': 1767,
#   'all_sun': 393,
#   'fall': 456,
#   'fall_sun': 84,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Callery pear',
#   'status': 'Alive',
#   'summer': 495,
#   'summer_sun': 225,
#   'tree_id': 208530.0,
#   'village': 'Clinton',
#   'winter': 360,
#   'winter_sun': 84},
#  205683.0: {'all_shade': 1578,
#   'all_sun': 582,
#   'fall': 397,
#   'fall_sun': 143,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Callery pear',
#   'status': 'Alive',
#   'summer': 463,
#   'summer_sun': 257,
#   'tree_id': 205683.0,
#   'village': 'Lincoln Square',
#   'winter': 321,
#   'winter_sun': 143},
#  192713.0: {'all_shade': 1522,
#   'all_sun': 638,
#   'fall': 404,
#   'fall_sun': 136,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Callery pear',
#   'status': 'Alive',
#   'summer': 461,
#   'summer_sun': 259,
#   'tree_id': 192713.0,
#   'village': 'West Village',
#   'winter': 253,
#   'winter_sun': 136},
#  178575.0: {'all_shade': 1734,
#   'all_sun': 426,
#   'fall': 438,
#   'fall_sun': 102,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 582,
#   'summer_sun': 138,
#   'tree_id': 178575.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 276,
#   'winter_sun': 102},
#  190241.0: {'all_shade': 1283,
#   'all_sun': 877,
#   'fall': 312,
#   'fall_sun': 228,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 397,
#   'summer_sun': 323,
#   'tree_id': 190241.0,
#   'village': 'Upper West Side',
#   'winter': 262,
#   'winter_sun': 228},
#  179547.0: {'all_shade': 773,
#   'all_sun': 1387,
#   'fall': 186,
#   'fall_sun': 354,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 246,
#   'summer_sun': 474,
#   'tree_id': 179547.0,
#   'village': 'Chinatown',
#   'winter': 155,
#   'winter_sun': 354},
#  191379.0: {'all_shade': 1313,
#   'all_sun': 847,
#   'fall': 299,
#   'fall_sun': 241,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'Japanese zelkova',
#   'status': 'Alive',
#   'summer': 355,
#   'summer_sun': 365,
#   'tree_id': 191379.0,
#   'village': 'Gramercy',
#   'winter': 360,
#   'winter_sun': 241},
#  191380.0: {'all_shade': 1345,
#   'all_sun': 815,
#   'fall': 325,
#   'fall_sun': 215,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'Japanese zelkova',
#   'status': 'Alive',
#   'summer': 335,
#   'summer_sun': 385,
#   'tree_id': 191380.0,
#   'village': 'Gramercy',
#   'winter': 360,
#   'winter_sun': 215},
#  208828.0: {'all_shade': 1315,
#   'all_sun': 845,
#   'fall': 302,
#   'fall_sun': 238,
#   'health': '',
#   'spc_common': '',
#   'status': 'Stump',
#   'summer': 351,
#   'summer_sun': 369,
#   'tree_id': 208828.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 238},
#  208821.0: {'all_shade': 1305,
#   'all_sun': 855,
#   'fall': 315,
#   'fall_sun': 225,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 315,
#   'summer_sun': 405,
#   'tree_id': 208821.0,
#   'village': 'Lenox Hill-Roosevelt Island',
#   'winter': 360,
#   'winter_sun': 225},
#  187059.0: {'all_shade': 1677,
#   'all_sun': 483,
#   'fall': 399,
#   'fall_sun': 141,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
# ...
#   'fall_sun': 330,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 235,
#   'summer_sun': 485,
#   'tree_id': 188498.0,
#   'village': 'Central Harlem South',
#   'winter': 258,
#   'winter_sun': 330},
#  190362.0: {'all_shade': 1262,
#   'all_sun': 898,
#   'fall': 322,
#   'fall_sun': 218,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 459,
#   'summer_sun': 261,
#   'tree_id': 190362.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 159,
#   'winter_sun': 218},
#  174283.0: {'all_shade': 1664,
#   'all_sun': 496,
#   'fall': 439,
#   'fall_sun': 101,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 426,
#   'summer_sun': 294,
#   'tree_id': 174283.0,
#   'village': 'Turtle Bay-East Midtown',
#   'winter': 360,
#   'winter_sun': 101},
#  177828.0: {'all_shade': 1912,
#   'all_sun': 248,
#   'fall': 474,
#   'fall_sun': 66,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 604,
#   'summer_sun': 116,
#   'tree_id': 177828.0,
#   'village': 'SoHo-TriBeCa-Civic Center-Little Italy',
#   'winter': 360,
#   'winter_sun': 66},
#  188692.0: {'all_shade': 1804,
#   'all_sun': 356,
#   'fall': 481,
#   'fall_sun': 59,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 482,
#   'summer_sun': 238,
#   'tree_id': 188692.0,
#   'village': 'Yorkville',
#   'winter': 360,
#   'winter_sun': 59},
#  187756.0: {'all_shade': 1657,
#   'all_sun': 503,
#   'fall': 396,
#   'fall_sun': 144,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 558,
#   'summer_sun': 162,
#   'tree_id': 187756.0,
#   'village': 'Yorkville',
#   'winter': 307,
#   'winter_sun': 144},
#  188688.0: {'all_shade': 1735,
#   'all_sun': 425,
#   'fall': 464,
#   'fall_sun': 76,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 447,
#   'summer_sun': 273,
#   'tree_id': 188688.0,
#   'village': 'Yorkville',
#   'winter': 360,
#   'winter_sun': 76},
#  188691.0: {'all_shade': 1804,
#   'all_sun': 356,
#   'fall': 471,
#   'fall_sun': 69,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 502,
#   'summer_sun': 218,
#   'tree_id': 188691.0,
#   'village': 'Yorkville',
#   'winter': 360,
#   'winter_sun': 69},
#  199720.0: {'all_shade': 1323,
#   'all_sun': 837,
#   'fall': 326,
#   'fall_sun': 214,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 415,
#   'summer_sun': 305,
#   'tree_id': 199720.0,
#   'village': 'Upper West Side',
#   'winter': 256,
#   'winter_sun': 214},
#  211760.0: {'all_shade': 690,
#   'all_sun': 1470,
#   'fall': 142,
#   'fall_sun': 398,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 226,
#   'summer_sun': 494,
#   'tree_id': 211760.0,
#   'village': 'Upper West Side',
#   'winter': 180,
#   'winter_sun': 398},
#  174275.0: {'all_shade': 1738,
#   'all_sun': 422,
#   'fall': 448,
#   'fall_sun': 92,
#   'health': 'Poor',
#   'health_num': 5,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 482,
#   'summer_sun': 238,
#   'tree_id': 174275.0,
#   'village': 'Turtle Bay-East Midtown',
#   'winter': 360,
#   'winter_sun': 92},
#  174277.0: {'all_shade': 1657,
#   'all_sun': 503,
#   'fall': 411,
#   'fall_sun': 129,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 475,
#   'summer_sun': 245,
#   'tree_id': 174277.0,
#   'village': 'Turtle Bay-East Midtown',
#   'winter': 360,
#   'winter_sun': 129},
#  183247.0: {'all_shade': 472,
#   'all_sun': 1688,
#   'fall': 96,
#   'fall_sun': 444,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American elm',
#   'status': 'Alive',
#   'summer': 152,
#   'summer_sun': 568,
#   'tree_id': 183247.0,
#   'village': 'Central Harlem South',
#   'winter': 128,
#   'winter_sun': 444},
#  178406.0: {'all_shade': 1001,
#   'all_sun': 1159,
#   'fall': 240,
#   'fall_sun': 300,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 251,
#   'summer_sun': 469,
#   'tree_id': 178406.0,
#   'village': 'Stuyvesant Town-Cooper Village',
#   'winter': 270,
#   'winter_sun': 300},
#  188545.0: {'all_shade': 297,
#   'all_sun': 1863,
#   'fall': 55,
#   'fall_sun': 485,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'London planetree',
#   'status': 'Alive',
#   'summer': 51,
#   'summer_sun': 669,
#   'tree_id': 188545.0,
#   'village': 'Morningside Heights',
#   'winter': 136,
#   'winter_sun': 485},
#  211786.0: {'all_shade': 930,
#   'all_sun': 1230,
#   'fall': 237,
#   'fall_sun': 303,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 233,
#   'summer_sun': 487,
#   'tree_id': 211786.0,
#   'village': 'Upper West Side',
#   'winter': 223,
#   'winter_sun': 303},
#  211803.0: {'all_shade': 1036,
#   'all_sun': 1124,
#   'fall': 272,
#   'fall_sun': 268,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 287,
#   'summer_sun': 433,
#   'tree_id': 211803.0,
#   'village': 'Upper West Side',
#   'winter': 205,
#   'winter_sun': 268},
#  194038.0: {'all_shade': 1630,
#   'all_sun': 530,
#   'fall': 393,
#   'fall_sun': 147,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 551,
#   'summer_sun': 169,
#   'tree_id': 194038.0,
#   'village': 'Upper West Side',
#   'winter': 293,
#   'winter_sun': 147},
#  58764.0: {'all_shade': 152,
#   'all_sun': 2008,
#   'fall': 0,
#   'fall_sun': 540,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'Siberian elm',
#   'status': 'Alive',
#   'summer': 152,
#   'summer_sun': 568,
#   'tree_id': 58764.0,
#   'village': 'Washington Heights South',
#   'winter': 0,
#   'winter_sun': 540},
#  40748.0: {'all_shade': 1578,
#   'all_sun': 582,
#   'fall': 395,
#   'fall_sun': 145,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Siberian elm',
#   'status': 'Alive',
#   'summer': 428,
#   'summer_sun': 292,
#   'tree_id': 40748.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 360,
#   'winter_sun': 145},
#  160758.0: {'all_shade': 1560,
#   'all_sun': 600,
#   'fall': 417,
#   'fall_sun': 123,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'black walnut',
#   'status': 'Alive',
#   'summer': 367,
#   'summer_sun': 353,
#   'tree_id': 160758.0,
#   'village': 'Washington Heights North',
#   'winter': 359,
#   'winter_sun': 123},
#  174080.0: {'all_shade': 926,
#   'all_sun': 1234,
#   'fall': 204,
#   'fall_sun': 336,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 420,
#   'summer_sun': 300,
#   'tree_id': 174080.0,
#   'village': 'Chinatown',
#   'winter': 98,
#   'winter_sun': 336},
#  211691.0: {'all_shade': 1862,
#   'all_sun': 298,
#   'fall': 524,
#   'fall_sun': 16,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 454,
#   'summer_sun': 266,
#   'tree_id': 211691.0,
#   'village': 'West Village',
#   'winter': 360,
#   'winter_sun': 16},
#  196072.0: {'all_shade': 1254,
#   'all_sun': 906,
#   'fall': 330,
#   'fall_sun': 210,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 234,
#   'summer_sun': 486,
#   'tree_id': 196072.0,
#   'village': 'Clinton',
#   'winter': 360,
#   'winter_sun': 210},
#  174187.0: {'all_shade': 1527,
#   'all_sun': 633,
#   'fall': 423,
#   'fall_sun': 117,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 396,
#   'summer_sun': 324,
#   'tree_id': 174187.0,
#   'village': 'Yorkville',
#   'winter': 285,
#   'winter_sun': 117},
#  194107.0: {'all_shade': 1609,
#   'all_sun': 551,
#   'fall': 401,
#   'fall_sun': 139,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 533,
#   'summer_sun': 187,
#   'tree_id': 194107.0,
#   'village': 'Lower East Side',
#   'winter': 274,
#   'winter_sun': 139},
#  174087.0: {'all_shade': 370,
#   'all_sun': 1790,
#   'fall': 108,
#   'fall_sun': 432,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 137,
#   'summer_sun': 583,
#   'tree_id': 174087.0,
#   'village': 'Chinatown',
#   'winter': 17,
#   'winter_sun': 432},
#  174305.0: {'all_shade': 1192,
#   'all_sun': 968,
#   'fall': 312,
#   'fall_sun': 228,
#   'health': 'Poor',
#   'health_num': 5,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 401,
#   'summer_sun': 319,
#   'tree_id': 174305.0,
#   'village': 'East Village',
#   'winter': 167,
#   'winter_sun': 228},
#  199708.0: {'all_shade': 1182,
#   'all_sun': 978,
#   'fall': 300,
#   'fall_sun': 240,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 317,
#   'summer_sun': 403,
#   'tree_id': 199708.0,
#   'village': 'Upper West Side',
#   'winter': 265,
#   'winter_sun': 240},
#  211801.0: {'all_shade': 1080,
#   'all_sun': 1080,
#   'fall': 304,
#   'fall_sun': 236,
#   'health': 'Poor',
#   'health_num': 5,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 271,
#   'summer_sun': 449,
#   'tree_id': 211801.0,
#   'village': 'Upper West Side',
#   'winter': 201,
#   'winter_sun': 236},
#  139761.0: {'all_shade': 1169,
#   'all_sun': 991,
#   'fall': 308,
#   'fall_sun': 232,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'magnolia',
#   'status': 'Alive',
#   'summer': 236,
#   'summer_sun': 484,
#   'tree_id': 139761.0,
#   'village': 'Central Harlem South',
#   'winter': 317,
#   'winter_sun': 232},
#  192330.0: {'all_shade': 1305,
#   'all_sun': 855,
#   'fall': 327,
#   'fall_sun': 213,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 291,
#   'summer_sun': 429,
#   'tree_id': 192330.0,
#   'village': 'Midtown-Midtown South',
#   'winter': 360,
#   'winter_sun': 213},
#  188604.0: {'all_shade': 883,
#   'all_sun': 1277,
#   'fall': 238,
#   'fall_sun': 302,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 269,
#   'summer_sun': 451,
#   'tree_id': 188604.0,
#   'village': 'Central Harlem South',
#   'winter': 138,
#   'winter_sun': 302},
#  204113.0: {'all_shade': 1626,
#   'all_sun': 534,
#   'fall': 445,
#   'fall_sun': 95,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Chinese elm',
#   'status': 'Alive',
#   'summer': 376,
#   'summer_sun': 344,
#   'tree_id': 204113.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 360,
#   'winter_sun': 95},
#  190341.0: {'all_shade': 1672,
#   'all_sun': 488,
#   'fall': 413,
#   'fall_sun': 127,
#   'health': '',
#   'spc_common': '',
#   'status': 'Dead',
#   'summer': 552,
#   'summer_sun': 168,
#   'tree_id': 190341.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 294,
#   'winter_sun': 127},
#  188501.0: {'all_shade': 858,
#   'all_sun': 1302,
#   'fall': 239,
#   'fall_sun': 301,
#   'health': '',
#   'spc_common': '',
#   'status': 'Dead',
#   'summer': 147,
#   'summer_sun': 573,
#   'tree_id': 188501.0,
#   'village': 'Central Harlem South',
#   'winter': 233,
#   'winter_sun': 301},
#  198193.0: {'all_shade': 1213,
#   'all_sun': 947,
#   'fall': 280,
#   'fall_sun': 260,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Japanese zelkova',
#   'status': 'Alive',
#   'summer': 293,
#   'summer_sun': 427,
#   'tree_id': 198193.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 360,
#   'winter_sun': 260},
#  190401.0: {'all_shade': 1803,
#   'all_sun': 357,
#   'fall': 452,
#   'fall_sun': 88,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'Japanese zelkova',
#   'status': 'Alive',
#   'summer': 539,
#   'summer_sun': 181,
#   'tree_id': 190401.0,
#   'village': 'East Harlem South',
#   'winter': 360,
#   'winter_sun': 88},
#  187078.0: {'all_shade': 1378,
#   'all_sun': 782,
#   'fall': 361,
#   'fall_sun': 179,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'Japanese zelkova',
#   'status': 'Alive',
#   'summer': 451,
#   'summer_sun': 269,
#   'tree_id': 187078.0,
#   'village': 'Morningside Heights',
#   'winter': 205,
#   'winter_sun': 179},
#  188663.0: {'all_shade': 355,
#   'all_sun': 1805,
#   'fall': 49,
#   'fall_sun': 491,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'northern red oak',
#   'status': 'Alive',
#   'summer': 205,
#   'summer_sun': 515,
#   'tree_id': 188663.0,
#   'village': 'Morningside Heights',
#   'winter': 52,
#   'winter_sun': 491},
#  188665.0: {'all_shade': 532,
#   'all_sun': 1628,
#   'fall': 122,
#   'fall_sun': 418,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'northern red oak',
#   'status': 'Alive',
#   'summer': 235,
#   'summer_sun': 485,
#   'tree_id': 188665.0,
#   'village': 'Morningside Heights',
#   'winter': 53,
#   'winter_sun': 418},
#  188243.0: {'all_shade': 1587,
#   'all_sun': 573,
#   'fall': 392,
#   'fall_sun': 148,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 443,
#   'summer_sun': 277,
#   'tree_id': 188243.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 360,
#   'winter_sun': 148},
#  188211.0: {'all_shade': 1542,
#   'all_sun': 618,
#   'fall': 385,
#   'fall_sun': 155,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 514,
#   'summer_sun': 206,
#   'tree_id': 188211.0,
#   'village': 'Upper East Side-Carnegie Hill',
#   'winter': 258,
#   'winter_sun': 155},
#  202059.0: {'all_shade': 705,
#   'all_sun': 1455,
#   'fall': 161,
#   'fall_sun': 379,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 145,
#   'summer_sun': 575,
#   'tree_id': 202059.0,
#   'village': 'Yorkville',
#   'winter': 238,
#   'winter_sun': 379},
#  202060.0: {'all_shade': 833,
#   'all_sun': 1327,
#   'fall': 215,
#   'fall_sun': 325,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 159,
#   'summer_sun': 561,
#   'tree_id': 202060.0,
#   'village': 'Yorkville',
#   'winter': 244,
#   'winter_sun': 325},
#  203696.0: {'all_shade': 1878,
#   'all_sun': 282,
#   'fall': 470,
#   'fall_sun': 70,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 578,
#   'summer_sun': 142,
#   'tree_id': 203696.0,
#   'village': 'Upper West Side',
#   'winter': 360,
#   'winter_sun': 70},
#  211802.0: {'all_shade': 1035,
#   'all_sun': 1125,
#   'fall': 281,
#   'fall_sun': 259,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'crab apple',
#   'status': 'Alive',
#   'summer': 278,
#   'summer_sun': 442,
#   'tree_id': 211802.0,
#   'village': 'Upper West Side',
#   'winter': 195,
#   'winter_sun': 259},
#  211970.0: {'all_shade': 1026,
#   'all_sun': 1134,
#   'fall': 255,
#   'fall_sun': 285,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'American linden',
#   'status': 'Alive',
#   'summer': 274,
#   'summer_sun': 446,
#   'tree_id': 211970.0,
#   'village': 'Washington Heights South',
#   'winter': 242,
#   'winter_sun': 285},
#  209915.0: {'all_shade': 920,
#   'all_sun': 1240,
#   'fall': 225,
#   'fall_sun': 315,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'pin oak',
#   'status': 'Alive',
#   'summer': 288,
#   'summer_sun': 432,
#   'tree_id': 209915.0,
#   'village': 'Morningside Heights',
#   'winter': 182,
#   'winter_sun': 315},
#  206700.0: {'all_shade': 1704,
#   'all_sun': 456,
#   'fall': 472,
#   'fall_sun': 68,
#   'health': 'Fair',
#   'health_num': 10,
#   'spc_common': 'honeylocust',
#   'status': 'Alive',
#   'summer': 400,
#   'summer_sun': 320,
#   'tree_id': 206700.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 360,
#   'winter_sun': 68},
#  198194.0: {'all_shade': 1286,
#   'all_sun': 874,
#   'fall': 314,
#   'fall_sun': 226,
#   'health': 'Good',
#   'health_num': 20,
#   'spc_common': 'northern red oak',
#   'status': 'Alive',
#   'summer': 298,
#   'summer_sun': 422,
#   'tree_id': 198194.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 360,
#   'winter_sun': 226},
#  206489.0: {'all_shade': 1864,
#   'all_sun': 296,
#   'fall': 455,
#   'fall_sun': 85,
#   'health': 'Poor',
#   'health_num': 5,
#   'spc_common': 'ginkgo',
#   'status': 'Alive',
#   'summer': 594,
#   'summer_sun': 126,
#   'tree_id': 206489.0,
#   'village': 'Murray Hill-Kips Bay',
#   'winter': 360,
#   'winter_sun': 85},
#  ...}

# %%
# find all tree species

import pandas as pd

# set rows as keys
species_df = pd.DataFrame.from_dict(tree_all_info,orient='index')

# %%
species_df
# Out:
#            tree_id health status         spc_common  \
# 356.0        356.0   Poor  Alive         crab apple
# 357.0        357.0   Good  Alive       Callery pear
# 358.0        358.0   Good  Alive       Callery pear
# 359.0        359.0   Good  Alive       Callery pear
# 394.0        394.0   Fair  Alive        honeylocust
# 395.0        395.0   Good  Alive        honeylocust
# 396.0        396.0   Fair  Alive       Callery pear
# 419.0        419.0   Good  Alive        honeylocust
# 420.0        420.0   Fair  Alive  littleleaf linden
# 421.0        421.0   Fair  Alive       Callery pear
# 422.0        422.0   Good  Alive       Callery pear
# 423.0        423.0   Fair  Alive       Callery pear
# 424.0        424.0   Good  Alive       Callery pear
# 425.0        425.0   Fair  Alive       Callery pear
# 426.0        426.0   Fair  Alive       Callery pear
# 431.0        431.0   Good  Alive       Callery pear
# 432.0        432.0   Good  Alive            Sophora
# 433.0        433.0   Good  Alive            Sophora
# 445.0        445.0   Good  Alive             ginkgo
# 446.0        446.0   Good  Alive             ginkgo
# 447.0        447.0   Good  Alive             ginkgo
# 448.0        448.0   Good  Alive             ginkgo
# 449.0        449.0   Good  Alive             ginkgo
# 450.0        450.0   Fair  Alive        honeylocust
# 451.0        451.0   Good  Alive             ginkgo
# 452.0        452.0   Fair  Alive          green ash
# 453.0        453.0   Good  Alive  littleleaf linden
# 454.0        454.0         Stump
# 455.0        455.0   Fair  Alive       Callery pear
# 456.0        456.0   Fair  Alive            pin oak
# ...            ...    ...    ...                ...
# 561787.0  561787.0   Fair  Alive   Japanese zelkova
# 561788.0  561788.0   Poor  Alive   Japanese zelkova
# 561789.0  561789.0   Good  Alive   Japanese zelkova
# 561790.0  561790.0   Good  Alive   Japanese zelkova
# 561797.0  561797.0   Good  Alive       sawtooth oak
# 561798.0  561798.0   Good  Alive       sawtooth oak
# 561799.0  561799.0   Good  Alive   Japanese zelkova
# 561800.0  561800.0   Good  Alive   London planetree
# 561801.0  561801.0   Good  Alive   London planetree
# 561802.0  561802.0   Poor  Alive   London planetree
# 698680.0  698680.0   Good  Alive        honeylocust
# 698681.0  698681.0   Good  Alive             cherry
# 698682.0  698682.0   Good  Alive        honeylocust
# 698683.0  698683.0   Good  Alive       Callery pear
# 698684.0  698684.0   Good  Alive        honeylocust
# 698685.0  698685.0   Good  Alive             cherry
# 698686.0  698686.0   Good  Alive        honeylocust
# 698687.0  698687.0   Good  Alive        honeylocust
# 698688.0  698688.0   Good  Alive             cherry
# 698689.0  698689.0   Good  Alive        honeylocust
# 698690.0  698690.0   Good  Alive             cherry
# 698691.0  698691.0   Good  Alive        honeylocust
# 722610.0  722610.0   Fair  Alive  littleleaf linden
# 722611.0  722611.0   Good  Alive      silver linden
# 722669.0  722669.0   Good  Alive   Japanese zelkova
# 722670.0  722670.0   Good  Alive   Japanese zelkova
# 722671.0  722671.0   Good  Alive   Japanese zelkova
# 722672.0  722672.0   Fair  Alive   Japanese zelkova
# 722673.0  722673.0   Fair  Alive       Callery pear
# 722674.0  722674.0   Fair  Alive       Callery pear
#
#                                     village  health_num  fall  fall_sun  \
# 356.0         Upper East Side-Carnegie Hill         5.0   447        93
# 357.0         Upper East Side-Carnegie Hill        20.0   446        94
# 358.0         Upper East Side-Carnegie Hill        20.0   430       110
# 359.0         Upper East Side-Carnegie Hill        20.0   408       132
# 394.0         Upper East Side-Carnegie Hill        10.0   449        91
# 395.0         Upper East Side-Carnegie Hill        20.0   453        87
# 396.0         Upper East Side-Carnegie Hill        10.0   461        79
# 419.0         Upper East Side-Carnegie Hill        20.0   440       100
# 420.0         Upper East Side-Carnegie Hill        10.0   438       102
# 421.0         Upper East Side-Carnegie Hill        10.0   425       115
# 422.0         Upper East Side-Carnegie Hill        20.0   473        67
# 423.0         Upper East Side-Carnegie Hill        10.0   472        68
# 424.0         Upper East Side-Carnegie Hill        20.0   465        75
# 425.0         Upper East Side-Carnegie Hill        10.0   465        75
# 426.0         Upper East Side-Carnegie Hill        10.0   466        74
# 431.0         Upper East Side-Carnegie Hill        20.0   482        58
# 432.0         Upper East Side-Carnegie Hill        20.0   480        60
# 433.0         Upper East Side-Carnegie Hill        20.0   485        55
# 445.0         Upper East Side-Carnegie Hill        20.0   359       181
# 446.0         Upper East Side-Carnegie Hill        20.0   405       135
# 447.0         Upper East Side-Carnegie Hill        20.0   431       109
# 448.0         Upper East Side-Carnegie Hill        20.0   447        93
# 449.0         Upper East Side-Carnegie Hill        20.0   458        82
# 450.0         Upper East Side-Carnegie Hill        10.0   466        74
# 451.0         Upper East Side-Carnegie Hill        20.0   373       167
# 452.0         Upper East Side-Carnegie Hill        10.0   419       121
# 453.0         Upper East Side-Carnegie Hill        20.0   433       107
# 454.0         Upper East Side-Carnegie Hill         NaN   409       131
# 455.0         Upper East Side-Carnegie Hill        10.0   405       135
# 456.0         Upper East Side-Carnegie Hill        10.0   458        82
# ...                                     ...         ...   ...       ...
# 561787.0               Central Harlem South        10.0   440       100
# 561788.0               Central Harlem South         5.0   439       101
# 561789.0               Central Harlem South        20.0   436       104
# 561790.0               Central Harlem South        20.0   377       163
# 561797.0                  East Harlem South        20.0   216       324
# 561798.0                  East Harlem South        20.0   262       278
# 561799.0                  East Harlem South        20.0   129       411
# 561800.0                  East Harlem South        20.0     0       540
# 561801.0                  East Harlem South        20.0     0       540
# 561802.0                  East Harlem South         5.0     0       540
# 698680.0        Lenox Hill-Roosevelt Island        20.0   294       246
# 698681.0        Lenox Hill-Roosevelt Island        20.0   370       170
# 698682.0        Lenox Hill-Roosevelt Island        20.0   362       178
# 698683.0        Lenox Hill-Roosevelt Island        20.0   378       162
# 698684.0        Lenox Hill-Roosevelt Island        20.0   344       196
# 698685.0        Lenox Hill-Roosevelt Island        20.0   349       191
# 698686.0        Lenox Hill-Roosevelt Island        20.0   343       197
# 698687.0        Lenox Hill-Roosevelt Island        20.0   365       175
# 698688.0        Lenox Hill-Roosevelt Island        20.0   373       167
# 698689.0        Lenox Hill-Roosevelt Island        20.0   394       146
# 698690.0        Lenox Hill-Roosevelt Island        20.0   397       143
# 698691.0        Lenox Hill-Roosevelt Island        20.0   356       184
# 722610.0  Battery Park City-Lower Manhattan        10.0   395       145
# 722611.0  Battery Park City-Lower Manhattan        20.0   397       143
# 722669.0                    Upper West Side        20.0   456        84
# 722670.0                    Upper West Side        20.0   464        76
# 722671.0                    Upper West Side        20.0   465        75
# 722672.0                    Upper West Side        10.0   462        78
# 722673.0                    Upper West Side        10.0   466        74
# 722674.0                    Upper West Side        10.0   445        95
#
#           summer  summer_sun  winter  winter_sun  all_shade  all_sun
# 356.0        400         320     327          93       1621      539
# 357.0        406         314     327          94       1625      535
# 358.0        346         374     317         110       1523      637
# 359.0        399         321     316         132       1531      629
# 394.0        498         222     360          91       1756      404
# 395.0        474         246     360          87       1740      420
# 396.0        510         210     360          79       1792      368
# 419.0        480         240     332         100       1692      468
# 420.0        471         249     335         102       1682      478
# 421.0        500         220     332         115       1682      478
# 422.0        492         228     311          67       1749      411
# 423.0        499         221     311          68       1754      406
# 424.0        512         208     314          75       1756      404
# 425.0        524         196     313          75       1767      393
# 426.0        540         180     313          74       1785      375
# 431.0        564         156     360          58       1888      272
# 432.0        518         202     360          60       1838      322
# 433.0        497         223     360          55       1827      333
# 445.0        528         192     360         181       1606      554
# 446.0        591         129     360         135       1761      399
# 447.0        526         194     360         109       1748      412
# 448.0        461         259     360          93       1715      445
# 449.0        388         332     360          82       1664      496
# 450.0        441         279     360          74       1733      427
# 451.0        531         189     360         167       1637      523
# 452.0        418         302     360         121       1616      544
# 453.0        436         284     325         107       1627      533
# 454.0        540         180     322         131       1680      480
# 455.0        563         157     323         135       1696      464
# 456.0        531         189     326          82       1773      387
# ...          ...         ...     ...         ...        ...      ...
# 561787.0     527         193     360         100       1767      393
# 561788.0     515         205     360         101       1753      407
# 561789.0     492         228     360         104       1724      436
# 561790.0     446         274     359         163       1559      601
# 561797.0     169         551     280         324        881     1279
# 561798.0     259         461     280         278       1063     1097
# 561799.0     220         500      24         411        502     1658
# 561800.0      21         699      42         540         63     2097
# 561801.0      10         710      42         540         52     2108
# 561802.0       0         720      43         540         43     2117
# 698680.0     285         435     272         246       1145     1015
# 698681.0     339         381     279         170       1358      802
# 698682.0     364         356     272         178       1360      800
# 698683.0     410         310     279         162       1445      715
# 698684.0     459         261     270         196       1417      743
# 698685.0     543         177     280         191       1521      639
# 698686.0     554         166     273         197       1513      647
# 698687.0     564         156     281         175       1575      585
# 698688.0     565         155     283         167       1594      566
# 698689.0     564         156     285         146       1637      523
# 698690.0     492         228     287         143       1573      587
# 698691.0     349         371     292         184       1353      807
# 722610.0     198         522     280         145       1268      892
# 722611.0     178         542     276         143       1248      912
# 722669.0     506         214     360          84       1778      382
# 722670.0     471         249     360          76       1759      401
# 722671.0     484         236     360          75       1774      386
# 722672.0     492         228     360          78       1776      384
# 722673.0     518         202     360          74       1810      350
# 722674.0     561         159     360          95       1811      349
#
# [65423 rows x 14 columns]

# %%
species_df.corr()
# Out:
#              tree_id  health_num      fall  fall_sun    summer  summer_sun  \
# tree_id     1.000000    0.053939 -0.079535  0.079535 -0.097480    0.097480
# health_num  0.053939    1.000000 -0.049134  0.049134 -0.045850    0.045850
# fall       -0.079535   -0.049134  1.000000 -1.000000  0.788535   -0.788535
# fall_sun    0.079535    0.049134 -1.000000  1.000000 -0.788535    0.788535
# summer     -0.097480   -0.045850  0.788535 -0.788535  1.000000   -1.000000
# summer_sun  0.097480    0.045850 -0.788535  0.788535 -1.000000    1.000000
# winter     -0.065446   -0.043776  0.742669 -0.742669  0.505789   -0.505789
# winter_sun  0.079535    0.049134 -1.000000  1.000000 -0.788535    0.788535
# all_shade  -0.090205   -0.051767  0.975137 -0.975137  0.874867   -0.874867
# all_sun     0.090205    0.051767 -0.975137  0.975137 -0.874867    0.874867
#
#               winter  winter_sun  all_shade   all_sun
# tree_id    -0.065446    0.079535  -0.090205  0.090205
# health_num -0.043776    0.049134  -0.051767  0.051767
# fall        0.742669   -1.000000   0.975137 -0.975137
# fall_sun   -0.742669    1.000000  -0.975137  0.975137
# summer      0.505789   -0.788535   0.874867 -0.874867
# summer_sun -0.505789    0.788535  -0.874867  0.874867
# winter      1.000000   -0.742669   0.793428 -0.793428
# winter_sun -0.742669    1.000000  -0.975137  0.975137
# all_shade   0.793428   -0.975137   1.000000 -1.000000
# all_sun    -0.793428    0.975137  -1.000000  1.000000

# %%
#create a dictionary for species
species_dict = {}
for i,r in species_df.iterrows():
    sp = r['spc_common']
    if sp not in species_dict:
        species_dict[sp]={}
species_dict
# Out:
# {'': {},
#  "'Schubert' chokecherry": {},
#  'American beech': {},
#  'American elm': {},
#  'American hophornbeam': {},
#  'American hornbeam': {},
#  'American larch': {},
#  'American linden': {},
#  'Amur cork tree': {},
#  'Amur maackia': {},
#  'Amur maple': {},
#  'Atlantic white cedar': {},
#  'Callery pear': {},
#  'Chinese chestnut': {},
#  'Chinese elm': {},
#  'Chinese fringetree': {},
#  'Chinese tree lilac': {},
#  'Cornelian cherry': {},
#  'Douglas-fir': {},
#  'English oak': {},
#  'European alder': {},
#  'European beech': {},
#  'European hornbeam': {},
#  'Himalayan cedar': {},
#  'Japanese hornbeam': {},
#  'Japanese maple': {},
#  'Japanese snowbell': {},
#  'Japanese tree lilac': {},
#  'Japanese zelkova': {},
#  'Kentucky coffeetree': {},
#  'Kentucky yellowwood': {},
#  'London planetree': {},
#  'Norway maple': {},
#  'Norway spruce': {},
#  'Ohio buckeye': {},
#  'Oklahoma redbud': {},
#  'Osage-orange': {},
#  'Persian ironwood': {},
#  "Schumard's oak": {},
#  'Scots pine': {},
#  'Siberian elm': {},
#  'Sophora': {},
#  'Turkish hazelnut': {},
#  'Virginia pine': {},
#  'arborvitae': {},
#  'ash': {},
#  'bald cypress': {},
#  'bigtooth aspen': {},
#  'black cherry': {},
#  'black locust': {},
#  'black maple': {},
#  'black oak': {},
#  'black pine': {},
#  'black walnut': {},
#  'blackgum': {},
#  'blue spruce': {},
#  'boxelder': {},
#  'bur oak': {},
#  'catalpa': {},
#  'cherry': {},
#  'cockspur hawthorn': {},
#  'common hackberry': {},
#  'crab apple': {},
#  'crepe myrtle': {},
#  'crimson king maple': {},
#  'cucumber magnolia': {},
#  'dawn redwood': {},
#  'eastern cottonwood': {},
#  'eastern hemlock': {},
#  'eastern redbud': {},
#  'eastern redcedar': {},
#  'empress tree': {},
#  'flowering dogwood': {},
#  'ginkgo': {},
#  'golden raintree': {},
#  'green ash': {},
#  'hardy rubber tree': {},
#  'hawthorn': {},
#  'hedge maple': {},
#  'holly': {},
#  'honeylocust': {},
#  'horse chestnut': {},
#  'katsura tree': {},
#  'kousa dogwood': {},
#  'littleleaf linden': {},
#  'magnolia': {},
#  'maple': {},
#  'mimosa': {},
#  'mulberry': {},
#  'northern red oak': {},
#  'pagoda dogwood': {},
#  'paper birch': {},
#  'paperbark maple': {},
#  'pignut hickory': {},
#  'pin oak': {},
#  'pine': {},
#  'pitch pine': {},
#  'pond cypress': {},
#  'purple-leaf plum': {},
#  'quaking aspen': {},
#  'red horse chestnut': {},
#  'red maple': {},
#  'red pine': {},
#  'river birch': {},
#  'sassafras': {},
#  'sawtooth oak': {},
#  'scarlet oak': {},
#  'serviceberry': {},
#  'shingle oak': {},
#  'silver birch': {},
#  'silver linden': {},
#  'silver maple': {},
#  'smoketree': {},
#  'southern magnolia': {},
#  'southern red oak': {},
#  'spruce': {},
#  'sugar maple': {},
#  'swamp white oak': {},
#  'sweetgum': {},
#  'sycamore maple': {},
#  'tartar maple': {},
#  'tree of heaven': {},
#  'tulip-poplar': {},
#  'two-winged silverbell': {},
#  'weeping willow': {},
#  'white ash': {},
#  'white oak': {},
#  'white pine': {},
#  'willow oak': {}}

# %%
species_groups = species_df.groupby('spc_common')

#species_groups.get_group('honeylocust').describe()
#species_groups
#there are 128 species
#len(species_groups)

# iterate through groups
for name, group in species_groups:
    print (name)
# Out:
# 'Schubert' chokecherry
# American beech
# American elm
# American hophornbeam
# American hornbeam
# American larch
# American linden
# Amur cork tree
# Amur maackia
# Amur maple
# Atlantic white cedar
# Callery pear
# Chinese chestnut
# Chinese elm
# Chinese fringetree
# Chinese tree lilac
# Cornelian cherry
# Douglas-fir
# English oak
# European alder
# European beech
# European hornbeam
# Himalayan cedar
# Japanese hornbeam
# Japanese maple
# Japanese snowbell
# Japanese tree lilac
# Japanese zelkova
# Kentucky coffeetree
# Kentucky yellowwood
# London planetree
# Norway maple
# Norway spruce
# Ohio buckeye
# Oklahoma redbud
# Osage-orange
# Persian ironwood
# Schumard's oak
# Scots pine
# Siberian elm
# Sophora
# Turkish hazelnut
# Virginia pine
# arborvitae
# ash
# bald cypress
# bigtooth aspen
# black cherry
# black locust
# black maple
# black oak
# black pine
# black walnut
# blackgum
# blue spruce
# boxelder
# bur oak
# catalpa
# cherry
# cockspur hawthorn
# common hackberry
# crab apple
# crepe myrtle
# crimson king maple
# cucumber magnolia
# dawn redwood
# eastern cottonwood
# eastern hemlock
# eastern redbud
# eastern redcedar
# empress tree
# flowering dogwood
# ginkgo
# golden raintree
# green ash
# hardy rubber tree
# hawthorn
# hedge maple
# holly
# honeylocust
# horse chestnut
# katsura tree
# kousa dogwood
# littleleaf linden
# magnolia
# maple
# mimosa
# mulberry
# northern red oak
# pagoda dogwood
# paper birch
# paperbark maple
# pignut hickory
# pin oak
# pine
# pitch pine
# pond cypress
# purple-leaf plum
# quaking aspen
# red horse chestnut
# red maple
# red pine
# river birch
# sassafras
# sawtooth oak
# scarlet oak
# serviceberry
# shingle oak
# silver birch
# silver linden
# silver maple
# smoketree
# southern magnolia
# southern red oak
# spruce
# sugar maple
# swamp white oak
# sweetgum
# sycamore maple
# tartar maple
# tree of heaven
# tulip-poplar
# two-winged silverbell
# weeping willow
# white ash
# white oak
# white pine
# willow oak

# %%
count_sp = species_df.groupby('spc_common').size()
count_sp.sort_values(inplace=True,ascending=False)
count_sp
# Out:
# spc_common
# honeylocust              13176
# Callery pear              7297
# ginkgo                    5859
# pin oak                   4584
# Sophora                   4453
# London planetree          4122
# Japanese zelkova          3596
# littleleaf linden         3333
#                           2995
# American elm              1698
# American linden           1583
# northern red oak          1143
# willow oak                 889
# cherry                     869
# Chinese elm                785
# green ash                  770
# swamp white oak            681
# silver linden              541
# crab apple                 437
# golden raintree            359
# red maple                  356
# sawtooth oak               353
# Kentucky coffeetree        348
# Norway maple               290
# black locust               259
# white oak                  241
# sweetgum                   227
# hawthorn                   219
# shingle oak                205
# dawn redwood               199
#                          ...
# two-winged silverbell        8
# eastern hemlock              7
# American larch               7
# southern red oak             7
# European beech               6
# Himalayan cedar              6
# crimson king maple           6
# pitch pine                   5
# crepe myrtle                 5
# arborvitae                   5
# bigtooth aspen               5
# blue spruce                  4
# Norway spruce                3
# cockspur hawthorn            3
# pine                         3
# Virginia pine                3
# black pine                   3
# quaking aspen                2
# boxelder                     2
# Scots pine                   2
# Douglas-fir                  2
# European alder               2
# Osage-orange                 1
# white pine                   1
# pignut hickory               1
# Persian ironwood             1
# red horse chestnut           1
# red pine                     1
# smoketree                    1
# spruce                       1
# Length: 129, dtype: int64

# %%
# create a dataframe from dictionary
# it is currently empty - no values
species_dict_df = pd.DataFrame.from_dict(species_dict,orient='index')
#species_dict_df

# %%
# species_dict['honeylocust']
for sp in species_dict:
    # first we get the groups
    print (str(sp))
# Out:
# crab apple
# Callery pear
# honeylocust
# littleleaf linden
# Sophora
# ginkgo
# green ash
#
# pin oak
# swamp white oak
# London planetree
# white pine
# Norway maple
# black oak
# American elm
# Japanese zelkova
# katsura tree
# European hornbeam
# cherry
# American linden
# Japanese tree lilac
# silver linden
# dawn redwood
# eastern redcedar
# paper birch
# northern red oak
# Chinese elm
# bald cypress
# tree of heaven
# sawtooth oak
# red maple
# sweetgum
# Schumard's oak
# European beech
# black locust
# willow oak
# 'Schubert' chokecherry
# magnolia
# eastern redbud
# silver maple
# Japanese hornbeam
# Japanese maple
# tulip-poplar
# American beech
# white oak
# Oklahoma redbud
# river birch
# Cornelian cherry
# Kentucky coffeetree
# pagoda dogwood
# common hackberry
# hedge maple
# golden raintree
# black cherry
# English oak
# southern magnolia
# serviceberry
# quaking aspen
# purple-leaf plum
# hawthorn
# flowering dogwood
# empress tree
# horse chestnut
# black walnut
# Amur maple
# mulberry
# American hophornbeam
# southern red oak
# crepe myrtle
# hardy rubber tree
# black pine
# pitch pine
# sugar maple
# crimson king maple
# two-winged silverbell
# Chinese fringetree
# Amur maackia
# Norway spruce
# pond cypress
# Turkish hazelnut
# Siberian elm
# mimosa
# shingle oak
# American hornbeam
# silver birch
# tartar maple
# white ash
# cucumber magnolia
# holly
# Japanese snowbell
# eastern cottonwood
# Chinese chestnut
# maple
# European alder
# scarlet oak
# sassafras
# Osage-orange
# eastern hemlock
# ash
# spruce
# Ohio buckeye
# Chinese tree lilac
# pine
# sycamore maple
# catalpa
# red pine
# Persian ironwood
# bur oak
# black maple
# weeping willow
# Scots pine
# Kentucky yellowwood
# Douglas-fir
# American larch
# paperbark maple
# bigtooth aspen
# cockspur hawthorn
# blackgum
# blue spruce
# Virginia pine
# smoketree
# kousa dogwood
# boxelder
# arborvitae
# red horse chestnut
# Amur cork tree
# Atlantic white cedar
# pignut hickory
# Himalayan cedar

# %%
# populate species_dict_df with info for each species
it = 0
for sp, sp_group in species_groups:
    #print sp
    
    count = len(sp_group)
    
    # status
    dead = 0
    stump = 0
    # health
    good = 0
    fair = 0
    poor = 0
    none = 0
    # minutes in shadow and sun
    summer = 0
    fall = 0 
    winter = 0
    summer_sun = 0
    fall_sun = 0 
    winter_sun = 0
    
    for i,v in sp_group.iterrows():
        idk = int(v['tree_id'])
        summer += tree_shd[idk]['summer']
        winter += tree_shd[idk]['winter']
        fall += tree_shd[idk]['fall']
        summer_sun += tree_shd[idk]['summer_sun']
        winter_sun += tree_shd[idk]['winter_sun']
        fall_sun += tree_shd[idk]['fall_sun']
        if v['status']=="Dead":
            dead = dead + 1
        if v['status']=="Stump":
            stump = stump + 1
        if v['health']=="Good":
            good = good + 1
        if v['health']=="Poor":
            poor = poor + 1
        if v['health']=="Fair":
            fair = fair + 1
        if v['health']=="None":
            none = none + 1
            
    # should normalize by the number of trees with the same species
    summer = summer/count*1.
    winter = winter/count*1.
    fall = fall/count*1.
    summer_sun = summer_sun/count*1.
    winter_sun = winter_sun/count*1.
    fall_sun = fall_sun/count*1.
    dead = dead/count*1.
    stump = stump/count*1.
    good = good/count*1.
    poor = poor/count*1.
    fair = fair/count*1.
    none = none/count*1.
 
    species_dict_df.set_value(i,'id', it)
    it = it+1
    species_dict_df.set_value(i,'sp_common', sp)
    species_dict_df.set_value(i,'count', count)
    species_dict_df.set_value(i,'summer', summer)
    species_dict_df.set_value(i,'summer_sun', summer_sun)
    species_dict_df.set_value(i,'winter', winter)
    species_dict_df.set_value(i,'winter_sun', winter_sun)
    species_dict_df.set_value(i,'fall', fall)
    species_dict_df.set_value(i,'fall_sun', fall_sun)
    species_dict_df.set_value(i,'stump', stump)
    species_dict_df.set_value(i,'good', good)
    species_dict_df.set_value(i,'poor', poor)
    species_dict_df.set_value(i,'fair', fair)
    species_dict_df.set_value(i,'dead', dead)

# %%
#len(species_dict_df)
species_dict_df.sort_values('count',inplace=True,ascending=False)
species_dict_df
top_30_species_df = species_dict_df.head(n=30)
top_30_species_df
# Out:
#              id            sp_common    count      summer  summer_sun  \
# 698691.0   80.0          honeylocust  13176.0  375.154675  344.845325
# 722674.0   12.0         Callery pear   7297.0  394.456763  325.543237
# 561759.0   73.0               ginkgo   5859.0  396.612221  323.387779
# 559867.0   94.0              pin oak   4584.0  313.383290  406.616710
# 560266.0   41.0              Sophora   4453.0  379.065574  340.934426
# 561802.0   31.0     London planetree   4122.0  266.092431  453.907569
# 722672.0   28.0     Japanese zelkova   3596.0  343.555617  376.444383
# 722610.0   84.0    littleleaf linden   3333.0  368.815782  351.184218
# 560277.0    0.0                        2995.0  352.359265  367.640735
# 537893.0    3.0         American elm   1698.0  270.050059  449.949941
# 555976.0    7.0      American linden   1583.0  386.780796  333.219204
# 559953.0   89.0     northern red oak   1143.0  333.986002  386.013998
# 537313.0  128.0           willow oak    889.0  375.737908  344.262092
# 698690.0   59.0               cherry    869.0  357.218642  362.781358
# 538124.0   14.0          Chinese elm    785.0  352.789809  367.210191
# 543816.0   75.0            green ash    770.0  329.348052  390.651948
# 543106.0  117.0      swamp white oak    681.0  329.765051  390.234949
# 722611.0  110.0        silver linden    541.0  349.587800  370.412200
# 540917.0   62.0           crab apple    437.0  360.123570  359.876430
# 560226.0   74.0      golden raintree    359.0  347.445682  372.554318
# 559904.0  101.0            red maple    356.0  306.733146  413.266854
# 561798.0  105.0         sawtooth oak    353.0  327.407932  392.592068
# 547999.0   29.0  Kentucky coffeetree    348.0  333.675287  386.324713
# 538521.0   32.0         Norway maple    290.0  291.013793  428.986207
# 542959.0   49.0         black locust    259.0  311.023166  408.976834
# 543631.0  126.0            white oak    241.0  315.821577  404.178423
# 543133.0  118.0             sweetgum    227.0  289.242291  430.757709
# 532206.0   77.0             hawthorn    219.0  398.607306  321.392694
# 543812.0  108.0          shingle oak    205.0  280.775610  439.224390
# 543257.0   66.0         dawn redwood    199.0  324.135678  395.864322
#
#               winter  winter_sun        fall    fall_sun     stump      good  \
# 698691.0  288.483151   71.516849  330.147617  209.852383  0.000000  0.831664
# 722674.0  304.410717   55.589283  349.839112  190.160888  0.000000  0.737563
# 561759.0  302.178187   57.821813  349.512715  190.487285  0.000000  0.748592
# 559867.0  248.937391  111.062609  275.143325  264.856675  0.000000  0.813918
# 560266.0  296.022906   63.977094  334.759937  205.240063  0.000000  0.798114
# 561802.0  232.185590  127.814410  242.508006  297.491994  0.000000  0.630034
# 722672.0  275.556730   84.443270  304.042269  235.957731  0.000000  0.771135
# 722610.0  288.762376   71.237624  327.902190  212.097810  0.000000  0.622862
# 560277.0  281.955259   78.044741  314.551252  225.448748  0.398664  0.000000
# 537893.0  238.261484  121.738516  249.159600  290.840400  0.000000  0.801531
# 555976.0  300.819962   59.180038  342.168035  197.831965  0.000000  0.644346
# 559953.0  270.228346   89.771654  302.911636  237.088364  0.000000  0.717410
# 537313.0  299.658043   60.341957  342.789651  197.210349  0.000000  0.840270
# 698690.0  276.828539   83.171461  309.729574  230.270426  0.000000  0.775604
# 538124.0  268.798726   91.201274  302.022930  237.977070  0.000000  0.769427
# 543816.0  283.200000   76.800000  302.657143  237.342857  0.000000  0.746753
# 543106.0  270.046990   89.953010  301.784141  238.215859  0.000000  0.806167
# 722611.0  279.290203   80.709797  310.083179  229.916821  0.000000  0.706100
# 540917.0  232.318078  127.681922  288.553776  251.446224  0.000000  0.848970
# 560226.0  301.275766   58.724234  324.114206  215.885794  0.000000  0.885794
# 559904.0  282.165730   77.834270  289.775281  250.224719  0.000000  0.629213
# 561798.0  270.756374   89.243626  298.053824  241.946176  0.000000  0.852691
# 547999.0  268.643678   91.356322  291.830460  248.169540  0.000000  0.850575
# 538521.0  236.013793  123.986207  258.989655  281.010345  0.000000  0.541379
# 542959.0  257.000000  103.000000  284.822394  255.177606  0.000000  0.776062
# 543631.0  253.294606  106.705394  290.738589  249.261411  0.000000  0.672199
# 543133.0  281.748899   78.251101  285.792952  254.207048  0.000000  0.665198
# 532206.0  255.671233  104.328767  316.694064  223.305936  0.000000  0.826484
# 543812.0  215.058537  144.941463  244.165854  295.834146  0.000000  0.804878
# 543257.0  267.854271   92.145729  300.517588  239.482412  0.000000  0.608040
#
#               poor      fair      dead
# 698691.0  0.015559  0.152702  0.000076
# 722674.0  0.060436  0.202001  0.000000
# 561759.0  0.083803  0.167605  0.000000
# 559867.0  0.029232  0.156850  0.000000
# 560266.0  0.041770  0.160117  0.000000
# 561802.0  0.092431  0.277535  0.000000
# 722672.0  0.056730  0.172136  0.000000
# 722610.0  0.138314  0.238824  0.000000
# 560277.0  0.000000  0.000000  0.601336
# 537893.0  0.045936  0.152532  0.000000
# 555976.0  0.116235  0.239419  0.000000
# 559953.0  0.049869  0.232721  0.000000
# 537313.0  0.030371  0.129359  0.000000
# 698690.0  0.060990  0.163406  0.000000
# 538124.0  0.053503  0.177070  0.000000
# 543816.0  0.058442  0.194805  0.000000
# 543106.0  0.044053  0.149780  0.000000
# 722611.0  0.077634  0.216266  0.000000
# 540917.0  0.070938  0.080092  0.000000
# 560226.0  0.019499  0.094708  0.000000
# 559904.0  0.112360  0.258427  0.000000
# 561798.0  0.011331  0.135977  0.000000
# 547999.0  0.025862  0.123563  0.000000
# 538521.0  0.137931  0.320690  0.000000
# 542959.0  0.023166  0.200772  0.000000
# 543631.0  0.095436  0.232365  0.000000
# 543133.0  0.114537  0.220264  0.000000
# 532206.0  0.041096  0.132420  0.000000
# 543812.0  0.029268  0.165854  0.000000
# 543257.0  0.160804  0.231156  0.000000

# %%
from __future__ import division

healthdf = pd.read_csv('data/health.csv', sep='\t')
print (villages.columns)

health = {}
for i,r in healthdf.iterrows():
    health[r['name ']] = r 

for i,v in villages.iterrows():
    
    try:
        name = v['NTAName']
        area = v['geometry'].area
    except:
        continue
        
    # first we get the groups
    village_trees = groups.get_group(name)
    
    summer = 0
    fall = 0 
    winter = 0
    summer_sun = 0
    fall_sun = 0 
    winter_sun = 0
    
    for k,t in village_trees.iterrows(): 
        idk = int(t['tree_id'])
        summer += tree_shd[idk]['summer']
        winter += tree_shd[idk]['winter']
        fall += tree_shd[idk]['fall']
        summer_sun += tree_shd[idk]['summer_sun']
        winter_sun += tree_shd[idk]['winter_sun']
        fall_sun += tree_shd[idk]['fall_sun']
    
    # now we count the number of trees
    count = len(village_trees)
    
    # should normalize by the number of trees 
    summer = summer/count*1.
    winter = winter/count*1.
    fall = fall/count*1.
    summer_sun = summer_sun/count*1.
    winter_sun = winter_sun/count*1.
    fall_sun = fall_sun/count*1.

    # print summer, fall, winter, area
    

    # since we have the geometry, we can find i.e. the density of trees
    density = len(village_trees)/area
    # total number of trees / area of neighbourhood
    
    # we can check the mean of the height
    height_mean = village_trees.tree_dbh.mean()
        
    treetotal = health[name]['count']
    good = health[name]['good_count']    
    fair = health[name]['fair_count']
    poor = health[name]['poor_count']
    dead = (treetotal-fair-good-poor)
    
    #score = float((good+fair+poor+dead)/v['geometry'].area)
    score_total = good*10 + fair*5 + poor*3 + dead*1
    #print score_total
    score = float((score_total)/treetotal*1.)
        
    villages.set_value(i,'count', count)
    #villages.set_value(i,'good_count', health[name]['good_count'])
    #villages.set_value(i,'good', good)
    #villages.set_value(i,'fair_count', health[name]['fair_count'])
    #villages.set_value(i,'fair', good)
    villages.set_value(i,'density',density)
    villages.set_value(i,'tree_total', treetotal )
    villages.set_value(i,'tree_score', score )
    villages.set_value(i,'shadow_summer', summer )
    villages.set_value(i,'shadow_winter', winter )
    villages.set_value(i,'shadow_fall', fall )
    villages.set_value(i,'sun_summer', summer_sun )
    villages.set_value(i,'sun_winter', winter_sun )
    villages.set_value(i,'sun_fall', fall_sun )
    villages.set_value(i,'score_total', score_total)
    villages.set_value(i,'height_mean', height_mean)
    
    if (name == "Marble Hill-Inwood"):
        print ("Saw Marble Hill-Inwood")
        print (villages.get_value(i,"count"))
        print (villages.get_value(i,"shadow_fall"))

    
#villages = villages[villages['NTAName']!='park-cemetery-etc-Manhattan']
# Out:
# Index(['BoroCode', 'BoroName', 'CountyFIPS', 'NTACode', 'NTAName',
#        'Shape_Area', 'Shape_Leng', 'geometry'],
#       dtype='object')
# Saw Marble Hill-Inwood
# 1419.0
# 247.772374912

# %%
import scipy.stats
print (villages['tree_score'].corr(villages['shadow_summer']))
print (villages['tree_score'].corr(villages['shadow_fall']))
print (villages['tree_score'].corr(villages['shadow_winter']))
print (villages['tree_score'].corr(villages['shadow_summer'],method='spearman'))
print (villages['tree_score'].corr(villages['shadow_fall'],method='spearman'))
print (villages['tree_score'].corr(villages['shadow_winter'],method='spearman'))
print (scipy.stats.spearmanr(villages['tree_score'], villages['shadow_winter']))
#print villages['shadow_summer'].corr(villages['tree_score'])
#print villages['tree_score'].corr(villages['sun_summer'])
# Out:
# -0.409299828244
# -0.4598952217
# -0.473718992222
# -0.203448275862
# -0.274876847291
# -0.266502463054
# SpearmanrResult(correlation=-0.26650246305418712, pvalue=0.16227698605435925)

# %%
villages.corr()
# Out:
#                BoroCode  Shape_Area  Shape_Leng     count   density  \
# BoroCode            NaN         NaN         NaN       NaN       NaN
# Shape_Area          NaN    1.000000    0.939065  0.146770 -0.475820
# Shape_Leng          NaN    0.939065    1.000000 -0.075486 -0.550342
# count               NaN    0.146770   -0.075486  1.000000  0.610666
# density             NaN   -0.475820   -0.550342  0.610666  1.000000
# tree_total          NaN    0.146770   -0.075486  1.000000  0.610666
# tree_score          NaN    0.336795    0.384662  0.015813 -0.087557
# shadow_summer       NaN   -0.266037   -0.320864  0.197653  0.296140
# shadow_winter       NaN   -0.420414   -0.494910  0.304712  0.488033
# shadow_fall         NaN   -0.293876   -0.360040  0.266198  0.356665
# sun_summer          NaN    0.266037    0.320864 -0.197653 -0.296140
# sun_winter          NaN    0.420414    0.494910 -0.304712 -0.488033
# sun_fall            NaN    0.293876    0.360040 -0.266198 -0.356665
# score_total         NaN    0.176505   -0.043632  0.995648  0.592135
# height_mean         NaN    0.611833    0.653707  0.083805 -0.023087
#
#                tree_total  tree_score  shadow_summer  shadow_winter  \
# BoroCode              NaN         NaN            NaN            NaN
# Shape_Area       0.146770    0.336795      -0.266037      -0.420414
# Shape_Leng      -0.075486    0.384662      -0.320864      -0.494910
# count            1.000000    0.015813       0.197653       0.304712
# density          0.610666   -0.087557       0.296140       0.488033
# tree_total       1.000000    0.015813       0.197653       0.304712
# tree_score       0.015813    1.000000      -0.409300      -0.473719
# shadow_summer    0.197653   -0.409300       1.000000       0.925651
# shadow_winter    0.304712   -0.473719       0.925651       1.000000
# shadow_fall      0.266198   -0.459895       0.984744       0.956106
# sun_summer      -0.197653    0.409300      -1.000000      -0.925651
# sun_winter      -0.304712    0.473719      -0.925651      -1.000000
# sun_fall        -0.266198    0.459895      -0.984744      -0.956106
# score_total      0.995648    0.098895       0.171505       0.269463
# height_mean      0.083805    0.647761      -0.403718      -0.450803
#
#                shadow_fall  sun_summer  sun_winter  sun_fall  score_total  \
# BoroCode               NaN         NaN         NaN       NaN          NaN
# Shape_Area       -0.293876    0.266037    0.420414  0.293876     0.176505
# Shape_Leng       -0.360040    0.320864    0.494910  0.360040    -0.043632
# count             0.266198   -0.197653   -0.304712 -0.266198     0.995648
# density           0.356665   -0.296140   -0.488033 -0.356665     0.592135
# tree_total        0.266198   -0.197653   -0.304712 -0.266198     0.995648
# tree_score       -0.459895    0.409300    0.473719  0.459895     0.098895
# shadow_summer     0.984744   -1.000000   -0.925651 -0.984744     0.171505
# shadow_winter     0.956106   -0.925651   -1.000000 -0.956106     0.269463
# shadow_fall       1.000000   -0.984744   -0.956106 -1.000000     0.233583
# sun_summer       -0.984744    1.000000    0.925651  0.984744    -0.171505
# sun_winter       -0.956106    0.925651    1.000000  0.956106    -0.269463
# sun_fall         -1.000000    0.984744    0.956106  1.000000    -0.233583
# score_total       0.233583   -0.171505   -0.269463 -0.233583     1.000000
# height_mean      -0.434223    0.403718    0.450803  0.434223     0.126063
#
#                height_mean
# BoroCode               NaN
# Shape_Area        0.611833
# Shape_Leng        0.653707
# count             0.083805
# density          -0.023087
# tree_total        0.083805
# tree_score        0.647761
# shadow_summer    -0.403718
# shadow_winter    -0.450803
# shadow_fall      -0.434223
# sun_summer        0.403718
# sun_winter        0.450803
# sun_fall          0.434223
# score_total       0.126063
# height_mean       1.000000

# %% [markdown]
# ## .. and finally plot..
#
# using "YlGn" as a colormap, we have lower (YELLOW) and higher (GREEN). Later we can add colormap bars!

# %% [markdown]
# ### .. the density of trees per villages..
# * Question! What do you think about Central Park's colour?  (Hint: it is a huge space and has a lot of meadows)

# %%
#health -- red = bad
kw = dict(column='tree_score', k=10, colormap='RdYlGn')
hp = villages.plot(scheme='QUANTILES', **kw)
fig = hp.get_figure()
fig.savefig('health-map.png')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/geopandas/plotting.py:225: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   "(for consistency with matplotlib)", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/geopandas/geodataframe.py:447: UserWarning: Invalid k: 10 (2 <= k <= 9), setting k=5 (default)
#   return plot_dataframe(self, *args, **kwargs)

# %%
#villages
villages.to_csv('villages_health-1.csv')

# %%
#health -- red = bad
kw = dict(column='tree_score', k=10, colormap='RdYlGn')
hp = villages.plot(scheme='QUANTILES', **kw)
fig = hp.get_figure()
fig.savefig('health-map.png')

#summershadows -- pink = more time
kw = dict(column='shadow_summer', k=10, colormap='spring')
ss = villages.plot(scheme='QUANTILES', **kw)
fig = ss.get_figure()
fig.savefig('summer-shadow-map.png')

#wintershadows -- darker blue = more time
kw = dict(column='shadow_winter', k=10, colormap='Blues_r')
ws = villages.plot(scheme='QUANTILES', **kw)
fig = ws.get_figure()
fig.savefig('winter-shadow-map.png')

#fallshadows -- darker orange = more time
kw = dict(column='shadow_fall', k=10, colormap='OrRd_r')
fs = villages.plot(scheme='QUANTILES', **kw)
fig = fs.get_figure()
fig.savefig('fall-shadow-map.png')

#density -- dark green = more dense
kw = dict(column='density', k=10, colormap='summer_r')
dens = villages.plot(scheme='QUANTILES', **kw)
fig = dens.get_figure()
fig.savefig('density-map.png')

#height -- dark purple = taller
kw = dict(column='height_mean', k=10, colormap='PuRd')
h = villages.plot(scheme='QUANTILES', **kw)
fig = h.get_figure()
fig.savefig('height-map.png')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/geopandas/plotting.py:225: FutureWarning: 'colormap' is deprecated, please use 'cmap' instead (for consistency with matplotlib)
#   "(for consistency with matplotlib)", FutureWarning)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/geopandas/geodataframe.py:447: UserWarning: Invalid k: 10 (2 <= k <= 9), setting k=5 (default)
#   return plot_dataframe(self, *args, **kwargs)

# %% [markdown]
# ### .. now, look at the average height of the trees ..
# * check Central Park again!

# %% [raw]
# kw = dict(column='height_mean', k=10, colormap='PuRd')
# villages.plot(scheme='QUANTILES', **kw)
